# %% [markdown]
# # Using an SAE as a steering vector
#
# This notebook demonstrates how to use SAE lens to identify a feature on a pretrained model, and then construct a steering vector to affect the models output to various prompts. This notebook will also make use of Neuronpedia for identifying features of interest.
#
# The steps below include:
#
#
#
# *   Installing relevant packages (Colab or locally)
# *   Load your SAE and the model it used
# *   Determining your feature of interest and its index
# *   Implementing your steering vector

# %% [markdown]
# ## Setting up packages and notebook

# %% [markdown]
# ### Import and installs

# %% [markdown]
# #### Environment Setup

# %%
try:
  # for google colab users
    import google.colab # type: ignore
    from google.colab import output
    COLAB = True
    # %pip install sae-lens transformer-lens
except:
  # for local setup
    COLAB = False
    from IPython import get_ipython # type: ignore
    ipython = get_ipython(); assert ipython is not None
    ipython.run_line_magic("load_ext", "autoreload")
    ipython.run_line_magic("autoreload", "2")

# Imports for displaying vis in Colab / notebook
import webbrowser
import http.server
import socketserver
import threading
PORT = 8000

# general imports
import os
import sys
import torch
from tqdm import tqdm
import plotly.express as px

torch.set_grad_enabled(False);

import copy
import pandas as pd
import itertools as ittl
import numpy as np
from scipy import stats
from scipy.spatial import distance
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from datasets import Dataset
from datasets import load_dataset, concatenate_datasets
import transformers
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### General Installs and device setup

# %%
# package import
from torch import Tensor
from transformer_lens import utils
from transformers import AutoTokenizer, AutoModelForCausalLM
from functools import partial
from jaxtyping import Int, Float


# device setup
if torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Device: {device}")
# Out:
# Device: cuda

# %% [markdown]
# ### Load your model and SAE
#
# We're going to work with a pretrained GPT2-small model, and the RES-JB SAE set which is for the residual stream.

# %%
from transformer_lens import HookedTransformer
from sae_lens import SAE
from sae_lens.toolkit.pretrained_saes import get_gpt2_res_jb_saes

# Choose a layer you want to focus on
# For this tutorial, we're going to use layer 2
# layer = 0

# get model
model = HookedTransformer.from_pretrained("gpt2-small", device=device)

# # get the SAE for this layer
# '''
# sae, cfg_dict, _ = SAE.from_pretrained(
#     release = "gemma-2b-res-jb",
#     sae_id = f"blocks.{layer}.hook_resid_post",
#     device = device
# )
# '''
# sae, cfg_dict, _ = SAE.from_pretrained(
#     release = "gpt2-small-res-jb",
#     sae_id = f"blocks.{layer}.hook_resid_pre",
#     device = device
# )

# # get hook point
# hook_point = sae.cfg.hook_name
# print(hook_point)
# Out:
# /home/jovyan/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loaded pretrained model gpt2-small into HookedTransformer

# %%
print(model.cfg)
# Out:
# HookedTransformerConfig:
# {'act_fn': 'gelu_new',
#  'attention_dir': 'causal',
#  'attn_only': False,
#  'attn_types': None,
#  'checkpoint_index': None,
#  'checkpoint_label_type': None,
#  'checkpoint_value': None,
#  'd_head': 64,
#  'd_mlp': 3072,
#  'd_model': 768,
#  'd_vocab': 50257,
#  'd_vocab_out': 50257,
#  'default_prepend_bos': True,
#  'device': 'cuda',
#  'dtype': torch.float32,
#  'eps': 1e-05,
#  'experts_per_token': None,
#  'final_rms': False,
#  'from_checkpoint': False,
#  'gated_mlp': False,
#  'init_mode': 'gpt2',
#  'init_weights': False,
#  'initializer_range': 0.02886751345948129,
#  'load_in_4bit': False,
#  'model_name': 'gpt2',
#  'n_ctx': 1024,
#  'n_devices': 1,
#  'n_heads': 12,
#  'n_key_value_heads': None,
#  'n_layers': 12,
#  'n_params': 84934656,
#  'normalization_type': 'LNPre',
#  'num_experts': None,
#  'original_architecture': 'GPT2LMHeadModel',
#  'parallel_attn_mlp': False,
#  'positional_embedding_type': 'standard',
#  'post_embedding_ln': False,
#  'rotary_adjacent_pairs': False,
#  'rotary_base': 10000,
#  'rotary_dim': None,
#  'scale_attn_by_inverse_layer_idx': False,
#  'seed': None,
#  'tokenizer_name': 'gpt2',
#  'tokenizer_prepends_bos': False,
#  'trust_remote_code': False,
#  'use_attn_in': False,
#  'use_attn_result': False,
#  'use_attn_scale': True,
#  'use_hook_mlp_in': False,
#  'use_hook_tokens': False,
#  'use_local_attn': False,
#  'use_split_qkv_input': False,
#  'window_size': None}

# %% [markdown]
# ## Determine your feature of interest and its index

# %% [markdown]
# ### Find your feature

# %% [markdown]
# #### Explore through code by using the feature activations for a prompt
#
# For the purpose of the tutorial, we are selecting a simple token prompt.
#
# In this example we will look trying to find and steer a "Jedi" feature.
#
# We run our prompt on our model and get the cache, which we then use with our sae to get our feature activations.
#
# Now we'll look at the top feature activations and look them up on Neuronpedia to determine what they have been intepreted as.

# %%
# print('dir(sae)\n', dir(sae))
# print('sae.W_enc.shape\n', sae.W_enc.shape)

# print('\n')

# #sv_prompt = " The Golden Gate Bridge"
# # sv_prompt = 'Jedi'
# sv_prompt = 'Emily\'s dog just died. She is feeling sad'
# # sv_prompt = 'John\'s lunch was stolen. He is feeling angry'
# # sv_prompt = 'John just received a present. He is feeling happy'

# sv_logits, cache = model.run_with_cache(sv_prompt, prepend_bos=True)
# tokens = model.to_tokens(sv_prompt)
# print('tokens', tokens)

# # get the feature activations from our SAE
# sv_feature_acts = sae.encode(cache[hook_point])

# # get sae_out
# sae_out = sae.decode(sv_feature_acts)

# # print out the top activations, focus on the indices
# print('\n', torch.topk(sv_feature_acts, 3))


# # Explanation of the topk outputs below:
# # There are 5 tokens in sv_prompt: <BOS>, The, Golden, Gate, Bridge. 
# # So what topk is showing is for each token what SAE feature is being activated the most.
# # Thats why we have a 5 x 3 array.

# %% [markdown]
# ### Set up hook functions
#
# Finally, we need to create a hook that allows us to apply the steering vector when our model runs generate() on our defined prompt. We have also added a boolean value 'steering_on' that allows us to easily toggle the steering vector on and off for each prompt

# %%
def steering_hook(resid_pre, hook):

    if resid_pre.shape[1] == 1:
        return

    # print('resid_pre.shape', resid_pre.shape)
    position = sae.W_dec.shape[-1]
    # print('sae_out.shape', sae_out.shape, '\n')
    if steering_on:
      # using our steering vector and applying the coefficient

      # So here resid_pre are the values from the residual stream (in this case [batch_size, n_tokens, 768])
      # We modify all values up to but not including the last token (since its an EOS token)

      # Modification is an addition of the outgoing weights from the target SAE feature 
      # (which is a size 768 vector) multiplied by a coefficient that controls the magnitude of the steering

      # The steered values would then make their way through the rest of the model
      resid_pre[:, :position - 1, :] += coeff * steering_vector

def ablation_hook(resid_pre, hook):

    if resid_pre.shape[1] == 1:
        return
    
    if steering_on:

        position = sae.W_dec.shape[-1]
    
        act_strength = (resid_pre @ sae.W_enc)[:, :position-1, feature_id]
        act_strength = torch.unsqueeze(act_strength, -1)
        new_shape = list(act_strength.shape)
        new_shape[-1] = steering_vector.shape[-1]
        act_strength.expand(new_shape)

        resid_pre[:, :position-1, :] -= act_strength * steering_vector

def hooked_generate(prompt_batch, fwd_hooks=[], seed=None, **kwargs):
    if seed is not None:
        torch.manual_seed(seed)

    with model.hooks(fwd_hooks=fwd_hooks):
        tokenized = model.to_tokens(prompt_batch)
        result = model.generate(
            stop_at_eos=False,  # avoids a bug on MPS
            input=tokenized,
            max_new_tokens=30,
            do_sample=True,
            **kwargs)
    return result

# %%
def run_generate(prompts, n_samples, steering_type='steer'):
  
  res_list = []

  for prompt, label in prompts:

    model.reset_hooks()

    # Steering
    editing_hooks = [(f"blocks.{layer}.hook_resid_pre", steering_hook)] if steering_type == 'steer' \
                    else [(f"blocks.{layer}.hook_resid_pre", ablation_hook)]

    res = hooked_generate([prompt] * n_samples, editing_hooks, seed=None, **sampling_kwargs)

    # Print results, removing the ugly beginning of sequence token
    res_str = model.to_string(res[:, 1:])
    res_str = [(text.split('\". '))[1] for text in res_str]
    res_list.append({'prompt': prompt, 'responses': res_str, 'label': label})

  return pd.DataFrame(res_list)

# %% [markdown]
# ## Implement your steering vector and affect the output

# %% [markdown]
# ### Define values for your steering vector
# To create our steering vector, we now need to get the decoder weights from our sparse autoencoder found at our index of interest.
#
# Then to use our steering vector, we want a prompt for text generation, as well as a scaling factor coefficent to apply with the steering vector
#
# We also set common sampling kwargs - temperature, top_p and freq_penalty

# %%
# Golden State Bridge:
# steering_vector = sae.W_dec[10200]

# Jedi:
# steering_vector = sae.W_dec[7650]

# Sadness: 2442, 
# steering_vector = sae.W_dec[2442]

# Anger: 1550, 4707, 18357, 5526, 21165, 252
# steering_vector = sae.W_dec[21165]

# Worry: 849, 15524, 18978, 21673
# steering_vector = sae.W_dec[18978]

# Happiness: 13928, 3879, 3456
# steering_vector = sae.W_dec[24422]
# sampling_kwargs = dict(temperature=0.9, top_p=0.1, freq_penalty=1.0)

# %% [markdown]
# ### Loading an Emotion Recognition Dataset - https://github.com/dair-ai/emotion_dataset

# %%
emotion_dataset = load_dataset('dair-ai/emotion', split='train', trust_remote_code=True)

# %%
emotion_dataset = emotion_dataset.shuffle(seed=42)

# %%
# Split dataset into partitions based on label
parted_dataset = [emotion_dataset.filter(lambda x: x['label'] == label) for label in range(len(emotion_dataset.features['label'].names))]

# %%
print(parted_dataset[0])
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 4666
# })

# %%
# batch_size will take batch_size number of samples from each class, awkward naming but whatever
batch_size = 5
batch = concatenate_datasets([part.select([x for x in range(batch_size)]) for part in parted_dataset])
print(batch)
# prompts = [f'Jennifer says, \"{text}\". Jennifer feels' for text in batch['text']]
prompts = [f'Alex says, \"{text}\". Alex feels' for text in batch['text']]
labels = [label for label in batch['label']]
prompts = list(zip(prompts, labels))
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 30
# })

# %% [markdown]
# ### Getting a "judge" model to judge the generations

# %%
sampling_kwargs = dict(temperature=0.5, top_p=0.1, freq_penalty=5.0)
n_samples = 1
steer_type = 'steer'
coeff = 15
feature_id = 22318
steering_vector = sae.W_dec[feature_id]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb Cell 27 line 6
#       <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X35sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> coeff = 15
#       <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X35sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> feature_id = 22318
# ----> <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X35sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> steering_vector = sae.W_dec[feature_id]
#
# NameError: name 'sae' is not defined

# %%
steering_on = False
default_generation = run_generate(prompts, n_samples, steering_type=steer_type)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
steering_on = True
steered_generation = run_generate(prompts, n_samples, steering_type=steer_type)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
emotion_features = {

    'layer_0':
    {
        'sadness': [12266, 23208, 14158, 10882, 10510, 546], 
        'joy': [8699, 10924, 13808, 16670, 15464, 1432], 
        'love': [24486, 19618, 3970, 7792, 13985, 21219, 4892, 7099],
        'anger': [22318, 13668, 17628, 12030, 800, 22574],
        'fear': [2998, 8167, 634, 22447, 15196, 8194, 2288, 13200, 23219, 4783, 6938],
        'surprise': [8279, 2031, 5029, 14386, 16023, 15694],
    },

    'layer_1':
    {
        'sadness': [8174, 15771, 24104, 8419], 
        'joy': [18120, 23750, 17653, 6284, 11250, 24040, 7683, 3591], 
        'love': [3091, 14230, 6847, 4332, 150],
        'anger': [20851, 13745, 10403, 11541, 4194],
        'fear': [5186, 6767, 20821, 23954, 21612, 21153, 19325, 6146, 21826],
        'surprise': [12718, 23779, 18239, 666, 487, 16125, 8551, 2037],
    },

    'layer_2':
    {
        'sadness': [11683, 14915, 11568, 4350, 2442], 
        'joy': [7796, 23405, 22134, 3456, 13928, 3879, 23476], 
        'love': [3203],
        'anger': [11085, 21027, 14918, 252, 21165, 4707, 1550, 5526, 18357],
        'fear': [24422, 22815, 21011, 20309, 18350, 10882, 9937, 5843, 12026],
        'surprise': [11631, 11365, 15076, 10353, 7902, 7800],
    },

    'layer_3':
    {
        'sadness': [24140, 24469, 22098, 14290], 
        'joy': [10739, 9828, 14625, 5329, 19341, 10990, 6001], 
        'love': [14981, 5501, 15927, 11815, 23271],
        'anger': [13819, 9272, 412, 3213, 16043, 24133],
        'fear': [6134, 1861, 22236, 8135, 20126, 20648, 2253, 20588, 18762, 9805, 8914, 6653],
        'surprise': [3282, 23140, 10647, 972, 17827, 3625, 17365, 14434, 10958],
    },

    'layer_4':
    {
        'sadness': [5179, 7494, 9341, 22033, 23292, 10051], 
        'joy': [15968, 12298, 9569, 8244, 22722], 
        'love': [9757, 10750, 4004, 7249],
        'anger': [22695, 9072, 18320, 11510, 3810, 16080, 15004, 11183],
        'fear': [20655, 18321, 13386, 4338, 2955, 24553, 16651, 15882, 14836, 12290],
        'surprise': [19514, 15250, 19967, 16649, 24019, 12758, 9661],
    },

    'layer_5':
    {
        'sadness': [1265, 22889], 
        'joy': [6803, 17170, 14404, 1255, 13678, 14997], 
        'love': [23060, 12473, 3674, 18288, 13689, 4600, 3448],
        'anger': [1773, 330, 5136, 9706, 9559],
        'fear': [7952, 15844, 6801, 21689, 24318, 2212, 5990, 15747],
        'surprise': [21258, 14750, 2877, 3055, 17557, 23920, 3546, 16559, 9884, 7516, 6011],
    },

    'layer_6':
    {
        'sadness': [20719, 251], 
        'joy': [9995, 3020, 18199, 14968, 203, 2617], 
        'love': [19727, 16022, 11397, 14808],
        'anger': [20521, 16530, 10131, 6415, 15780, 21846],
        'fear': [3246, 5289, 12900, 20520, 18781, 2459, 20211, 19068, 6685, 2260],
        'surprise': [13502, 18954, 14477, 6315, 9678, 2328, 21364, 17678, 9978, 19798, 3036],
    },

    'layer_7':
    {
        'sadness': [2045], 
        'joy': [24314, 17025, 19547], 
        'love': [2887, 2715, 19662],
        'anger': [1776, 10033],
        'fear': [18892, 13863, 17128, 13519, 4505, 5211, 17463, 19010, 15862, 14791],
        'surprise': [17837, 20417, 17104, 12344, 8002, 10849, 15668, 11750, 8981, 8442],
    },

    'layer_8':
    {
        'sadness': [7473, 3927], 
        'joy': [13624, 8708, 13433], 
        'love': [8631, 9837, 2017],
        'anger': [21519, 22715, 2133, 17121],
        'fear': [13796, 4846, 8887, 4810, 19414, 19585, 17376],
        'surprise': [14571, 1366, 14856, 15950, 15512, 20821, 8855, 12456, 20423, 4939],
    },

    'layer_9':
    {
        'sadness': [10885, 17773, 5000], 
        'joy': [4288, 7702, 20850, 1418, 4864], 
        'love': [20105, 9946, 17442, 21303, 21876],
        'anger': [21253, 7002, 15510, 16663],
        'fear': [20233, 19535, 5563, 1413, 15382, 14412],
        'surprise': [21445, 21532, 10719, 14851, 24082, 16180, 1167, 14205, 7831, 17898, 1655],
    },

    'layer_10':
    {
        'sadness': [11363], 
        'joy': [4091, 5713, 809], 
        'love': [10165, 14654, 20694, 19070, 130, 2095],
        'anger': [14697, 5203, 19957],
        'fear': [24358, 20305, 18367, 6822, 6260, 2783],
        'surprise': [2150, 9733, 23922, 23723, 7658, 184, 18509, 20367, 14901, 6227],
    },

    'layer_11':
    {
        'sadness': [3334, 24428, 16896], 
        'joy': [4943, 8946], 
        'love': [12316, 6390, 6694, 15057, 4407],
        'anger': [21754, 12214, 8427, 20367, 14410],
        'fear': [13374, 9550, 24256, 14324, 13554, 165, 12092, 9703, 20934],
        'surprise': [22471, 5047, 22203, 17670, 17411, 17777, 5820, 949, 12189, 4452, 15556, 3086, 21799],
    },

}

# %% [markdown]
# ### Attempts at LLMs as Oracles

# %%
emotion_labels = emotion_dataset.features['label'].names
# judge_prompt = f'For each of the following emotions: {emotion_labels}, rate '
emotions = ", ".join(emotion_labels)
print(emotions, '\n')
# judge_prompt = f'For the following text: {example_response}, which of the following emotions: {emotions}, does John feel?'
# judge_prompt = f'For the following text: \"{steered_example[0]}\", what does John feel?'
# judge_prompt = f'Given the following text: \"{steered_example[0]}\", what does John feel? John feels'

# example_idx = 0

# default_example = default_generation.iloc[example_idx]['responses'][0]
# steered_example = steered_generation.iloc[example_idx]['responses'][0]

# print(default_generation.iloc[example_idx]['prompt'])
# print(default_example)
# print(list(set(default_generation.iloc[example_idx]['prompt'].split(' ')) & set(default_example.split(' '))))
# print()
# print(steered_generation.iloc[example_idx]['prompt'])
# print(steered_example)
# print(list(set(steered_generation.iloc[example_idx]['prompt'].split(' ')) & set(steered_example.split(' '))))
# Out:
# sadness, joy, love, anger, fear, surprise

# %%
# model_id = "meta-llama/Meta-Llama-3-8B"

# tokenizer = AutoTokenizer.from_pretrained(model_id)
# judge_model = AutoModelForCausalLM.from_pretrained(model_id)

# pipeline = transformers.pipeline(
#     "text-generation",
#     model=model_id,
#     model_kwargs={"torch_dtype": torch.bfloat16},
#     device=device,
#     return_full_text=False,
# )
# pipeline.tokenizer.pad_token_id = judge_model.config.eos_token_id

# %%
# Constrained generation
from guidance import models
from guidance import select

guided_model = models.Transformers('meta-llama/Meta-Llama-3-8B', device_map={"": 0})
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# # Import few-shot prompt

# # label_map = {'(a)': 'sadness', '(b)': 'joy', '(c)': 'love', '(d)': 'anger', '(e)': 'fear', '(f)': 'surprise'}
# label_map = {'(a)': 0, '(b)': 1, '(c)': 2, '(d)': 3, '(e)': 4, '(f)': 5}

# # new_prompt = f"\n\n---\n\nText:\n\\'\'\'\n{default_example}\n\\'\'\'\nLabel: "

prompt_file = open('fewshot1.txt', 'r')

judge_fewshot = prompt_file.read()
judge_prompt = judge_fewshot + new_prompt

prompt_file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb Cell 36 line 1
#       <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> prompt_file = open('fewshot1.txt', 'r')
#      <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> judge_fewshot = prompt_file.read()
# ---> <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> judge_prompt = judge_fewshot + new_prompt
#      <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> prompt_file.close()
#
# NameError: name 'new_prompt' is not defined

# %%
# from guidance import select

# # lm = guided_model + judge_prompt + select(['(a)', '(b)', '(c)', '(d)', '(e)', '(f)'], name='choice')
# lm = guided_model + judge_prompt + select(emotion_labels, name='choice')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb Cell 36 line 4
#       <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X51sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from guidance import select
#       <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X51sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # lm = guided_model + judge_prompt + select(['(a)', '(b)', '(c)', '(d)', '(e)', '(f)'], name='choice')
# ----> <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X51sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> lm = guided_model + judge_prompt + select(emotion_labels, name='choice')
#
# NameError: name 'judge_prompt' is not defined

# %%
print(lm['choice'])
# Out:
# fear

# %% [markdown]
# ### Default responses from GPT2 (no steering, annotation done by Llama 3 - 8B)

# %%
def annotate_responses(generation):

    annotation_df = generation.copy(deep=True)
    annotation_df['responses'] = np.empty(annotation_df['responses'].size, dtype=str)
    annotation_df = annotation_df.rename(columns={'responses': 'prediction'})

    for i, row in generation.iterrows():

        row_annotations = pd.Series(n_samples, dtype=int)

        judge_prompts = []
        for j, response in enumerate(row['responses']):

            new_prompt = f"\n\n---\n\nText:\n\\'\'\'\n{response}\n\\'\'\'\nLabel: "
            # guided_res = guided_model + judge_fewshot + new_prompt + select(['(a)', '(b)', '(c)', '(d)', '(e)', '(f)'], name='choice')
            guided_res = guided_model + judge_fewshot + new_prompt + select(emotion_labels, name='choice')
            row_annotations[j] = guided_res['choice']
        
        # annotation = label_map[(row_annotations.mode())[0]]
        annotation = (row_annotations.mode())[0]
        annotation_df.loc[i, "prediction"] = annotation

    return annotation_df

# %%
# def annotate_responses(generation):

#     annotation_df = generation.copy(deep=True)
#     annotation_df['responses'] = np.empty(annotation_df['responses'].size, dtype=str)
#     annotation_df = annotation_df.rename(columns={'responses': 'prediction'})

#     for i, row in generation.iterrows():

#         row_annotations = pd.Series(n_samples, dtype=int)

#         judge_prompts = []
#         for j, response in enumerate(row['responses']):

#             new_prompt = f"\n\n---\n\nText:\n\\'\'\'\n{response}\n\\'\'\'\nLabel: "
#             guided_res = guided_model + judge_fewshot + new_prompt + select(['(a)', '(b)', '(c)', '(d)', '(e)', '(f)'], name='choice')
#             row_annotations[j] = guided_res['choice']
#             # judge_prompts.append(judge_fewshot + new_prompt)

#         # judge_prompts = Dataset.from_list(judge_prompts)
#         # outputs = pipeline(
#         #             judge_prompts,
#         #             max_new_tokens=3,
#         #             eos_token_id=terminators,
#         #             do_sample=True,
#         #             temperature=0.1,
#         #             top_p=0.1,
#         #             batch_size=len(judge_prompts)
#         #             )   
                    
#         # try:
#         #     row_annotations = pd.Series([label_map[item[0]['generated_text'][1:4]] for item in outputs])
#         # except:
#         #     print('error getting annotation')
#         #     debug = open('debug.txt', 'a')
#         #     debug.write(str(judge_prompts))
#         #     debug.close()
#         # annotation = label_map[outputs[0]['generated_text'][1:4]]
#         # row_annotations[j] = annotation
#         annotation = label_map[(row_annotations.mode())[0]]
#         # Add annotation to annotation_df
#         # annotation_df['prediction'][i] = annotation
#         annotation_df.loc[i, "prediction"] = annotation

#     return annotation_df

# %%
default_preds = annotate_responses(default_generation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb Cell 41 line 1
# ----> <a href='vscode-notebook-cell://lobot.caslab.queensu.ca/home/jovyan/1L-Sparse-Autoencoder/feature_steering.ipynb#X55sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> default_preds = annotate_responses(default_generation)
#
# NameError: name 'default_generation' is not defined

# %%
steered_preds = annotate_responses(steered_generation)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'>Label the text with the correct emotion:
#
# sadness
# joy
# love
# anger
# fear
# surprise
#
# ---
#
# Text:
# \```
# John feels angry.
# \```
# Label: anger
#
# ---
#
# Text:
# \```
# John feels miserable.
# \```
# Label: sadness
#
# ---
#
# Text:
# \```
# John feels loved.
# \```
# Label: love
#
# ---
#
# Text:
# \```
# John feels surprised.
# \```
# Label: surprise
#
# ---
#
# Text:
# \```
# John feels frightened.
# \```
# Label: fear
#
# ---
#
# Text:
# \```
# John feels joyful.
# \```
# Label: joy
#
# ---
#
# Text:
# \```
# John feels affectionate.
# \```
# Label: love
#
# ---
#
# Text:
# \```
# John feels frustrated.
# \```
# Label: anger
#
# ---
#
# Text:
# \```
# John feels sad.
# \```
# Label: sadness
#
# ---
#
# Text:
# \```
# John feels shocked.
# \```
# Label: surprise
#
# ---
#
# Text:
# \```
# John feels afraid.
# \```
# Label: fear
#
# ---
#
# Text:
# \```
# John feels happy.
# \```
# Label: joy
#
# ---
#
# Text:
# \&#x27;&#x27;&#x27;
# Alex feels fury furious fury to the.
# ! of a moment that it was in her on back for all when this one- &#x27; as no matter before his
# \&#x27;&#x27;&#x27;
# Label: <span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>anger</span></pre>
# /tmp/ipykernel_32363/515263311.py:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'anger' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   row_annotations[j] = guided_res['choice']

# %%
def fill_missing_labels(series: pd.Series):

    # labels = [0, 1, 2, 3, 4, 5]
    labels = emotion_labels
    missing = []
    for label in labels:
        if label not in series.index:
            missing.append(label)
            
    missing = pd.Series([0 for _ in range(len(missing))], index=missing)

    return pd.concat([series, missing]) if not(missing.empty) else series

# %%
# Fill in missing labels if necessary 

real_distr = default_preds['label'].value_counts(sort=False)
print(real_distr.index)
# real_distr = real_distr.reindex(sorted(real_distr.index))
real_distr.index = emotion_labels


default_distr = fill_missing_labels(default_preds['prediction'].value_counts(sort=False))
# default_distr = default_distr.reindex(sorted(default_distr.index))
default_distr = default_distr.reindex(emotion_labels)

steered_distr = fill_missing_labels(steered_preds['prediction'].value_counts(sort=False))
# steered_distr = steered_distr.reindex(sorted(steered_distr.index))
steered_distr = steered_distr.reindex(emotion_labels)
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int64', name='label')

# %%
print(real_distr.index)
# Out:
# Index(['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'], dtype='object')

# %%
plot_df = pd.DataFrame([real_distr, default_distr, steered_distr]).transpose()
plot_df.columns = ['real', 'default', 'steered']
print(plot_df)
# Out:
#           real  default  steered
# sadness      5        6        0
# joy          5        4        0
# love         5        5        0
# anger        5        6       30
# fear         5        9        0
# surprise     5        0        0

# %%
# df = pd.DataFrame({"Example one":yesSeries,"Example two":nodSeries})
ax = plot_df.plot.bar(color=["SeaGreen", "SkyBlue","IndianRed"], rot=0, title=f"Default and Steered Label Predictions ({steer_type} feature {feature_id})")
ax.set_xlabel("Predicted Labels")
ax.set_ylabel("Counts")
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()

# %%
# Calculate Jensen-Shannon Divergence for real labels vs default predictions

js_dis = distance.jensenshannon(default_distr, steered_distr)
print(js_dis)
# Out:
# 0.6502387678692824

# %% [markdown]
# ## Go through emotion related features and check ablation effects on prediction

# %%
# batch_size will take batch_size number of samples from each class, awkward naming but whatever
batch_size = 15
batch = concatenate_datasets([part.select([x for x in range(batch_size)]) for part in parted_dataset])
print(batch)
# prompts = [f'Jennifer says, \"{text}\". Jennifer feels' for text in batch['text']]
prompts = [f'Alex says, \"{text}\". Alex feels' for text in batch['text']]
labels = [label for label in batch['label']]
prompts = list(zip(prompts, labels))
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 90
# })

# %% [markdown]
# BTW, I should also do divergence with just the logit distribution (final output of model)

# %%
ablation_effects = copy.deepcopy(emotion_features)
steer_20_effects = copy.deepcopy(emotion_features)
sampling_kwargs = dict(temperature=0.5, top_p=0.1, freq_penalty=5.0)
n_samples = 1
# coeff = 20
# steer_type = 'ablate'
# target_layer = 0

# Get default distribution
steering_on = False
default_generation = run_generate(prompts, n_samples, steering_type=steer_type)
default_preds = annotate_responses(default_generation)
default_distr = fill_missing_labels(default_preds['prediction'].value_counts(sort=False))
default_distr = default_distr.reindex(emotion_labels)
    

steering_on = True
for layer_idx, layer_name in enumerate(ablation_effects.keys()):

    layer = layer_idx

    # Load SAE for this layer
    sae, cfg_dict, _ = SAE.from_pretrained(
        release = "gpt2-small-res-jb",
        sae_id = f"blocks.{layer_idx}.hook_resid_pre",
        device = device
        )

    # get hook point
    hook_point = sae.cfg.hook_name

    for emotion in ablation_effects[layer_name]:
        
        # steer_type = 'ablate'
        # for j, feature_num in enumerate(ablation_effects[layer_name][emotion]):

        #     feature_id = feature_num
        #     steering_vector = sae.W_dec[feature_num]
            
        #     # Do generation
        #     responses = run_generate(prompts, n_samples, steering_type=steer_type)

        #     # Do annotation
        #     annotations = annotate_responses(responses)

        #     # Get distribution
        #     new_distr = fill_missing_labels(annotations['prediction'].value_counts(sort=False))
        #     new_distr = new_distr.reindex(emotion_labels)

        #     # Get JS distance
        #     js_distance = distance.jensenshannon(default_distr, new_distr)

        #     # Replace value in dict
        #     ablation_effects[layer_name][emotion][j] = (feature_num, js_distance, new_distr)
        
        steer_type = 'steer'
        coeff = 10
        for j, feature_num in enumerate(steer_20_effects[layer_name][emotion]):

            feature_id = feature_num
            steering_vector = sae.W_dec[feature_num]
            print('steering_vector.shape', steering_vector.shape)

            # Try normalizing steering_vector
            # steering_vector = torch.nn.functional.normalize(steering_vector, dim=0)
              
            # Do generation
            responses = run_generate(prompts, n_samples, steering_type=steer_type)

            # Do annotation
            annotations = annotate_responses(responses)

            # Get distribution
            new_distr = fill_missing_labels(annotations['prediction'].value_counts(sort=False))
            new_distr = new_distr.reindex(emotion_labels)

            # Get JS distance
            js_distance = distance.jensenshannon(default_distr, new_distr)

            # Replace value in dict
            steer_20_effects[layer_name][emotion][j] = (feature_num, js_distance, new_distr)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'>Label the text with the correct emotion:
#
# sadness
# joy
# love
# anger
# fear
# surprise
#
# ---
#
# Text:
# \```
# John feels angry.
# \```
# Label: anger
#
# ---
#
# Text:
# \```
# John feels miserable.
# \```
# Label: sadness
#
# ---
#
# Text:
# \```
# John feels loved.
# \```
# Label: love
#
# ---
#
# Text:
# \```
# John feels surprised.
# \```
# Label: surprise
#
# ---
#
# Text:
# \```
# John feels frightened.
# \```
# Label: fear
#
# ---
#
# Text:
# \```
# John feels joyful.
# \```
# Label: joy
#
# ---
#
# Text:
# \```
# John feels affectionate.
# \```
# Label: love
#
# ---
#
# Text:
# \```
# John feels frustrated.
# \```
# Label: anger
#
# ---
#
# Text:
# \```
# John feels sad.
# \```
# Label: sadness
#
# ---
#
# Text:
# \```
# John feels shocked.
# \```
# Label: surprise
#
# ---
#
# Text:
# \```
# John feels afraid.
# \```
# Label: fear
#
# ---
#
# Text:
# \```
# John feels happy.
# \```
# Label: joy
#
# ---
#
# Text:
# \&#x27;&#x27;&#x27;
# Alex feels like he&#x27;s in a trance. He starts to feel more and more comfortable with his surroundings.
#
# &quot;I&#x27;m not sure if it is just
# \&#x27;&#x27;&#x27;
# Label: <span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>fear</span></pre>
# /tmp/ipykernel_1004/515263311.py:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'fear' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   row_annotations[j] = guided_res['choice']

# %%
import pickle

# %%
with open(f'steer_10_effect_all_layers.pkl', 'wb') as f:
    pickle.dump(steer_20_effects, f)

# %%
with open(f'steer_10_effect_all_layers.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)
    print(loaded_dict)
# Out:
# {'layer_0': {'sadness': [(12266, 0.5441889393587733, sadness     54
# joy          0
# love        36
# anger        0
# fear         0
# surprise     0
# dtype: int64), (23208, 0.6460578116808572, sadness     87
# joy          0
# love         1
# anger        0
# fear         2
# surprise     0
# dtype: int64), (14158, 0.6900749503973443, sadness     90
# joy          0
# love         0
# anger        0
# fear         0
# surprise     0
# dtype: int64), (10882, 0.599689322777156, sadness     82
# joy          0
# love         3
# anger        0
# fear         5
# surprise     0
# dtype: int64), (10510, 0.6900749503973443, sadness     90
# joy          0
# love         0
# anger        0
# fear         0
# surprise     0
# dtype: int64), (546, 0.6900749503973443, sadness     90
# joy          0
# love         0
# anger        0
# fear         0
# surprise     0
# dtype: int64)], 'joy': [(8699, 0.6347128338599364, sadness      0
# joy         29
# love        11
# anger        0
# fear         1
# surprise    49
# dtype: int64), (10924, 0.6508789521971602, sadness      1
# joy         88
# love         0
# anger        0
# fear         1
# surprise     0
# dtype: int64), (13808, 0.5058649865454296, sadness      4
# joy          3
# love        81
# anger        1
# fear         1
# surprise     0
# dtype: int64), (16670, 0.6123243143393922, sadness      0
# joy         82
# love         8
# anger        0
# fear         0
# surprise     0
# dtype: int64), (15464, 0.5505002782515989, sadness      0
# joy         63
# love        27
# anger        0
# fear         0
# surprise     0
# dtype: int64), (1432, 0.5194681552724966, sadness      6
# joy          0
# love        80
# anger        0
# fear         4
# surprise     0
# dtype: int64)], 'love': [(24486, 0.6203960348901981, sadness      0
# joy          0
# love        90
# anger        0
# fear         0
# surprise     0
# dtype: int64), (19618, 0.5948571412602007, sadness      0
# joy          2
# love        88
# anger        0
# fear         0
# surprise     0
# dtype: int64), (3970, 0.6203960348901981, sadness      0
# joy          0
# love        90
# anger        0
# fear         0
# surprise     0
# dtype: int64), (7792, 0.6203960348901981, sadness      0
# joy          0
# love        90
# anger        0
# fear         0
# surprise     0
# dtype: int64), (13985, 0.6203960348901981, sadness      0
# joy          0
# love        90
# anger        0
# fear         0
# surprise     0
# dtype: int64), (21219, 0.3237527566496205, sadness      5
# joy          0
# love        32
# anger        9
# fear        42
# surprise     2
# dtype: int64), (4892, 0.4554230650692342, sadness      1
# joy          0
# love        74
# anger        5
# fear        10
# surprise     0
# dtype: int64), (7099, 0.6203960348901981, sadness      0
# joy          0
# love        90
# anger        0
# fear         0
# surprise     0
# dtype: int64)], 'anger': [(22318, 0.4284979031483098, sadness      1
# joy          0
# love        35
# anger       51
# fear         3
# surprise     0
# dtype: int64), (13668, 0.4779220172417087, sadness      0
# joy          0
# love        20
# anger       67
# fear         3
# surprise     0
# dtype: int64), (17628, 0.6426368607874716, sadness      0
# joy          0
# love         0
# anger       90
# fear         0
# surprise     0
# dtype: int64), (12030, 0.6277244464204002, sadness      1
# joy          0
# love         0
# anger       89
# fear         0
# surprise     0
# dtype: int64), (800, 0.6426368607874716, sadness      0
# joy          0
# love         0
# anger       90
# fear         0
# surprise     0
# dtype: int64), (22574, 0.6254592290167893, sadness      0
# joy          0
# love         1
# anger       89
# fear         0
# surprise     0
# dtype: int64)], 'fear': [(2998, 0.44641092018603434, sadness      5
# joy          0
# love        65
# anger        0
# fear        20
# surprise     0
# dtype: int64), (8167, 0.6203960348901981, sadness      0
# joy          0
# love         0
# anger        0
# fear        90
# surprise     0
# dtype: int64), (634, 0.6203960348901981, sadness      0
# joy          0
# love         0
# anger        0
# fear        90
# surprise     0
# dtype: int64), (22447, 0.6050608328807885, sadness      1
# joy          0
# love         0
# anger        0
# fear        89
# surprise     0
# dtype: int64), (15196, 0.6203960348901981, sadness      0
# joy          0
# love         0
# anger        0
# fear        90
# surprise     0
# dtype: int64), (8194, 0.6203960348901981, sadness      0
# joy          0
# love         0
# anger        0
# fear        90
# surprise     0
# dtype: int64), (2288, 0.4572936294498618, sadness      0
# joy          0
# love        19
# anger        3
# fear        68
# surprise     0
# dtype: int64), (13200, 0.3828356012024193, sadness      7
# joy          0
# love        26
# anger        2
# fear        54
# surprise     1
# dtype: int64), (23219, 0.6203960348901981, sadness      0
# joy          0
# love         0
# anger        0
# fear        90
# surprise     0
# dtype: int64), (4783, 0.6203960348901981, sadness      0
# joy          0
# love         0
# anger        0
# fear        90
# surprise     0
# dtype: int64), (6938, 0.5214210138199261, sadness      0
# joy          0
# love         9
# anger        1
# fear        80
# surprise     0
# dtype: int64)], 'surprise': [(8279, 0.3916848267213387, sadness      0
# joy         10
# love        16
# anger       12
# fear        28
# surprise    24
# dtype: int64), (2031, 0.36763159340960433, prediction
# sadness      3
# joy         20
# love         5
# anger        7
# fear        43
# surprise    12
# Name: count, dtype: int64), (5029, 0.8325546111576977, sadness      0
# joy          0
# love         0
# anger        0
# fear         0
# surprise    90
# dtype: int64), (14386, 0.38438450312925454, sadness      2
# joy          0
# love        55
# anger       19
# fear        10
# surprise     4
# dtype: int64), (16023, 0.6478103897817655, sadness      1
# joy          0
# love        25
# anger        1
# fear         3
# surprise    60
# dtype: int64), (15694, 0.8325546111576977, sadness      0
# joy          0
# love         0
# anger        0
# fear         0
# surprise    90
# dtype: int64)]}, 'layer_1': {'sadness': [(8174, 0.21814910697178627, prediction
# sadness     25
# joy         17
# love        28
# anger        7
# fear        11
# surprise     2
# Name: count, dtype: int64), (15771, 0.12574925198221198, prediction
# sadness     23
# joy         13
# love        15
# anger       18
# fear        20
# surprise     1
# Name: count, dtype: int64), (24104, 0.1889728753603165, prediction
# sadness     25
# joy         19
# love        20
# anger       14
# fear        10
# surprise     2
# Name: count, dtype: int64), (8419, 0.1497165149496651, prediction
# sadness     22
# joy         10
# love        17
# anger       16
# fear        22
# surprise     3
# Name: count, dtype: int64)], 'joy': [(18120, 0.20167395042972433, prediction
# sadness     18
# joy         14
# love        29
# anger        6
# fear        19
# surprise     4
# Name: count, dtype: int64), (23750, 0.13002393913348426, prediction
# sadness     21
# joy         15
# love        16
# anger       18
# fear        18
# surprise     2
# Name: count, dtype: int64), (17653, 0.1797626974748056, prediction
# sadness     18
# joy         17
# love        19
# anger       12
# fear        18
# surprise     6
# Name: count, dtype: int64), (6284, 0.19824968517602104, prediction
# sadness     18
# joy         29
# love        17
# anger       12
# fear        12
# surprise     2
# Name: count, dtype: int64), (11250, 0.21462854854982844, prediction
# sadness     11
# joy         33
# love        18
# anger       11
# fear        14
# surprise     3
# Name: count, dtype: int64), (24040, 0.11474526063841675, prediction
# sadness     10
# joy         18
# love        23
# anger       21
# fear        16
# surprise     2
# Name: count, dtype: int64), (7683, 0.22502304836598833, prediction
# sadness     13
# joy         37
# love        13
# anger       14
# fear        12
# surprise     1
# Name: count, dtype: int64), (3591, 0.1677910205584698, prediction
# sadness      7
# joy         25
# love        29
# anger       15
# fear        13
# surprise     1
# Name: count, dtype: int64)], 'love': [(3091, 0.1413121637593637, prediction
# sadness     10
# joy         15
# love        33
# anger       13
# fear        17
# surprise     2
# Name: count, dtype: int64), (14230, 0.18581694041218258, prediction
# sadness     12
# joy         23
# love        33
# anger       10
# fear        11
# surprise     1
# Name: count, dtype: int64), (6847, 0.16410319255848488, prediction
# sadness     11
# joy         22
# love        26
# anger       16
# fear        12
# surprise     3
# Name: count, dtype: int64), (4332, 0.16484962666468767, prediction
# sadness     19
# joy         13
# love        29
# anger       11
# fear        15
# surprise     3
# Name: count, dtype: int64), (150, 0.16312046516954276, prediction
# sadness     21
# joy          6
# love        20
# anger       17
# fear        23
# surprise     3
# Name: count, dtype: int64)], 'anger': [(20851, 0.2792830708150944, prediction
# sadness     18
# joy          5
# love         8
# anger       43
# fear        13
# surprise     3
# Name: count, dtype: int64), (13745, 0.16878509532755845, prediction
# sadness     12
# joy          9
# love        11
# anger       29
# fear        27
# surprise     2
# Name: count, dtype: int64), (10403, 0.26839117974715987, prediction
# sadness     17
# joy          6
# love         8
# anger       44
# fear        13
# surprise     2
# Name: count, dtype: int64), (11541, 0.19218737863189642, prediction
# sadness     18
# joy         12
# love        16
# anger       29
# fear        11
# surprise     4
# Name: count, dtype: int64), (4194, 0.07802691828581283, prediction
# sadness     13
# joy         14
# love        21
# anger       23
# fear        18
# surprise     1
# Name: count, dtype: int64)], 'fear': [(5186, 0.17097009163800397, prediction
# sadness     17
# joy         10
# love        16
# anger       18
# fear        23
# surprise     6
# Name: count, dtype: int64), (6767, 0.19127389415308796, prediction
# sadness     21
# joy         10
# love        12
# anger       12
# fear        32
# surprise     3
# Name: count, dtype: int64), (20821, 0.17057633544641873, prediction
# sadness     14
# joy         11
# love        15
# anger       12
# fear        35
# surprise     3
# Name: count, dtype: int64), (23954, 0.21870977230108604, prediction
# sadness     12
# joy          7
# love         9
# anger       22
# fear        36
# surprise     4
# Name: count, dtype: int64), (21612, 0.20446507754952323, prediction
# sadness     17
# joy         12
# love        12
# anger       10
# fear        35
# surprise     4
# Name: count, dtype: int64), (21153, 0.17741486987318064, prediction
# sadness     22
# joy         14
# love        11
# anger       14
# fear        26
# surprise     3
# Name: count, dtype: int64), (19325, 0.18212493038529157, prediction
# sadness     13
# joy          7
# love        18
# anger       25
# fear        21
# surprise     6
# Name: count, dtype: int64), (6146, 0.15810541970133096, prediction
# sadness      8
# joy          9
# love        15
# anger       23
# fear        33
# surprise     2
# Name: count, dtype: int64), (21826, 0.08972413430282046, prediction
# sadness     10
# joy         17
# love        26
# anger       15
# fear        21
# surprise     1
# Name: count, dtype: int64)], 'surprise': [(12718, 0.13416537701498896, sadness     21
# joy          6
# love        20
# anger       15
# fear        28
# surprise     0
# dtype: int64), (23779, 0.12710266798430048, prediction
# sadness     20
# joy         13
# love        16
# anger       15
# fear        24
# surprise     2
# Name: count, dtype: int64), (18239, 0.16071803180768252, prediction
# sadness     12
# joy         11
# love        13
# anger       25
# fear        25
# surprise     4
# Name: count, dtype: int64), (666, 0.2108046697841588, prediction
# sadness     13
# joy         20
# love        19
# anger       12
# fear        17
# surprise     9
# Name: count, dtype: int64), (487, 0.18866341894128533, prediction
# sadness     22
# joy          9
# love        16
# anger       11
# fear        28
# surprise     4
# Name: count, dtype: int64), (16125, 0.1348201786607814, prediction
# sadness     15
# joy         18
# love        25
# anger       10
# fear        20
# surprise     2
# Name: count, dtype: int64), (8551, 0.20232879191370465, sadness     24
# joy          6
# love         8
# anger       25
# fear        27
# surprise     0
# dtype: int64), (2037, 0.17075092904047154, prediction
# sadness     22
# joy         18
# love        13
# anger       13
# fear        21
# surprise     3
# Name: count, dtype: int64)]}, 'layer_2': {'sadness': [(11683, 0.18288312550051153, prediction
# sadness     26
# joy          4
# love        23
# anger       17
# fear        19
# surprise     1
# Name: count, dtype: int64), (14915, 0.16149375852957368, sadness     27
# joy          9
# love        25
# anger       17
# fear        12
# surprise     0
# dtype: int64), (11568, 0.2203278271868371, prediction
# sadness     30
# joy         12
# love        24
# anger       14
# fear         8
# surprise     2
# Name: count, dtype: int64), (4350, 0.13451426945535958, prediction
# sadness     20
# joy         10
# love        21
# anger       22
# fear        15
# surprise     2
# Name: count, dtype: int64), (2442, 0.16229211174682698, sadness     29
# joy         10
# love        19
# anger       19
# fear        13
# surprise     0
# dtype: int64)], 'joy': [(7796, 0.3280554046941551, prediction
# sadness      8
# joy         37
# love        29
# anger       11
# fear         2
# surprise     3
# Name: count, dtype: int64), (23405, 0.13324307980947211, prediction
# sadness     16
# joy         22
# love        18
# anger       15
# fear        17
# surprise     2
# Name: count, dtype: int64), (22134, 0.23194019703137003, prediction
# sadness     16
# joy         32
# love        13
# anger       12
# fear        13
# surprise     4
# Name: count, dtype: int64), (3456, 0.18194212211203364, prediction
# sadness      6
# joy         27
# love        21
# anger       16
# fear        17
# surprise     3
# Name: count, dtype: int64), (13928, 0.25528859435020607, prediction
# sadness     15
# joy         36
# love        19
# anger       11
# fear         7
# surprise     2
# Name: count, dtype: int64), (3879, 0.18607102962431007, prediction
# sadness     25
# joy         16
# love        26
# anger       13
# fear         9
# surprise     1
# Name: count, dtype: int64), (23476, 0.16649788789344752, prediction
# sadness     23
# joy         16
# love        24
# anger       10
# fear        15
# surprise     2
# Name: count, dtype: int64)], 'love': [(3203, 0.06027888853838009, sadness     12
# joy         15
# love        28
# anger       17
# fear        18
# surprise     0
# dtype: int64)], 'anger': [(11085, 0.09453583612394897, prediction
# sadness     15
# joy         12
# love        16
# anger       24
# fear        22
# surprise     1
# Name: count, dtype: int64), (21027, 0.17515186017637338, prediction
# sadness     16
# joy          7
# love        10
# anger       25
# fear        31
# surprise     1
# Name: count, dtype: int64), (14918, 0.24430572274676085, prediction
# sadness     15
# joy          4
# love         9
# anger       39
# fear        21
# surprise     2
# Name: count, dtype: int64), (252, 0.22524051371528178, prediction
# sadness     18
# joy          5
# love         8
# anger       35
# fear        23
# surprise     1
# Name: count, dtype: int64), (21165, 0.28194262377252444, prediction
# sadness     15
# joy          5
# love         5
# anger       45
# fear        19
# surprise     1
# Name: count, dtype: int64), (4707, 0.30900834986900055, sadness      9
# joy          4
# love         7
# anger       55
# fear        15
# surprise     0
# dtype: int64), (1550, 0.34612922405206753, prediction
# sadness     14
# joy          2
# love         6
# anger       54
# fear        12
# surprise     2
# Name: count, dtype: int64), (5526, 0.16481140532778676, prediction
# sadness      8
# joy          8
# love        19
# anger       25
# fear        26
# surprise     4
# Name: count, dtype: int64), (18357, 0.13394227614784612, prediction
# sadness     18
# joy         12
# love        13
# anger       23
# fear        22
# surprise     2
# Name: count, dtype: int64)], 'fear': [(24422, 0.1665347109642487, prediction
# sadness     19
# joy          8
# love        18
# anger       11
# fear        32
# surprise     2
# Name: count, dtype: int64), (22815, 0.23395851887914815, prediction
# sadness     23
# joy         19
# love        10
# anger       12
# fear        19
# surprise     7
# Name: count, dtype: int64), (21011, 0.2122548144576532, prediction
# sadness     12
# joy          7
# love         8
# anger       25
# fear        36
# surprise     2
# Name: count, dtype: int64), (20309, 0.232185855944547, prediction
# sadness     11
# joy          4
# love        12
# anger       20
# fear        39
# surprise     4
# Name: count, dtype: int64), (18350, 0.24478809947780053, prediction
# sadness     22
# joy         10
# love         7
# anger       10
# fear        39
# surprise     2
# Name: count, dtype: int64), (10882, 0.1938713958438832, prediction
# sadness     19
# joy          7
# love        13
# anger       18
# fear        28
# surprise     5
# Name: count, dtype: int64), (9937, 0.22986688732387012, prediction
# sadness     11
# joy          8
# love         6
# anger       30
# fear        33
# surprise     2
# Name: count, dtype: int64), (5843, 0.18178854499323677, prediction
# sadness     26
# joy          8
# love        13
# anger       13
# fear        29
# surprise     1
# Name: count, dtype: int64), (12026, 0.11412171445698596, prediction
# sadness     19
# joy          8
# love        18
# anger       20
# fear        24
# surprise     1
# Name: count, dtype: int64)], 'surprise': [(11631, 0.2329804491216918, sadness     22
# joy          3
# love         8
# anger       25
# fear        32
# surprise     0
# dtype: int64), (11365, 0.07630628065569636, sadness      9
# joy         12
# love        23
# anger       26
# fear        20
# surprise     0
# dtype: int64), (15076, 0.15642483000056617, prediction
# sadness     12
# joy         21
# love        22
# anger       12
# fear        19
# surprise     4
# Name: count, dtype: int64), (10353, 0.17422432490283835, prediction
# sadness     20
# joy         18
# love        25
# anger       12
# fear        12
# surprise     3
# Name: count, dtype: int64), (7902, 0.16079777682923022, prediction
# sadness      7
# joy         23
# love        28
# anger       13
# fear        17
# surprise     2
# Name: count, dtype: int64), (7800, 0.1714997733953463, prediction
# sadness     21
# joy         19
# love        21
# anger       14
# fear        12
# surprise     3
# Name: count, dtype: int64)]}, 'layer_3': {'sadness': [(24140, 0.1257371233753519, prediction
# sadness     18
# joy         10
# love        30
# anger       16
# fear        15
# surprise     1
# Name: count, dtype: int64), (24469, 0.1766487911161029, prediction
# sadness     24
# joy          9
# love        28
# anger        8
# fear        20
# surprise     1
# Name: count, dtype: int64), (22098, 0.2601641844964492, sadness     41
# joy         14
# love        15
# anger       11
# fear         9
# surprise     0
# dtype: int64), (14290, 0.19697858945091754, prediction
# sadness     33
# joy          9
# love        18
# anger       14
# fear        15
# surprise     1
# Name: count, dtype: int64)], 'joy': [(10739, 0.22349023186853242, prediction
# sadness      6
# joy         36
# love        22
# anger       12
# fear        13
# surprise     1
# Name: count, dtype: int64), (9828, 0.22877525786324285, prediction
# sadness     15
# joy         33
# love        17
# anger        9
# fear        13
# surprise     3
# Name: count, dtype: int64), (14625, 0.10174850753418042, sadness     22
# joy         15
# love        16
# anger       19
# fear        18
# surprise     0
# dtype: int64), (5329, 0.10808541527677985, prediction
# sadness     15
# joy         20
# love        23
# anger       16
# fear        15
# surprise     1
# Name: count, dtype: int64), (19341, 0.1432442305420153, prediction
# sadness     19
# joy          9
# love        16
# anger       15
# fear        29
# surprise     2
# Name: count, dtype: int64), (10990, 0.21764690110298945, sadness     17
# joy         35
# love        17
# anger       10
# fear        11
# surprise     0
# dtype: int64), (6001, 0.23633745508312493, prediction
# sadness     24
# joy         28
# love        15
# anger       13
# fear         8
# surprise     2
# Name: count, dtype: int64)], 'love': [(14981, 0.18431240618932873, prediction
# sadness     12
# joy          9
# love        30
# anger       10
# fear        24
# surprise     5
# Name: count, dtype: int64), (5501, 0.097331331806785, prediction
# sadness     18
# joy         10
# love        25
# anger       16
# fear        20
# surprise     1
# Name: count, dtype: int64), (15927, 0.19615234325592845, prediction
# sadness     16
# joy         15
# love        34
# anger       13
# fear         9
# surprise     3
# Name: count, dtype: int64), (11815, 0.16877177972017013, prediction
# sadness     16
# joy         14
# love        35
# anger        8
# fear        16
# surprise     1
# Name: count, dtype: int64), (23271, 0.16186900169491464, prediction
# sadness     11
# joy         12
# love        39
# anger       13
# fear        14
# surprise     1
# Name: count, dtype: int64)], 'anger': [(13819, 0.2443315307666106, prediction
# sadness     22
# joy          6
# love         8
# anger       36
# fear        16
# surprise     2
# Name: count, dtype: int64), (9272, 0.16867052607768768, prediction
# sadness     10
# joy          9
# love        18
# anger       27
# fear        21
# surprise     5
# Name: count, dtype: int64), (412, 0.2406895882654526, prediction
# sadness     11
# joy          3
# love        10
# anger       38
# fear        27
# surprise     1
# Name: count, dtype: int64), (3213, 0.18508138968740956, prediction
# sadness     18
# joy          8
# love        10
# anger       24
# fear        27
# surprise     3
# Name: count, dtype: int64), (16043, 0.22279754203265567, sadness     15
# joy          5
# love         9
# anger       40
# fear        21
# surprise     0
# dtype: int64), (24133, 0.14747709043619833, prediction
# sadness     17
# joy          6
# love        15
# anger       26
# fear        25
# surprise     1
# Name: count, dtype: int64)], 'fear': [(6134, 0.22417825117831253, prediction
# sadness     19
# joy          6
# love         9
# anger       15
# fear        39
# surprise     2
# Name: count, dtype: int64), (1861, 0.24047093479896378, prediction
# sadness     16
# joy          9
# love        14
# anger        6
# fear        42
# surprise     3
# Name: count, dtype: int64), (22236, 0.18737296600710748, prediction
# sadness     13
# joy         10
# love        15
# anger       11
# fear        38
# surprise     3
# Name: count, dtype: int64), (8135, 0.19080762376270943, prediction
# sadness     28
# joy          6
# love        17
# anger       14
# fear        23
# surprise     2
# Name: count, dtype: int64), (20126, 0.09994397228071417, prediction
# sadness     14
# joy         14
# love        16
# anger       16
# fear        29
# surprise     1
# Name: count, dtype: int64), (20648, 0.06629577933461947, sadness     17
# joy         11
# love        20
# anger       16
# fear        26
# surprise     0
# dtype: int64), (2253, 0.21620802845910125, prediction
# sadness     30
# joy         11
# love        10
# anger       10
# fear        28
# surprise     1
# Name: count, dtype: int64), (20588, 0.16496866494641058, prediction
# sadness     13
# joy         10
# love        11
# anger       20
# fear        34
# surprise     2
# Name: count, dtype: int64), (18762, 0.18819929065495644, prediction
# sadness     18
# joy          6
# love        15
# anger       13
# fear        36
# surprise     2
# Name: count, dtype: int64), (9805, 0.1844647870497418, prediction
# sadness     12
# joy          6
# love        16
# anger       14
# fear        41
# surprise     1
# Name: count, dtype: int64), (8914, 0.223454093607088, prediction
# sadness      8
# joy          5
# love        14
# anger       18
# fear        42
# surprise     3
# Name: count, dtype: int64), (6653, 0.22046828332661766, prediction
# sadness      7
# joy          8
# love        11
# anger       18
# fear        44
# surprise     2
# Name: count, dtype: int64)], 'surprise': [(3282, 0.16515918124316312, prediction
# sadness     21
# joy         17
# love        19
# anger        8
# fear        23
# surprise     2
# Name: count, dtype: int64), (23140, 0.127797749125605, sadness     20
# joy         13
# love        30
# anger       11
# fear        16
# surprise     0
# dtype: int64), (10647, 0.12334460708634097, prediction
# sadness     18
# joy         12
# love        19
# anger       17
# fear        21
# surprise     3
# Name: count, dtype: int64), (972, 0.10184855777965116, prediction
# sadness     11
# joy         13
# love        27
# anger       18
# fear        19
# surprise     2
# Name: count, dtype: int64), (17827, 0.14556787746460825, prediction
# sadness     21
# joy         13
# love        18
# anger       13
# fear        22
# surprise     3
# Name: count, dtype: int64), (3625, 0.1574997580470451, prediction
# sadness     13
# joy         23
# love        18
# anger       11
# fear        22
# surprise     3
# Name: count, dtype: int64), (17365, 0.1894462436072316, prediction
# sadness     22
# joy         16
# love        15
# anger       11
# fear        21
# surprise     5
# Name: count, dtype: int64), (14434, 0.157565280417881, prediction
# sadness     18
# joy         21
# love        20
# anger       13
# fear        15
# surprise     3
# Name: count, dtype: int64), (10958, 0.16725060448744755, prediction
# sadness     23
# joy         12
# love        11
# anger       16
# fear        26
# surprise     2
# Name: count, dtype: int64)]}, 'layer_4': {'sadness': [(5179, 0.22949008993453504, prediction
# sadness     21
# joy          8
# love        15
# anger       37
# fear         8
# surprise     1
# Name: count, dtype: int64), (7494, 0.14379286974109426, prediction
# sadness     18
# joy         11
# love        14
# anger       15
# fear        30
# surprise     2
# Name: count, dtype: int64), (9341, 0.20527931132298738, prediction
# sadness     33
# joy          8
# love        16
# anger       11
# fear        21
# surprise     1
# Name: count, dtype: int64), (22033, 0.14916173275257819, prediction
# sadness     13
# joy         12
# love        29
# anger       23
# fear        11
# surprise     2
# Name: count, dtype: int64), (23292, 0.18776386360004776, prediction
# sadness     31
# joy         12
# love        20
# anger       13
# fear        13
# surprise     1
# Name: count, dtype: int64), (10051, 0.267479696816989, prediction
# sadness     39
# joy          8
# love        13
# anger       16
# fear        11
# surprise     3
# Name: count, dtype: int64)], 'joy': [(15968, 0.14508173270367525, prediction
# sadness     21
# joy          9
# love        15
# anger       23
# fear        20
# surprise     2
# Name: count, dtype: int64), (12298, 0.1098071713286312, sadness     10
# joy         23
# love        26
# anger       14
# fear        17
# surprise     0
# dtype: int64), (9569, 0.15648128979613582, prediction
# sadness     24
# joy         20
# love        16
# anger       14
# fear        15
# surprise     1
# Name: count, dtype: int64), (8244, 0.19082883544373383, prediction
# sadness     14
# joy         29
# love        17
# anger       12
# fear        15
# surprise     3
# Name: count, dtype: int64), (22722, 0.1856370388894728, prediction
# sadness     21
# joy         14
# love        20
# anger       14
# fear        15
# surprise     6
# Name: count, dtype: int64)], 'love': [(9757, 0.18445212262513774, prediction
# sadness      7
# joy         12
# love        41
# anger       10
# fear        19
# surprise     1
# Name: count, dtype: int64), (10750, 0.1617494319751448, prediction
# sadness     12
# joy         18
# love        35
# anger       11
# fear        13
# surprise     1
# Name: count, dtype: int64), (4004, 0.05154138804674101, sadness     12
# joy         18
# love        20
# anger       21
# fear        19
# surprise     0
# dtype: int64), (7249, 0.11740802886525253, prediction
# sadness     15
# joy         15
# love        22
# anger       22
# fear        14
# surprise     2
# Name: count, dtype: int64)], 'anger': [(22695, 0.07905959013584256, sadness     20
# joy         14
# love        17
# anger       17
# fear        22
# surprise     0
# dtype: int64), (9072, 0.2643428752923344, sadness     15
# joy          5
# love        12
# anger       48
# fear        10
# surprise     0
# dtype: int64), (18320, 0.19418824676470436, sadness     21
# joy          4
# love        17
# anger       33
# fear        15
# surprise     0
# dtype: int64), (11510, 0.2319774308234038, prediction
# sadness     15
# joy          3
# love        12
# anger       39
# fear        20
# surprise     1
# Name: count, dtype: int64), (3810, 0.17468060760851534, prediction
# sadness     20
# joy          6
# love        16
# anger       31
# fear        16
# surprise     1
# Name: count, dtype: int64), (16080, 0.1228492528502746, prediction
# sadness     16
# joy          8
# love        18
# anger       21
# fear        25
# surprise     2
# Name: count, dtype: int64), (15004, 0.12220337825291473, prediction
# sadness     17
# joy          8
# love        19
# anger       19
# fear        25
# surprise     2
# Name: count, dtype: int64), (11183, 0.12425918168788291, prediction
# sadness     15
# joy          8
# love        23
# anger       27
# fear        16
# surprise     1
# Name: count, dtype: int64)], 'fear': [(20655, 0.17008409518390202, prediction
# sadness     22
# joy         14
# love        12
# anger       12
# fear        28
# surprise     2
# Name: count, dtype: int64), (18321, 0.11297895282129683, prediction
# sadness     11
# joy          9
# love        21
# anger       20
# fear        27
# surprise     2
# Name: count, dtype: int64), (13386, 0.16543140506684417, prediction
# sadness     24
# joy         12
# love        12
# anger       22
# fear        18
# surprise     2
# Name: count, dtype: int64), (4338, 0.13847425738907143, prediction
# sadness     15
# joy          9
# love        21
# anger       14
# fear        28
# surprise     3
# Name: count, dtype: int64), (2955, 0.21634675346997106, prediction
# sadness     11
# joy          8
# love        15
# anger        9
# fear        46
# surprise     1
# Name: count, dtype: int64), (24553, 0.2178672759315262, prediction
# sadness     10
# joy          7
# love         9
# anger       21
# fear        41
# surprise     2
# Name: count, dtype: int64), (16651, 0.13940302154319323, prediction
# sadness     16
# joy          9
# love        13
# anger       19
# fear        32
# surprise     1
# Name: count, dtype: int64), (15882, 0.17628564354190945, prediction
# sadness     22
# joy         12
# love        14
# anger        9
# fear        32
# surprise     1
# Name: count, dtype: int64), (14836, 0.15460483691217816, prediction
# sadness     11
# joy          6
# love        20
# anger       23
# fear        27
# surprise     3
# Name: count, dtype: int64), (12290, 0.16285580385573362, prediction
# sadness     15
# joy          5
# love        19
# anger       17
# fear        32
# surprise     2
# Name: count, dtype: int64)], 'surprise': [(19514, 0.12334488884286635, prediction
# sadness     19
# joy          7
# love        19
# anger       18
# fear        26
# surprise     1
# Name: count, dtype: int64), (15250, 0.05236078783066686, sadness     17
# joy         13
# love        19
# anger       21
# fear        20
# surprise     0
# dtype: int64), (19967, 0.17022373264269672, prediction
# sadness     12
# joy         26
# love        21
# anger       14
# fear        14
# surprise     3
# Name: count, dtype: int64), (16649, 0.17439273230947605, prediction
# sadness     17
# joy          7
# love        13
# anger       19
# fear        31
# surprise     3
# Name: count, dtype: int64), (24019, 0.13462752661035873, sadness     25
# joy         13
# love        16
# anger       12
# fear        24
# surprise     0
# dtype: int64), (12758, 0.11079954873476164, prediction
# sadness      9
# joy         16
# love        18
# anger       23
# fear        22
# surprise     2
# Name: count, dtype: int64), (9661, 0.12929879524984123, prediction
# sadness     11
# joy         12
# love        32
# anger       17
# fear        16
# surprise     2
# Name: count, dtype: int64)]}, 'layer_5': {'sadness': [(1265, 0.19453646600670982, prediction
# sadness     27
# joy          7
# love        10
# anger       22
# fear        23
# surprise     1
# Name: count, dtype: int64), (22889, 0.27769851609489854, prediction
# sadness     40
# joy          5
# love        16
# anger       10
# fear        16
# surprise     3
# Name: count, dtype: int64)], 'joy': [(6803, 0.17015304608886075, prediction
# sadness     13
# joy         24
# love        19
# anger       12
# fear        18
# surprise     4
# Name: count, dtype: int64), (17170, 0.11826608629670958, prediction
# sadness     16
# joy         16
# love        22
# anger       20
# fear        14
# surprise     2
# Name: count, dtype: int64), (14404, 0.13943620053025704, prediction
# sadness     21
# joy         20
# love        20
# anger       14
# fear        14
# surprise     1
# Name: count, dtype: int64), (1255, 0.19434322029632944, prediction
# sadness      9
# joy         21
# love        32
# anger       18
# fear         8
# surprise     2
# Name: count, dtype: int64), (13678, 0.23980841654807478, prediction
# sadness     17
# joy         26
# love        18
# anger        8
# fear        14
# surprise     7
# Name: count, dtype: int64), (14997, 0.22858917818600083, prediction
# sadness     11
# joy         30
# love        24
# anger       17
# fear         6
# surprise     2
# Name: count, dtype: int64)], 'love': [(23060, 0.10242182289993403, prediction
# sadness     14
# joy         13
# love        28
# anger       12
# fear        22
# surprise     1
# Name: count, dtype: int64), (12473, 0.09365868059334888, prediction
# sadness     11
# joy         10
# love        26
# anger       23
# fear        19
# surprise     1
# Name: count, dtype: int64), (3674, 0.14856704087554623, prediction
# sadness     21
# joy          8
# love        20
# anger       17
# fear        21
# surprise     3
# Name: count, dtype: int64), (18288, 0.15939395557265762, sadness     19
# joy         12
# love        35
# anger       13
# fear        11
# surprise     0
# dtype: int64), (13689, 0.17345066644113222, prediction
# sadness     16
# joy         14
# love        32
# anger       14
# fear        11
# surprise     3
# Name: count, dtype: int64), (4600, 0.15616637921313917, prediction
# sadness     10
# joy         15
# love        37
# anger       11
# fear        16
# surprise     1
# Name: count, dtype: int64), (3448, 0.08990880317346749, prediction
# sadness     15
# joy          9
# love        24
# anger       17
# fear        24
# surprise     1
# Name: count, dtype: int64)], 'anger': [(1773, 0.211944916077296, sadness     19
# joy          3
# love        17
# anger       36
# fear        15
# surprise     0
# dtype: int64), (330, 0.10597102334024319, prediction
# sadness     19
# joy         15
# love        17
# anger       14
# fear        24
# surprise     1
# Name: count, dtype: int64), (5136, 0.1191946171012156, prediction
# sadness     12
# joy         10
# love        17
# anger       20
# fear        29
# surprise     2
# Name: count, dtype: int64), (9706, 0.30789326924260346, prediction
# sadness     11
# joy          3
# love         6
# anger       47
# fear        20
# surprise     3
# Name: count, dtype: int64), (9559, 0.19417217241520002, prediction
# sadness     20
# joy          5
# love        17
# anger       33
# fear        14
# surprise     1
# Name: count, dtype: int64)], 'fear': [(7952, 0.15887520777010986, prediction
# sadness     20
# joy          7
# love        23
# anger       10
# fear        29
# surprise     1
# Name: count, dtype: int64), (15844, 0.13471841244430025, prediction
# sadness     13
# joy          6
# love        18
# anger       22
# fear        30
# surprise     1
# Name: count, dtype: int64), (6801, 0.11108475390706744, prediction
# sadness     17
# joy         12
# love        29
# anger       14
# fear        17
# surprise     1
# Name: count, dtype: int64), (21689, 0.18137646319650164, prediction
# sadness     13
# joy         15
# love        13
# anger       10
# fear        37
# surprise     2
# Name: count, dtype: int64), (24318, 0.18008134959328012, prediction
# sadness     11
# joy          7
# love        17
# anger       15
# fear        37
# surprise     3
# Name: count, dtype: int64), (2212, 0.19040665884804955, prediction
# sadness     19
# joy         10
# love        13
# anger       11
# fear        34
# surprise     3
# Name: count, dtype: int64), (5990, 0.14174967607433395, prediction
# sadness     23
# joy          7
# love        20
# anger       15
# fear        24
# surprise     1
# Name: count, dtype: int64), (15747, 0.09528125850013372, prediction
# sadness     15
# joy         13
# love        28
# anger       14
# fear        19
# surprise     1
# Name: count, dtype: int64)], 'surprise': [(21258, 0.10759848327035339, prediction
# sadness     13
# joy         13
# love        16
# anger       16
# fear        31
# surprise     1
# Name: count, dtype: int64), (14750, 0.1296863783861365, sadness     23
# joy          7
# love        17
# anger       18
# fear        25
# surprise     0
# dtype: int64), (2877, 0.15862788134071437, prediction
# sadness     21
# joy         14
# love        18
# anger        9
# fear        26
# surprise     2
# Name: count, dtype: int64), (3055, 0.14100117479727683, prediction
# sadness     23
# joy         10
# love        22
# anger       16
# fear        17
# surprise     2
# Name: count, dtype: int64), (17557, 0.1142447197585021, prediction
# sadness     13
# joy         12
# love        16
# anger       25
# fear        22
# surprise     2
# Name: count, dtype: int64), (23920, 0.14943582986648796, prediction
# sadness     12
# joy         16
# love        28
# anger       19
# fear        12
# surprise     3
# Name: count, dtype: int64), (3546, 0.1188650436757739, prediction
# sadness     14
# joy         15
# love        31
# anger       14
# fear        15
# surprise     1
# Name: count, dtype: int64), (16559, 0.1717985745510197, prediction
# sadness     16
# joy         23
# love        20
# anger       17
# fear        11
# surprise     3
# Name: count, dtype: int64), (9884, 0.19610080045972636, prediction
# sadness     19
# joy         18
# love        17
# anger        8
# fear        23
# surprise     5
# Name: count, dtype: int64), (7516, 0.13460388483609212, prediction
# sadness     14
# joy         12
# love        29
# anger       16
# fear        16
# surprise     3
# Name: count, dtype: int64), (6011, 0.09010337827777035, prediction
# sadness     17
# joy         12
# love        24
# anger       14
# fear        22
# surprise     1
# Name: count, dtype: int64)]}, 'layer_6': {'sadness': [(20719, 0.20589487553563351, sadness     31
# joy          6
# love        26
# anger        9
# fear        18
# surprise     0
# dtype: int64), (251, 0.21789103112939906, prediction
# sadness     33
# joy          7
# love        21
# anger       13
# fear        14
# surprise     2
# Name: count, dtype: int64)], 'joy': [(9995, 0.19237168110287758, prediction
# sadness     11
# joy         26
# love        31
# anger       10
# fear        11
# surprise     1
# Name: count, dtype: int64), (3020, 0.1401032014345676, prediction
# sadness     24
# joy         12
# love        21
# anger       11
# fear        21
# surprise     1
# Name: count, dtype: int64), (18199, 0.222157067831931, prediction
# sadness     12
# joy         28
# love        25
# anger       15
# fear         7
# surprise     3
# Name: count, dtype: int64), (14968, 0.3451042790526257, prediction
# sadness     11
# joy         48
# love        15
# anger        2
# fear        12
# surprise     2
# Name: count, dtype: int64), (203, 0.16035764009347828, prediction
# sadness      8
# joy         25
# love        28
# anger       11
# fear        17
# surprise     1
# Name: count, dtype: int64), (2617, 0.0747029079247618, sadness     15
# joy         10
# love        26
# anger       22
# fear        17
# surprise     0
# dtype: int64)], 'love': [(19727, 0.16464523735786024, prediction
# sadness     15
# joy         16
# love        33
# anger       16
# fear         9
# surprise     1
# Name: count, dtype: int64), (16022, 0.23750714211642548, prediction
# sadness     17
# joy         20
# love        32
# anger       13
# fear         5
# surprise     3
# Name: count, dtype: int64), (11397, 0.19296213800887332, prediction
# sadness     10
# joy         15
# love        38
# anger       11
# fear        13
# surprise     3
# Name: count, dtype: int64), (14808, 0.11447201643877725, prediction
# sadness     18
# joy          8
# love        27
# anger       16
# fear        20
# surprise     1
# Name: count, dtype: int64)], 'anger': [(20521, 0.19215504313666654, sadness     23
# joy          5
# love        10
# anger       26
# fear        26
# surprise     0
# dtype: int64), (16530, 0.22614972364580602, prediction
# sadness     23
# joy          2
# love        14
# anger       25
# fear        24
# surprise     2
# Name: count, dtype: int64), (10131, 0.157686662697713, prediction
# sadness     19
# joy          6
# love        17
# anger       29
# fear        18
# surprise     1
# Name: count, dtype: int64), (6415, 0.20708119286653354, sadness     20
# joy          9
# love         9
# anger       37
# fear        15
# surprise     0
# dtype: int64), (15780, 0.1352582862796114, prediction
# sadness     17
# joy          6
# love        17
# anger       22
# fear        27
# surprise     1
# Name: count, dtype: int64), (21846, 0.12912175073970963, prediction
# sadness     16
# joy         10
# love        17
# anger       22
# fear        22
# surprise     3
# Name: count, dtype: int64)], 'fear': [(3246, 0.15489095081404952, prediction
# sadness     11
# joy          5
# love        18
# anger       23
# fear        32
# surprise     1
# Name: count, dtype: int64), (5289, 0.13279601907512972, prediction
# sadness     21
# joy         11
# love        13
# anger       18
# fear        26
# surprise     1
# Name: count, dtype: int64), (12900, 0.07199000739155295, prediction
# sadness     12
# joy         14
# love        22
# anger       22
# fear        19
# surprise     1
# Name: count, dtype: int64), (20520, 0.14865856441887337, prediction
# sadness     11
# joy          9
# love        18
# anger       20
# fear        28
# surprise     4
# Name: count, dtype: int64), (18781, 0.0993130725560142, prediction
# sadness     16
# joy          9
# love        19
# anger       18
# fear        27
# surprise     1
# Name: count, dtype: int64), (2459, 0.14447586133866644, prediction
# sadness     19
# joy         10
# love        15
# anger       13
# fear        32
# surprise     1
# Name: count, dtype: int64), (20211, 0.17998513416899595, prediction
# sadness      9
# joy          9
# love        15
# anger       14
# fear        42
# surprise     1
# Name: count, dtype: int64), (19068, 0.25387223668137177, prediction
# sadness     11
# joy          5
# love         6
# anger       24
# fear        43
# surprise     1
# Name: count, dtype: int64), (6685, 0.189278639430555, prediction
# sadness     22
# joy          8
# love         9
# anger       18
# fear        32
# surprise     1
# Name: count, dtype: int64), (2260, 0.12344586945094813, sadness     13
# joy         10
# love        17
# anger       14
# fear        36
# surprise     0
# dtype: int64)], 'surprise': [(13502, 0.09468507744126366, prediction
# sadness     14
# joy         14
# love        24
# anger       17
# fear        19
# surprise     2
# Name: count, dtype: int64), (18954, 0.1422458084837898, prediction
# sadness     20
# joy         10
# love        18
# anger       15
# fear        24
# surprise     3
# Name: count, dtype: int64), (14477, 0.13694069503913958, sadness     11
# joy         11
# love        37
# anger       18
# fear        13
# surprise     0
# dtype: int64), (6315, 0.1484694200025264, prediction
# sadness      8
# joy         15
# love        17
# anger       19
# fear        27
# surprise     4
# Name: count, dtype: int64), (9678, 0.15459659294445982, prediction
# sadness     22
# joy          5
# love        19
# anger       18
# fear        25
# surprise     1
# Name: count, dtype: int64), (2328, 0.1699830916697447, prediction
# sadness     15
# joy         12
# love        26
# anger       10
# fear        22
# surprise     5
# Name: count, dtype: int64), (21364, 0.13516811724378883, prediction
# sadness     11
# joy         10
# love        31
# anger       21
# fear        15
# surprise     2
# Name: count, dtype: int64), (17678, 0.13411359233402356, prediction
# sadness     13
# joy         18
# love        23
# anger       19
# fear        14
# surprise     3
# Name: count, dtype: int64), (9978, 0.1238066947997609, prediction
# sadness     18
# joy         15
# love        24
# anger       12
# fear        19
# surprise     2
# Name: count, dtype: int64), (19798, 0.17895387380572825, prediction
# sadness     22
# joy          9
# love        18
# anger       14
# fear        22
# surprise     5
# Name: count, dtype: int64), (3036, 0.16054543914303765, prediction
# sadness     17
# joy          6
# love        23
# anger       14
# fear        27
# surprise     3
# Name: count, dtype: int64)]}, 'layer_7': {'sadness': [(2045, 0.1816933278446553, prediction
# sadness     28
# joy          8
# love        19
# anger       12
# fear        21
# surprise     2
# Name: count, dtype: int64)], 'joy': [(24314, 0.10322832911305253, prediction
# sadness     17
# joy         14
# love        14
# anger       21
# fear        23
# surprise     1
# Name: count, dtype: int64), (17025, 0.14576328797379745, prediction
# sadness     22
# joy         12
# love        17
# anger       16
# fear        20
# surprise     3
# Name: count, dtype: int64), (19547, 0.15277555903736464, prediction
# sadness     13
# joy         25
# love        23
# anger       17
# fear        11
# surprise     1
# Name: count, dtype: int64)], 'love': [(2887, 0.1594637390071327, prediction
# sadness      6
# joy         18
# love        28
# anger       13
# fear        22
# surprise     3
# Name: count, dtype: int64), (2715, 0.14836861457648676, prediction
# sadness     16
# joy         16
# love        30
# anger       13
# fear        13
# surprise     2
# Name: count, dtype: int64), (19662, 0.19744983004107866, prediction
# sadness     28
# joy          6
# love        18
# anger       15
# fear        20
# surprise     3
# Name: count, dtype: int64)], 'anger': [(1776, 0.1421947037282029, prediction
# sadness     17
# joy          9
# love        16
# anger       18
# fear        27
# surprise     3
# Name: count, dtype: int64), (10033, 0.15067581021454782, prediction
# sadness     13
# joy         12
# love        17
# anger       17
# fear        26
# surprise     5
# Name: count, dtype: int64)], 'fear': [(18892, 0.16522442677594373, prediction
# sadness     12
# joy         10
# love        13
# anger       18
# fear        34
# surprise     3
# Name: count, dtype: int64), (13863, 0.11332343324519877, prediction
# sadness     13
# joy         16
# love        22
# anger       17
# fear        19
# surprise     3
# Name: count, dtype: int64), (17128, 0.11361428658693704, prediction
# sadness     20
# joy          9
# love        19
# anger       16
# fear        25
# surprise     1
# Name: count, dtype: int64), (13519, 0.1331951939905063, prediction
# sadness     12
# joy          6
# love        23
# anger       17
# fear        31
# surprise     1
# Name: count, dtype: int64), (4505, 0.185398448573516, prediction
# sadness     15
# joy          8
# love        17
# anger       10
# fear        38
# surprise     2
# Name: count, dtype: int64), (5211, 0.18788495838167726, prediction
# sadness      7
# joy         13
# love        13
# anger       14
# fear        42
# surprise     1
# Name: count, dtype: int64), (17463, 0.12779852261042185, prediction
# sadness     15
# joy          6
# love        29
# anger       19
# fear        20
# surprise     1
# Name: count, dtype: int64), (19010, 0.15065162815596286, prediction
# sadness     10
# joy         10
# love        17
# anger       14
# fear        38
# surprise     1
# Name: count, dtype: int64), (15862, 0.14464340710076495, prediction
# sadness     20
# joy         12
# love        13
# anger       16
# fear        27
# surprise     2
# Name: count, dtype: int64), (14791, 0.1399635736741592, prediction
# sadness     20
# joy         10
# love        14
# anger       15
# fear        30
# surprise     1
# Name: count, dtype: int64)], 'surprise': [(17837, 0.1524801676123491, prediction
# sadness     19
# joy         11
# love        15
# anger       19
# fear        22
# surprise     4
# Name: count, dtype: int64), (20417, 0.13844080296817665, prediction
# sadness     22
# joy         13
# love        17
# anger       11
# fear        26
# surprise     1
# Name: count, dtype: int64), (17104, 0.16683080738248612, prediction
# sadness     24
# joy          8
# love        24
# anger       11
# fear        21
# surprise     2
# Name: count, dtype: int64), (12344, 0.06599386253936929, prediction
# sadness     14
# joy         14
# love        23
# anger       18
# fear        20
# surprise     1
# Name: count, dtype: int64), (8002, 0.11094407568325328, prediction
# sadness     15
# joy          8
# love        21
# anger       16
# fear        29
# surprise     1
# Name: count, dtype: int64), (10849, 0.16673110607560357, prediction
# sadness     19
# joy         10
# love        10
# anger       21
# fear        28
# surprise     2
# Name: count, dtype: int64), (15668, 0.16399837485586305, prediction
# sadness     13
# joy          9
# love        19
# anger       15
# fear        29
# surprise     5
# Name: count, dtype: int64), (11750, 0.12641685121877114, prediction
# sadness     20
# joy         16
# love        16
# anger       12
# fear        25
# surprise     1
# Name: count, dtype: int64), (8981, 0.12991451926557568, prediction
# sadness     21
# joy         14
# love        22
# anger       14
# fear        17
# surprise     2
# Name: count, dtype: int64), (8442, 0.09424001138587228, prediction
# sadness     14
# joy         15
# love        19
# anger       17
# fear        23
# surprise     2
# Name: count, dtype: int64)]}, 'layer_8': {'sadness': [(7473, 0.13639252906411858, prediction
# sadness     23
# joy          9
# love        25
# anger       16
# fear        16
# surprise     1
# Name: count, dtype: int64), (3927, 0.16919487427440322, prediction
# sadness     28
# joy          7
# love        17
# anger       16
# fear        21
# surprise     1
# Name: count, dtype: int64)], 'joy': [(13624, 0.10917725224380168, prediction
# sadness     15
# joy         17
# love        23
# anger       17
# fear        16
# surprise     2
# ...
# sadness     14
# joy         16
# love        22
# anger       21
# fear        16
# surprise     1
# Name: count, dtype: int64), (15950, 0.13085344483346517, prediction
# sadness     13
# joy         13
# love        21
# anger       15
# fear        24
# surprise     4
# Name: count, dtype: int64), (15512, 0.1387877619137877, prediction
# sadness     17
# joy         12
# love        17
# anger       12
# fear        30
# surprise     2
# Name: count, dtype: int64), (20821, 0.10247367790489512, prediction
# sadness     16
# joy         10
# love        22
# anger       18
# fear        22
# surprise     2
# Name: count, dtype: int64), (8855, 0.11334636004654328, prediction
# sadness     21
# joy          9
# love        19
# anger       19
# fear        21
# surprise     1
# Name: count, dtype: int64), (12456, 0.09681001504627487, prediction
# sadness     15
# joy         15
# love        18
# anger       19
# fear        21
# surprise     2
# Name: count, dtype: int64), (20423, 0.12490367160710278, prediction
# sadness     17
# joy         10
# love        15
# anger       22
# fear        24
# surprise     2
# Name: count, dtype: int64), (4939, 0.10637366363613898, prediction
# sadness     19
# joy         10
# love        17
# anger       22
# fear        21
# surprise     1
# Name: count, dtype: int64)]}, 'layer_9': {'sadness': [(10885, 0.12410766904810024, prediction
# sadness     15
# joy         13
# love        26
# anger       15
# fear        18
# surprise     3
# Name: count, dtype: int64), (17773, 0.12685119655211216, prediction
# sadness     23
# joy         11
# love        16
# anger       16
# fear        23
# surprise     1
# Name: count, dtype: int64), (5000, 0.13140300520756246, prediction
# sadness     19
# joy          6
# love        24
# anger       21
# fear        19
# surprise     1
# Name: count, dtype: int64)], 'joy': [(4288, 0.06522132417078134, prediction
# sadness     14
# joy         15
# love        21
# anger       18
# fear        21
# surprise     1
# Name: count, dtype: int64), (7702, 0.08010138754307301, prediction
# sadness     17
# joy         15
# love        21
# anger       17
# fear        19
# surprise     1
# Name: count, dtype: int64), (20850, 0.14580004797188587, prediction
# sadness     26
# joy          9
# love        18
# anger       16
# fear        20
# surprise     1
# Name: count, dtype: int64), (1418, 0.07475134533966858, prediction
# sadness     13
# joy         12
# love        25
# anger       16
# fear        23
# surprise     1
# Name: count, dtype: int64), (4864, 0.07843100671394485, sadness     18
# joy         16
# love        19
# anger       21
# fear        16
# surprise     0
# dtype: int64)], 'love': [(20105, 0.088690113388658, sadness     21
# joy         13
# love        18
# anger       15
# fear        23
# surprise     0
# dtype: int64), (9946, 0.05901899870629992, sadness     17
# joy         10
# love        23
# anger       18
# fear        22
# surprise     0
# dtype: int64), (17442, 0.10292618548164185, prediction
# sadness     19
# joy         14
# love        24
# anger       16
# fear        16
# surprise     1
# Name: count, dtype: int64), (21303, 0.11631832462827521, prediction
# sadness     20
# joy         12
# love        20
# anger       16
# fear        20
# surprise     2
# Name: count, dtype: int64), (21876, 0.0961950060322151, prediction
# sadness     13
# joy         14
# love        22
# anger       15
# fear        24
# surprise     2
# Name: count, dtype: int64)], 'anger': [(21253, 0.11751695160570039, prediction
# sadness     18
# joy          9
# love        20
# anger       17
# fear        24
# surprise     2
# Name: count, dtype: int64), (7002, 0.16748818534003712, prediction
# sadness     25
# joy          8
# love        16
# anger       22
# fear        17
# surprise     2
# Name: count, dtype: int64), (15510, 0.1361516444415053, prediction
# sadness     21
# joy         11
# love        21
# anger       12
# fear        23
# surprise     2
# Name: count, dtype: int64), (16663, 0.09422971113064055, prediction
# sadness     18
# joy         14
# love        16
# anger       20
# fear        21
# surprise     1
# Name: count, dtype: int64)], 'fear': [(20233, 0.09145474925238545, prediction
# sadness     13
# joy         16
# love        19
# anger       14
# fear        27
# surprise     1
# Name: count, dtype: int64), (19535, 0.08660989461348656, sadness     13
# joy         10
# love        21
# anger       15
# fear        31
# surprise     0
# dtype: int64), (5563, 0.0769076558500059, sadness     15
# joy         10
# love        20
# anger       16
# fear        29
# surprise     0
# dtype: int64), (1413, 0.14102861717297607, prediction
# sadness     18
# joy          7
# love        19
# anger       16
# fear        28
# surprise     2
# Name: count, dtype: int64), (15382, 0.10658072116774162, sadness     22
# joy         12
# love        17
# anger       14
# fear        25
# surprise     0
# dtype: int64), (14412, 0.1530686653214498, prediction
# sadness     17
# joy         12
# love        16
# anger       11
# fear        32
# surprise     2
# Name: count, dtype: int64)], 'surprise': [(21445, 0.16140109423494128, prediction
# sadness     17
# joy         10
# love        21
# anger       13
# fear        24
# surprise     5
# Name: count, dtype: int64), (21532, 0.09225356250834568, prediction
# sadness     13
# joy         12
# love        21
# anger       18
# fear        24
# surprise     2
# Name: count, dtype: int64), (10719, 0.07868326463493748, prediction
# sadness     15
# joy         15
# love        17
# anger       19
# fear        23
# surprise     1
# Name: count, dtype: int64), (14851, 0.10543817401633956, prediction
# sadness     20
# joy         10
# love        18
# anger       18
# fear        23
# surprise     1
# Name: count, dtype: int64), (24082, 0.06753663769876524, prediction
# sadness     13
# joy         16
# love        20
# anger       18
# fear        22
# surprise     1
# Name: count, dtype: int64), (16180, 0.044296873584812615, sadness     17
# joy         13
# love        21
# anger       17
# fear        22
# surprise     0
# dtype: int64), (1167, 0.07442318205784552, sadness     18
# joy         15
# love        16
# anger       17
# fear        24
# surprise     0
# dtype: int64), (14205, 0.07790514327946754, prediction
# sadness     16
# joy         12
# love        24
# anger       18
# fear        19
# surprise     1
# Name: count, dtype: int64), (7831, 0.11038046525434898, prediction
# sadness     18
# joy          9
# love        22
# anger       14
# fear        26
# surprise     1
# Name: count, dtype: int64), (17898, 0.11047079239616872, prediction
# sadness     18
# joy         11
# love        18
# anger       18
# fear        23
# surprise     2
# Name: count, dtype: int64), (1655, 0.01741687931252597, sadness     14
# joy         14
# love        21
# anger       20
# fear        21
# surprise     0
# dtype: int64)]}, 'layer_10': {'sadness': [(11363, 0.04366250496803034, sadness     16
# joy         12
# love        21
# anger       17
# fear        24
# surprise     0
# dtype: int64)], 'joy': [(4091, 0.06711558984663678, prediction
# sadness     12
# joy         14
# love        20
# anger       21
# fear        22
# surprise     1
# Name: count, dtype: int64), (5713, 0.1091407577196389, sadness     24
# joy         11
# love        18
# anger       17
# fear        20
# surprise     0
# dtype: int64), (809, 0.0440483073210979, sadness     16
# joy         15
# love        19
# anger       17
# fear        23
# surprise     0
# dtype: int64)], 'love': [(10165, 0.052237426976732, sadness     17
# joy         12
# love        20
# anger       17
# fear        24
# surprise     0
# dtype: int64), (14654, 0.09123938578262134, prediction
# sadness     18
# joy         11
# love        20
# anger       16
# fear        24
# surprise     1
# Name: count, dtype: int64), (20694, 0.09100396475508404, prediction
# sadness     16
# joy         10
# love        21
# anger       16
# fear        26
# surprise     1
# Name: count, dtype: int64), (19070, 0.0818915639712267, sadness     18
# joy         10
# love        24
# anger       14
# fear        24
# surprise     0
# dtype: int64), (130, 0.12027634124129509, prediction
# sadness     19
# joy         11
# love        20
# anger       14
# fear        24
# surprise     2
# Name: count, dtype: int64), (2095, 0.09036342723411336, sadness     21
# joy         13
# love        19
# anger       14
# fear        23
# surprise     0
# dtype: int64)], 'anger': [(14697, 0.07585957627923133, sadness     11
# joy         13
# love        16
# anger       24
# fear        26
# surprise     0
# dtype: int64), (5203, 0.04936924725514356, sadness     15
# joy         12
# love        19
# anger       18
# fear        26
# surprise     0
# dtype: int64), (19957, 0.07283682346054661, prediction
# sadness     14
# joy         16
# love        19
# anger       17
# fear        23
# surprise     1
# Name: count, dtype: int64)], 'fear': [(24358, 0.047442155661203675, sadness     11
# joy         13
# love        20
# anger       19
# fear        27
# surprise     0
# dtype: int64), (20305, 0.07971906922860944, prediction
# sadness     15
# joy         14
# love        20
# anger       15
# fear        25
# surprise     1
# Name: count, dtype: int64), (18367, 0.05370796547084912, sadness     16
# joy         11
# love        23
# anger       16
# fear        24
# surprise     0
# dtype: int64), (6822, 0.09396858580566318, prediction
# sadness     15
# joy         11
# love        20
# anger       15
# fear        28
# surprise     1
# Name: count, dtype: int64), (6260, 0.06915806529471231, sadness     14
# joy         12
# love        20
# anger       15
# fear        29
# surprise     0
# dtype: int64), (2783, 0.04552335672643904, sadness     15
# joy         12
# love        22
# anger       16
# fear        25
# surprise     0
# dtype: int64)], 'surprise': [(2150, 0.08358186668896679, prediction
# sadness     17
# joy         12
# love        20
# anger       16
# fear        24
# surprise     1
# Name: count, dtype: int64), (9733, 0.10961939021615949, prediction
# sadness     18
# joy         10
# love        21
# anger       18
# fear        21
# surprise     2
# Name: count, dtype: int64), (23922, 0.07535541382601882, prediction
# sadness     12
# joy         14
# love        18
# anger       20
# fear        25
# surprise     1
# Name: count, dtype: int64), (23723, 0.04715921453062784, sadness     17
# joy         13
# love        20
# anger       17
# fear        23
# surprise     0
# dtype: int64), (7658, 0.06916658468153175, sadness     16
# joy         14
# love        17
# anger       16
# fear        27
# surprise     0
# dtype: int64), (184, 0.05621042798783864, sadness     17
# joy         12
# love        18
# anger       20
# fear        23
# surprise     0
# dtype: int64), (18509, 0.08730540700595354, prediction
# sadness     17
# joy         12
# love        19
# anger       16
# fear        25
# surprise     1
# Name: count, dtype: int64), (20367, 0.08561788415784374, prediction
# sadness     16
# joy         11
# love        24
# anger       15
# fear        23
# surprise     1
# Name: count, dtype: int64), (14901, 0.041428054816818445, sadness     15
# joy         11
# love        22
# anger       18
# fear        24
# surprise     0
# dtype: int64), (6227, 0.03743871095643714, sadness     16
# joy         13
# love        21
# anger       17
# fear        23
# surprise     0
# dtype: int64)]}, 'layer_11': {'sadness': [(3334, 0.052237426976732, sadness     17
# joy         12
# love        20
# anger       17
# fear        24
# surprise     0
# dtype: int64), (24428, 0.03084274932724556, sadness     15
# joy         12
# love        21
# anger       19
# fear        23
# surprise     0
# dtype: int64), (16896, 0.0364857340802401, sadness     15
# joy         12
# love        20
# anger       19
# fear        24
# surprise     0
# dtype: int64)], 'joy': [(4943, 0.07187460409200887, prediction
# sadness     15
# joy         13
# love        20
# anger       17
# fear        24
# surprise     1
# Name: count, dtype: int64), (8946, 0.07941079774213403, prediction
# sadness     15
# joy         10
# love        23
# anger       20
# fear        21
# surprise     1
# Name: count, dtype: int64)], 'love': [(12316, 0.0723428235014457, sadness     17
# joy         11
# love        19
# anger       16
# fear        27
# surprise     0
# dtype: int64), (6390, 0.04929815897440885, sadness     17
# joy         13
# love        23
# anger       16
# fear        21
# surprise     0
# dtype: int64), (6694, 0.07383091933423432, prediction
# sadness     16
# joy         12
# love        22
# anger       17
# fear        22
# surprise     1
# Name: count, dtype: int64), (15057, 0.07591071124774335, sadness     19
# joy         11
# love        21
# anger       15
# fear        24
# surprise     0
# dtype: int64), (4407, 0.08783654287418464, prediction
# sadness     15
# joy         12
# love        22
# anger       14
# fear        26
# surprise     1
# Name: count, dtype: int64)], 'anger': [(21754, 0.0991235185169159, prediction
# sadness     14
# joy         11
# love        24
# anger       16
# fear        23
# surprise     2
# Name: count, dtype: int64), (12214, 0.018395601360860287, sadness     14
# joy         15
# love        21
# anger       18
# fear        22
# surprise     0
# dtype: int64), (8427, 0.024498503121305075, sadness     14
# joy         15
# love        20
# anger       18
# fear        23
# surprise     0
# dtype: int64), (20367, 0.054504696758014705, sadness     16
# joy         14
# love        20
# anger       15
# fear        25
# surprise     0
# dtype: int64), (14410, 0.07584894729278036, prediction
# sadness     14
# joy         11
# love        20
# anger       19
# fear        25
# surprise     1
# Name: count, dtype: int64)], 'fear': [(13374, 0.05106621132552304, sadness     13
# joy         14
# love        18
# anger       18
# fear        27
# surprise     0
# dtype: int64), (9550, 0.036339598958936556, sadness     14
# joy         14
# love        19
# anger       18
# fear        25
# surprise     0
# dtype: int64), (24256, 0.04264029264752792, sadness     14
# joy         13
# love        19
# anger       18
# fear        26
# surprise     0
# dtype: int64), (14324, 0.04942702464547207, sadness     14
# joy         13
# love        22
# anger       15
# fear        26
# surprise     0
# dtype: int64), (13554, 0.06993588498426953, prediction
# sadness     14
# joy         15
# love        23
# anger       16
# fear        21
# surprise     1
# Name: count, dtype: int64), (165, 0.050622515936510036, sadness     13
# joy         12
# love        22
# anger       16
# fear        27
# surprise     0
# dtype: int64), (12092, 0.05827607833723516, sadness     16
# joy         10
# love        21
# anger       18
# fear        25
# surprise     0
# dtype: int64), (9703, 0.04279116618405219, sadness     14
# joy         12
# love        21
# anger       17
# fear        26
# surprise     0
# dtype: int64), (20934, 0.0510238273242257, sadness     16
# joy         12
# love        21
# anger       16
# fear        25
# surprise     0
# dtype: int64)], 'surprise': [(22471, 0.07328401487159385, sadness     17
# joy          9
# love        22
# anger       17
# fear        25
# surprise     0
# dtype: int64), (5047, 0.06201864709476672, sadness     17
# joy         14
# love        18
# anger       16
# fear        25
# surprise     0
# dtype: int64), (22203, 0.021758644419822656, sadness     14
# joy         14
# love        23
# anger       17
# fear        22
# surprise     0
# dtype: int64), (17670, 0.07903803961681195, prediction
# sadness     16
# joy         13
# love        24
# anger       18
# fear        18
# surprise     1
# Name: count, dtype: int64), (17411, 0.07443448496772502, sadness     17
# joy         12
# love        24
# anger       13
# fear        24
# surprise     0
# dtype: int64), (17777, 0.09459006348336665, prediction
# sadness     18
# joy         12
# love        21
# anger       14
# fear        24
# surprise     1
# Name: count, dtype: int64), (5820, 0.026684841650294944, sadness     14
# joy         13
# love        20
# anger       19
# fear        24
# surprise     0
# dtype: int64), (949, 0.04915740113289864, sadness     16
# joy         11
# love        22
# anger       17
# fear        24
# surprise     0
# dtype: int64), (12189, 0.10030813468574619, prediction
# sadness     19
# joy         13
# love        19
# anger       14
# fear        24
# surprise     1
# Name: count, dtype: int64), (4452, 0.10293069690504054, prediction
# sadness     20
# joy         13
# love        18
# anger       15
# fear        23
# surprise     1
# Name: count, dtype: int64), (15556, 0.024564712000467115, sadness     14
# joy         13
# love        20
# anger       20
# fear        23
# surprise     0
# dtype: int64), (3086, 0.05886866140617843, sadness     17
# joy         12
# love        24
# anger       15
# fear        22
# surprise     0
# dtype: int64), (21799, 0.023762849652629116, sadness     15
# joy         13
# love        22
# anger       19
# fear        21
# surprise     0
# dtype: int64)]}}

# %%
with open(f'ablation_effect_all_layers.pkl', 'wb') as f:
    pickle.dump(ablation_effects, f)

with open(f'steer_20_effect_all_layers.pkl', 'wb') as f:
    pickle.dump(steer_20_effects, f)

# %%
with open(f'ablation_effect_all_layers.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)
    print(loaded_dict)
# Out:
# {'layer_0': {'sadness': [(12266, 0.05920798421448489), (23208, 0.092545568777795), (14158, 0.10598818985199403), (10882, 0.08441380089022585), (10510, 0.042430235470293294), (546, 0.09506236271362445)], 'joy': [(8699, 0.06013792769847593), (10924, 0.05442534221522403), (13808, 0.14422535808526082), (16670, 0.0972270243966704), (15464, 0.06801962236531685), (1432, 0.07907644240058859)], 'love': [(24486, 0.04199374843362757), (19618, 0.07785277366991186), (3970, 0.0738154339558306), (7792, 0.1090845437855492), (13985, 0.07359145043270564), (21219, 0.060694505838899786), (4892, 0.12055547402890134), (7099, 0.06485527517976264)], 'anger': [(22318, 0.07140873140508561), (13668, 0.11260909246796945), (17628, 0.136993132323818), (12030, 0.08207058533001868), (800, 0.1336924728991583), (22574, 0.06984331557150779)], 'fear': [(2998, 0.08669878258234977), (8167, 0.08839673501064112), (634, 0.10288922697877087), (22447, 0.10043814345398534), (15196, 0.10198877668693447), (8194, 0.1503271416717931), (2288, 0.10512030717921103), (13200, 0.04148056162429206), (23219, 0.102654977026402), (4783, 0.11430782877322976), (6938, 0.10917842381580542)], 'surprise': [(8279, 0.07232417477746987), (2031, 0.07671283642450336), (5029, 0.14099754806542966), (14386, 0.07332051241010643), (16023, 0.12047911496575464), (15694, 0.10069613565345462)]}, 'layer_1': {'sadness': [(8174, 0.08278261069873295), (15771, 0.0707970533106189), (24104, 0.11251054328651888), (8419, 0.08556252241333802)], 'joy': [(18120, 0.0882647015903174), (23750, 0.08401244301678701), (17653, 0.06893731512603865), (6284, 0.10078771768658373), (11250, 0.110114043089124), (24040, 0.0802607338309567), (7683, 0.10848610192052004), (3591, 0.09021383180043342)], 'love': [(3091, 0.10888524314829286), (14230, 0.07459391690591335), (6847, 0.09059198210017705), (4332, 0.07153630946089715), (150, 0.08396553794138618)], 'anger': [(20851, 0.08698506078235167), (13745, 0.09177732502630577), (10403, 0.09664953424925479), (11541, 0.08892998467946743), (4194, 0.08049815424784616)], 'fear': [(5186, 0.06532839367619102), (6767, 0.044099045072224494), (20821, 0.08082077232689851), (23954, 0.10072919764278811), (21612, 0.08770381488459113), (21153, 0.06175227177015332), (19325, 0.119999965603483), (6146, 0.08205126474078336), (21826, 0.08156900736407777)], 'surprise': [(12718, 0.13967974926152998), (23779, 0.041260862324528226), (18239, 0.10499565369232723), (666, 0.07321535309891099), (487, 0.02596511610082932), (16125, 0.053906248386955985), (8551, 0.13205099186631775), (2037, 0.1178055222362124)]}, 'layer_2': {'sadness': [(11683, 0.10901298153471035), (14915, 0.13088293565167347), (11568, 0.06966354897426054), (4350, 0.08484378995198522), (2442, 0.10134184728648533)], 'joy': [(7796, 0.17982066049934312), (23405, 0.07340644639445086), (22134, 0.09081248835786807), (3456, 0.13996561349074774), (13928, 0.11056528765708495), (3879, 0.11641754045351872), (23476, 0.07537542370792892)], 'love': [(3203, 0.07667066216200115)], 'anger': [(11085, 0.07795194239863522), (21027, 0.06898965952670631), (14918, 0.08486769742737132), (252, 0.11079884925220439), (21165, 0.16978544516701438), (4707, 0.07412123160452701), (1550, 0.14649070366810923), (5526, 0.12208548058919942), (18357, 0.10914000845849153)], 'fear': [(24422, 0.14471614390713852), (22815, 0.13971655418695292), (21011, 0.19965969638448558), (20309, 0.1576285615866012), (18350, 0.16328753882045655), (10882, 0.1786845279869587), (9937, 0.1451197785971641), (5843, 0.11012748832194018), (12026, 0.09285075188100708)], 'surprise': [(11631, 0.08530139172590022), (11365, 0.09281374963404761), (15076, 0.12746189189513843), (10353, 0.11497617240740243), (7902, 0.06890262999999801), (7800, 0.07979319290773887)]}, 'layer_3': {'sadness': [(24140, 0.11089085529604116), (24469, 0.12268222312403322), (22098, 0.1952673551815616), (14290, 0.2137946147603388)], 'joy': [(10739, 0.3033343227657852), (9828, 0.16630223394861934), (14625, 0.15553963898143797), (5329, 0.11385538224077 ...

# %%
print(steer_20_effects)
# Out:
# {'layer_0': {'sadness': [12266, 23208, 14158, 10882, 10510, 546], 'joy': [8699, 10924, 13808, 16670, 15464, 1432], 'love': [24486, 19618, 3970, 7792, 13985, 21219, 4892, 7099], 'anger': [22318, 13668, 17628, 12030, 800, 22574], 'fear': [2998, 8167, 634, 22447, 15196, 8194, 2288, 13200, 23219, 4783, 6938], 'surprise': [8279, 2031, 5029, 14386, 16023, 15694]}, 'layer_1': {'sadness': [8174, 15771, 24104, 8419], 'joy': [18120, 23750, 17653, 6284, 11250, 24040, 7683, 3591], 'love': [3091, 14230, 6847, 4332, 150], 'anger': [20851, 13745, 10403, 11541, 4194], 'fear': [5186, 6767, 20821, 23954, 21612, 21153, 19325, 6146, 21826], 'surprise': [12718, 23779, 18239, 666, 487, 16125, 8551, 2037]}, 'layer_2': {'sadness': [11683, 14915, 11568, 4350, 2442], 'joy': [7796, 23405, 22134, 3456, 13928, 3879, 23476], 'love': [3203], 'anger': [11085, 21027, 14918, 252, 21165, 4707, 1550, 5526, 18357], 'fear': [24422, 22815, 21011, 20309, 18350, 10882, 9937, 5843, 12026], 'surprise': [11631, 11365, 15076, 10353, 7902, 7800]}, 'layer_3': {'sadness': [24140, 24469, 22098, 14290], 'joy': [10739, 9828, 14625, 5329, 19341, 10990, 6001], 'love': [14981, 5501, 15927, 11815, 23271], 'anger': [13819, 9272, 412, 3213, 16043, 24133], 'fear': [6134, 1861, 22236, 8135, 20126, 20648, 2253, 20588, 18762, 9805, 8914, 6653], 'surprise': [3282, 23140, 10647, 972, 17827, 3625, 17365, 14434, 10958]}, 'layer_4': {'sadness': [(5179, 0.18218899644082082), (7494, 0.13167911455489734), (9341, 0.40293895996609025), (22033, 0.31097613525076423), (23292, 0.5314430815949358), (10051, 0.6027760430259975)], 'joy': [(15968, 0.17590611904589878), (12298, 0.3275249137464507), (9569, 0.39257111449133003), (8244, 0.38911317707570103), (22722, 0.22145850298755843)], 'love': [(9757, 0.4460286026385722), (10750, 0.5309766020226961), (4004, 0.26943276297327384), (7249, 0.2862318646377037)], 'anger': [(22695, 0.18966329011422806), (9072, 0.4711841663050394), (18320, 0.3328448090661558), (11510, 0.47023503249242016), (3810, 0.2989590336704878), (16080, 0.1644146385420268), (15004, 0.23043942604638706), (11183, 0.22146159762076692)], 'fear': [(20655, 0.2685137517313212), (18321, 0.1683113538849863), (13386, 0.15289010172467213), (4338, 0.13436654088127076), (2955, 0.4149281369070298), (24553, 0.5032057892648392), (16651, 0.42608606463605586), (15882, 0.4499338076821463), (14836, 0.33194135980359524), (12290, 0.3747336196420694)], 'surprise': [(19514, 0.15021134404218275), (15250, 0.1804911208896597), (19967, 0.4335914596421074), (16649, 0.17666172858648552), (24019, 0.1854853283641485), (12758, 0.2865766418111494), (9661, 0.2712700992619696)]}, 'layer_5': {'sadness': [1265, 22889], 'joy': [6803, 17170, 14404, 1255, 13678, 14997], 'love': [23060, 12473, 3674, 18288, 13689, 4600, 3448], 'anger': [1773, 330, 5136, 9706, 9559], 'fear': [7952, 15844, 6801, 21689, 24318, 2212, 5990, 15747], 'surprise': [21258, 14750, 2877, 3055, 17557, 23920, 3546, 16559, 9884, 7516, 6011]}, 'layer_6': {'sadness': [20719, 251], 'joy': [9995, 3020, 18199, 14968, 203, 2617], 'love': [19727, 16022, 11397, 14808], 'anger': [20521, 16530, 10131, 6415, 15780, 21846], 'fear': [3246, 5289, 12900, 20520, 18781, 2459, 20211, 19068, 6685, 2260], 'surprise': [13502, 18954, 14477, 6315, 9678, 2328, 21364, 17678, 9978, 19798, 3036]}, 'layer_7': {'sadness': [2045], 'joy': [24314, 17025, 19547], 'love': [2887, 2715, 19662], 'anger': [1776, 10033], 'fear': [18892, 13863, 17128, 13519, 4505, 5211, 17463, 19010, 15862, 14791], 'surprise': [17837, 20417, 17104, 12344, 8002, 10849, 15668, 11750, 8981, 8442]}, 'layer_8': {'sadness': [7473, 3927], 'joy': [13624, 8708, 13433], 'love': [8631, 9837, 2017], 'anger': [21519, 22715, 2133, 17121], 'fear': [13796, 4846, 8887, 4810, 19414, 19585, 17376], 'surprise': [14571, 1366, 14856, 15950, 15512, 20821, 8855, 12456, 20423, 4939]}, 'layer_9': {'sadness': [10885, 17773, 5000], 'joy': [4288, 7702, 20850, 1418, 4864], 'love': [20105, 9946, 17442, 21303, 21876], 'anger': [21253, 7002, 15510, 16663 ...

# %%
print(ablation_effects)
# Out:
# {'layer_0': {'sadness': [12266, 23208, 14158, 10882, 10510, 546], 'joy': [8699, 10924, 13808, 16670, 15464, 1432], 'love': [24486, 19618, 3970, 7792, 13985, 21219, 4892, 7099], 'anger': [22318, 13668, 17628, 12030, 800, 22574], 'fear': [2998, 8167, 634, 22447, 15196, 8194, 2288, 13200, 23219, 4783, 6938], 'surprise': [8279, 2031, 5029, 14386, 16023, 15694]}, 'layer_1': {'sadness': [8174, 15771, 24104, 8419], 'joy': [18120, 23750, 17653, 6284, 11250, 24040, 7683, 3591], 'love': [3091, 14230, 6847, 4332, 150], 'anger': [20851, 13745, 10403, 11541, 4194], 'fear': [5186, 6767, 20821, 23954, 21612, 21153, 19325, 6146, 21826], 'surprise': [12718, 23779, 18239, 666, 487, 16125, 8551, 2037]}, 'layer_2': {'sadness': [11683, 14915, 11568, 4350, 2442], 'joy': [7796, 23405, 22134, 3456, 13928, 3879, 23476], 'love': [3203], 'anger': [11085, 21027, 14918, 252, 21165, 4707, 1550, 5526, 18357], 'fear': [24422, 22815, 21011, 20309, 18350, 10882, 9937, 5843, 12026], 'surprise': [11631, 11365, 15076, 10353, 7902, 7800]}, 'layer_3': {'sadness': [24140, 24469, 22098, 14290], 'joy': [10739, 9828, 14625, 5329, 19341, 10990, 6001], 'love': [14981, 5501, 15927, 11815, 23271], 'anger': [13819, 9272, 412, 3213, 16043, 24133], 'fear': [6134, 1861, 22236, 8135, 20126, 20648, 2253, 20588, 18762, 9805, 8914, 6653], 'surprise': [3282, 23140, 10647, 972, 17827, 3625, 17365, 14434, 10958]}, 'layer_4': {'sadness': [(5179, 0.15037059723155236), (7494, 0.1234799374108679), (9341, 0.19482402648264632), (22033, 0.1928657476801596), (23292, 0.08375136558652015), (10051, 0.18453389571173054)], 'joy': [(15968, 0.14992831400144688), (12298, 0.1540917404519769), (9569, 0.09159589991453815), (8244, 0.0902234703148447), (22722, 0.1521547214926575)], 'love': [(9757, 0.1654931225284623), (10750, 0.4475711504566756), (4004, 0.08194580604159592), (7249, 0.1129769738193759)], 'anger': [(22695, 0.16789129273020656), (9072, 0.17780075095749842), (18320, 0.26486377115119836), (11510, 0.2012046172793415), (3810, 0.15453146011826524), (16080, 0.21939485454932042), (15004, 0.11294002933983269), (11183, 0.1521547214926575)], 'fear': [(20655, 0.16078315662118262), (18321, 0.239085532064044), (13386, 0.1725242052026652), (4338, 0.1487632340342783), (2955, 0.21935889738775247), (24553, 0.14737780098823453), (16651, 0.20674850437470382), (15882, 0.14250673434503003), (14836, 0.15888185672086802), (12290, 0.3621171870901296)], 'surprise': [(19514, 0.16937890970185077), (15250, 0.08150334736596794), (19967, 0.3927833962220925), (16649, 0.13578770405092835), (24019, 0.16506179953893704), (12758, 0.18710035244033263), (9661, 0.24870618455228424)]}, 'layer_5': {'sadness': [1265, 22889], 'joy': [6803, 17170, 14404, 1255, 13678, 14997], 'love': [23060, 12473, 3674, 18288, 13689, 4600, 3448], 'anger': [1773, 330, 5136, 9706, 9559], 'fear': [7952, 15844, 6801, 21689, 24318, 2212, 5990, 15747], 'surprise': [21258, 14750, 2877, 3055, 17557, 23920, 3546, 16559, 9884, 7516, 6011]}, 'layer_6': {'sadness': [20719, 251], 'joy': [9995, 3020, 18199, 14968, 203, 2617], 'love': [19727, 16022, 11397, 14808], 'anger': [20521, 16530, 10131, 6415, 15780, 21846], 'fear': [3246, 5289, 12900, 20520, 18781, 2459, 20211, 19068, 6685, 2260], 'surprise': [13502, 18954, 14477, 6315, 9678, 2328, 21364, 17678, 9978, 19798, 3036]}, 'layer_7': {'sadness': [2045], 'joy': [24314, 17025, 19547], 'love': [2887, 2715, 19662], 'anger': [1776, 10033], 'fear': [18892, 13863, 17128, 13519, 4505, 5211, 17463, 19010, 15862, 14791], 'surprise': [17837, 20417, 17104, 12344, 8002, 10849, 15668, 11750, 8981, 8442]}, 'layer_8': {'sadness': [7473, 3927], 'joy': [13624, 8708, 13433], 'love': [8631, 9837, 2017], 'anger': [21519, 22715, 2133, 17121], 'fear': [13796, 4846, 8887, 4810, 19414, 19585, 17376], 'surprise': [14571, 1366, 14856, 15950, 15512, 20821, 8855, 12456, 20423, 4939]}, 'layer_9': {'sadness': [10885, 17773, 5000], 'joy': [4288, 7702, 20850, 1418, 4864], 'love': [20105, 9946, 17442, 21303, 21876], 'anger': [21253, 7002, 15510,  ...

# %%
print(str(sys.getsizeof(emotion_features)), 'bytes')
# Out:
# 640 bytes

# %%
with open(f'ablation_effect_layer_{target_layer}.pkl', 'wb') as f:
    pickle.dump(ablation_effects, f)
        
with open(f'ablation_effect_layer_{target_layer}.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)
    ablation_layer_4_effects = np.array([n for e in loaded_dict[f'layer_{target_layer}'] for _, n in loaded_dict['layer_4'][e]])

# %%
with open(f'steer_20_effect_layer_{target_layer}.pkl', 'wb') as f:
    pickle.dump(steer_20_effects, f)
        
with open(f'steer_20_effect_layer_{target_layer}.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)
    steer_20_layer_4_effects = np.array([n for e in loaded_dict['layer_4'] for _, n in loaded_dict['layer_4'][e]])
    scatter_plt_labels = np.array([e for e in loaded_dict['layer_4'] for _, n in loaded_dict['layer_4'][e]])

# %%
print(scatter_plt_labels)
# Out:
# ['sadness' 'sadness' 'sadness' 'sadness' 'sadness' 'sadness' 'joy' 'joy'
#  'joy' 'joy' 'joy' 'love' 'love' 'love' 'love' 'anger' 'anger' 'anger'
#  'anger' 'anger' 'anger' 'anger' 'anger' 'fear' 'fear' 'fear' 'fear'
#  'fear' 'fear' 'fear' 'fear' 'fear' 'fear' 'surprise' 'surprise'
#  'surprise' 'surprise' 'surprise' 'surprise' 'surprise']

# %% [markdown]
# ### Make plots for each layer

# %%
import pickle

# %%
with open(f'ablation_effect_all_layers.pkl', 'rb') as f:

    loaded_dict = pickle.load(f)
    ablation_effect_all_layers = []

    for layer_idx in range(len(emotion_features.keys())):

        ablation_effect_all_layers.append(np.array([n for e in loaded_dict[f'layer_{layer_idx}'] for _, n in loaded_dict[f'layer_{layer_idx}'][e]]))

with open(f'steer_20_effect_all_layers.pkl', 'rb') as f:

    loaded_dict = pickle.load(f)
    steer_20_effect_all_layers = []

    for layer_idx in range(len(emotion_features.keys())):

        steer_20_effect_all_layers.append(np.array([n for e in loaded_dict[f'layer_{layer_idx}'] for _, n in loaded_dict[f'layer_{layer_idx}'][e]]))

# %%
for layer_idx in range(len(ablation_effect_all_layers)):

    scatter_plt_labels = np.array([e for e in loaded_dict[f'layer_{layer_idx}'] for _, n in loaded_dict[f'layer_{layer_idx}'][e]])

    x = ablation_effect_all_layers[layer_idx]
    y = steer_20_effect_all_layers[layer_idx]

    # Create a colormap
    cmap = plt.get_cmap('plasma')
    unique_plt_labels = list(set(scatter_plt_labels))
    colors = [cmap(i / len(unique_plt_labels)) for i in range(len(unique_plt_labels))]
    color_map = dict(zip(unique_plt_labels, colors))

    # Plotting the scatter plot with colored labels
    plt.figure(figsize=(12, 12))
    for label in unique_plt_labels:
        idx = np.where(scatter_plt_labels == label)
        plt.scatter(x[idx], y[idx], color=color_map[label], label=label)

    # Create legend
    plt.legend()

    # Adding labels to each point (uncomment if needed)
    # for i in range(len(ablation_layer_0_effects)):
    #     plt.text(ablation_layer_0_effects[i], steer_20_layer_0_effects[i], scatter_plt_labels[i], fontsize=10, ha='right')

    plt.xlabel('Ablation: JS distance from default distribution')
    plt.ylabel('Steering (coeff = 20): JS distance from default distribution')
    plt.title(f'Layer {layer_idx}: Ablation and Steering Effects (coeff = 20)')
    plt.savefig(f'layer_{layer_idx}_effects.png', bbox_inches='tight')

# %% [markdown]
# ### Sort features based on JS distances

# %%
with open(f'ablation_effect_all_layers.pkl', 'rb') as f:

    sorted_dict = pickle.load(f)

    for layer_idx in range(len(emotion_features.keys())):

        for emotion in sorted_dict[f'layer_{layer_idx}']:

            sorted_dict[f'layer_{layer_idx}'][emotion] = sorted(sorted_dict[f'layer_{layer_idx}'][emotion], key=lambda x: x[1], reverse=True)
    
    sorted_dict_ablation_effects = sorted_dict


with open(f'steer_20_effect_all_layers.pkl', 'rb') as f:

    sorted_dict = pickle.load(f)

    for layer_idx in range(len(emotion_features.keys())):

        for emotion in sorted_dict[f'layer_{layer_idx}']:

            sorted_dict[f'layer_{layer_idx}'][emotion] = sorted(sorted_dict[f'layer_{layer_idx}'][emotion], key=lambda x: x[1], reverse=True)

    sorted_dict_steer_20_effects = sorted_dict

# %%
import json

# %%
print(json.dumps(sorted_dict_ablation_effects, sort_keys=True, indent=4))
# Out:
# {
#     "layer_0": {
#         "anger": [
#             [
#                 17628,
#                 0.136993132323818
#             ],
#             [
#                 800,
#                 0.1336924728991583
#             ],
#             [
#                 13668,
#                 0.11260909246796945
#             ],
#             [
#                 12030,
#                 0.08207058533001868
#             ],
#             [
#                 22318,
#                 0.07140873140508561
#             ],
#             [
#                 22574,
#                 0.06984331557150779
#             ]
#         ],
#         "fear": [
#             [
#                 8194,
#                 0.1503271416717931
#             ],
#             [
#                 4783,
#                 0.11430782877322976
#             ],
#             [
#                 6938,
#                 0.10917842381580542
#             ],
#             [
#                 2288,
#                 0.10512030717921103
#             ],
#             [
#                 634,
#                 0.10288922697877087
#             ],
#             [
#                 23219,
#                 0.102654977026402
#             ],
#             [
#                 15196,
#                 0.10198877668693447
#             ],
#             [
#                 22447,
#                 0.10043814345398534
#             ],
#             [
#                 8167,
#                 0.08839673501064112
#             ],
#             [
#                 2998,
#                 0.08669878258234977
#             ],
#             [
#                 13200,
#                 0.04148056162429206
#             ]
#         ],
#         "joy": [
#             [
#                 13808,
#                 0.14422535808526082
#             ],
#             [
#                 16670,
#                 0.0972270243966704
#             ],
#             [
#                 1432,
#                 0.07907644240058859
#             ],
#             [
#                 15464,
#                 0.06801962236531685
#             ],
#             [
#                 8699,
#                 0.06013792769847593
#             ],
#             [
#                 10924,
#                 0.05442534221522403
#             ]
#         ],
#         "love": [
#             [
#                 4892,
#                 0.12055547402890134
#             ],
#             [
#                 7792,
#                 0.1090845437855492
#             ],
#             [
#                 19618,
#                 0.07785277366991186
#             ],
#             [
#                 3970,
#                 0.0738154339558306
#             ],
#             [
#                 13985,
#                 0.07359145043270564
#             ],
#             [
#                 7099,
#                 0.06485527517976264
#             ],
#             [
#                 21219,
#                 0.060694505838899786
#             ],
#             [
#                 24486,
#                 0.04199374843362757
#             ]
#         ],
#         "sadness": [
#             [
#                 14158,
#                 0.10598818985199403
#             ],
#             [
#                 546,
#                 0.09506236271362445
#             ],
#             [
#                 23208,
#                 0.092545568777795
#             ],
#             [
#                 10882,
#                 0.08441380089022585
#             ],
#             [
#                 12266,
#                 0.05920798421448489
#             ],
#             [
#                 10510,
#                 0.042430235470293294
#             ]
#         ],
#         "surprise": [
#             [
#                 5029,
#                 0.14099754806542966
#             ],
#             [
#                 16023,
#                 0.12047911496575464
#             ],
#             [
#                 15694,
#                 0.10069613565345462
#             ],
#             [
#                 2031,
#                 0.07671283642450336
#             ],
#             [
#                 14386,
#                 0.07332051241010643
#             ],
#             [
#                 8279,
#                 0.07232417477746987
#             ]
#         ]
#     },
#     "layer_1": {
#         "anger": [
#             [
#                 10403,
#                 0.09664953424925479
#             ],
#             [
#                 13745,
#                 0.09177732502630577
#             ],
#             [
#                 11541,
#                 0.08892998467946743
#             ],
#             [
#                 20851,
#                 0.08698506078235167
#             ],
#             [
#                 4194,
#                 0.08049815424784616
#             ]
#         ],
#         "fear": [
#             [
#                 19325,
#                 0.119999965603483
#             ],
#             [
#                 23954,
#                 0.10072919764278811
#             ],
#             [
#                 21612,
#                 0.08770381488459113
#             ],
#             [
#                 6146,
#                 0.08205126474078336
#             ],
#             [
#                 21826,
#                 0.08156900736407777
#             ],
#             [
#                 20821,
#                 0.08082077232689851
#             ],
#             [
#                 5186,
#                 0.06532839367619102
#             ],
#             [
#                 21153,
#                 0.06175227177015332
#             ],
#             [
#                 6767,
#                 0.044099045072224494
#             ]
#         ],
#         "joy": [
#             [
#                 11250,
#                 0.110114043089124
#             ],
#             [
#                 7683,
#                 0.10848610192052004
#             ],
#             [
#                 6284,
#                 0.10078771768658373
#             ],
#             [
#                 3591,
#                 0.09021383180043342
#             ],
#             [
#                 18120,
#                 0.0882647015903174
#             ],
#             [
#                 23750,
#                 0.08401244301678701
#             ],
#             [
#                 24040,
#                 0.0802607338309567
#             ],
#             [
#                 17653,
#                 0.06893731512603865
#             ]
#         ],
#         "love": [
#             [
#                 3091,
#                 0.10888524314829286
#             ],
#             [
#                 6847,
#                 0.09059198210017705
#             ],
#             [
#                 150,
#                 0.08396553794138618
#             ],
#             [
#                 14230,
#                 0.07459391690591335
#             ],
#             [
#                 4332,
#                 0.07153630946089715
#             ]
#         ],
#         "sadness": [
#             [
#                 24104,
#                 0.11251054328651888
#             ],
#             [
#                 8419,
#                 0.08556252241333802
#             ],
#             [
#                 8174,
#                 0.08278261069873295
#             ],
#             [
#                 15771,
#                 0.0707970533106189
#             ]
#         ],
#         "surprise": [
#             [
#                 12718,
#                 0.13967974926152998
#             ],
#             [
#                 8551,
#                 0.13205099186631775
#             ],
#             [
#                 2037,
#                 0.1178055222362124
#             ],
#             [
#                 18239,
#                 0.10499565369232723
#             ],
#             [
#                 666,
#                 0.07321535309891099
#             ],
#             [
#                 16125,
#                 0.053906248386955985
#             ],
#             [
#                 23779,
#                 0.041260862324528226
#             ],
#             [
#                 487,
#                 0.02596511610082932
#             ]
#         ]
#     },
#     "layer_10": {
#         "anger": [
#             [
#                 5203,
#                 0.12109571074675084
#             ],
#             [
#                 19957,
#                 0.10935485036682291
#             ],
#             [
#                 14697,
#                 0.080494470429097
#             ]
#         ],
#         "fear": [
#             [
#                 24358,
#                 0.12342722001564692
#             ],
#             [
#                 6260,
#                 0.0853634643116814
#             ],
#             [
#                 6822,
#                 0.08492831011969887
#             ],
#             [
#                 2783,
#                 0.07527187671307996
#             ],
#             [
#                 18367,
#                 0.07249504590225818
#             ],
#             [
#                 20305,
#                 0.050942894174335916
#             ]
#         ],
#         "joy": [
#             [
#                 5713,
#                 0.11791119595372762
#             ],
#             [
#                 4091,
#                 0.0910336432916331
#             ],
#             [
#                 809,
#                 0.06737367319841785
#             ]
#         ],
#         "love": [
#             [
#                 20694,
#                 0.1160955389433796
#             ],
#             [
#                 10165,
#                 0.10543352214385351
#             ],
#             [
#                 2095,
#                 0.10434852523662398
#             ],
#             [
#                 130,
#                 0.10016602648643837
#             ],
#             [
#                 14654,
#                 0.09768209397223344
#             ],
#             [
#                 19070,
#                 0.05373079365516869
#             ]
#         ],
#         "sadness": [
#             [
#                 11363,
#                 0.04822834991281956
#             ]
#         ],
#         "surprise": [
#             [
#                 9733,
#                 0.10669960998845879
#             ],
#             [
#                 23922,
#                 0.0996319509378801
#             ],
#             [
#                 184,
#                 0.09512646252949322
#             ],
#             [
#                 18509,
#                 0.09367956085515729
#             ],
#             [
#                 20367,
#                 0.08981363738952128
#             ],
#             [
#                 14901,
#                 0.08961755338190079
#             ],
#             [
#                 7658,
#                 0.08640320186602929
#             ],
#             [
#                 6227,
#                 0.05110375694231299
#             ],
#             [
#                 2150,
#                 0.049379195137489264
#             ],
#             [
#                 23723,
#                 0.028596126887156532
#             ]
#         ]
#     },
#     "layer_11": {
#         "anger": [
#             [
#                 14410,
#                 0.11787660521784123
#             ],
#             [
#                 21754,
#                 0.11133324244259951
#             ],
#             [
#                 8427,
#                 0.09447104991078069
#             ],
#             [
#                 12214,
#                 0.05831364519482581
#             ],
#             [
#                 20367,
#                 0.0446769072920493
#             ]
#         ],
#         "fear": [
#             [
#                 13554,
#                 0.149864940113406
#             ],
#             [
#                 9550,
#                 0.1063693132265101
#             ],
#             [
#                 13374,
#                 0.06391760642634166
#             ],
#             [
#                 12092,
#                 0.05943900434489758
#             ],
#             [
#                 24256,
#                 0.05597584565279088
#             ],
#             [
#                 9703,
#                 0.05222925621919577
#             ],
#             [
#                 14324,
#                 0.04667880951207732
#             ],
#             [
#                 165,
#                 0.046527363852980584
#             ],
#             [
#                 20934,
#                 0.038558525135048365
#             ]
#         ],
#         "joy": [
#             [
#                 4943,
#                 0.07499662694943307
#             ],
#             [
#                 8946,
#                 0.0455783323832594
#             ]
#         ],
#         "love": [
#             [
#                 6694,
#                 0.0842768407729381
#             ],
#             [
#                 12316,
#                 0.07762917902410268
#             ],
#             [
#                 15057,
#                 0.07099832418666449
#             ],
#             [
#                 6390,
#                 0.05236080739283085
#             ],
#             [
#                 4407,
#                 0.04846728407267005
#             ]
#         ],
#         "sadness": [
#             [
#                 24428,
#                 0.061601851458312394
#             ],
#             [
#                 16896,
#                 0.04134567669712565
#             ],
#             [
#                 3334,
#                 0.03491064789711906
#             ]
#         ],
#         "surprise": [
#             [
#                 17777,
#                 0.13129797037847057
#             ],
#             [
#                 4452,
#                 0.12365358861082651
#             ],
#             [
#                 17670,
#                 0.09113426308525982
#             ],
#             [
#                 12189,
#                 0.08630888625260198
#             ],
#             [
#                 5047,
#                 0.08343433222256068
#             ],
#             [
#                 15556,
#                 0.07904224206200781
#             ],
#             [
#                 22471,
#                 0.07075167017046219
#             ],
#             [
#                 17411,
#                 0.06877949017731294
#             ],
#             [
#                 22203,
#                 0.06251590983165062
#             ],
#             [
#                 949,
#                 0.05172578478481615
#             ],
#             [
#                 3086,
#                 0.03762554961227632
#             ],
#             [
#                 5820,
#                 0.03073685194208769
#             ],
#             [
#                 21799,
#                 0.017362469960508557
#             ]
#         ]
#     },
#     "layer_2": {
#         "anger": [
#             [
#                 21165,
#                 0.16978544516701438
#             ],
#             [
#                 1550,
#                 0.14649070366810923
#             ],
#             [
#                 5526,
#                 0.12208548058919942
#             ],
#             [
#                 252,
#                 0.11079884925220439
#             ],
#             [
#                 18357,
#                 0.10914000845849153
#             ],
#             [
#                 14918,
#                 0.08486769742737132
#             ],
#             [
#                 11085,
#                 0.07795194239863522
#             ],
#             [
#                 4707,
#                 0.07412123160452701
#             ],
#             [
#                 21027,
#                 0.06898965952670631
#             ]
#         ],
#         "fear": [
#             [
#                 21011,
#                 0.19965969638448558
#             ],
#             [
#                 10882,
#                 0.1786845279869587
#             ],
#             [
#                 18350,
#                 0.16328753882045655
#             ],
#             [
#                 20309,
#                 0.1576285615866012
#             ],
#             [
#                 9937,
#                 0.1451197785971641
#             ],
#             [
#                 24422,
#                 0.14471614390713852
#             ],
#             [
#                 22815,
#                 0.13971655418695292
#             ],
#             [
#                 5843,
#                 0.11012748832194018
#             ],
#             [
#                 12026,
#                 0.09285075188100708
#             ]
#         ],
#         "joy": [
#             [
#                 7796,
#                 0.17982066049934312
#             ],
#             [
#                 3456,
#                 0.13996561349074774
#             ],
#             [
#                 3879,
#                 0.11641754045351872
#             ],
#             [
#                 13928,
#                 0.11056528765708495
#             ],
#             [
#                 22134,
#                 0.09081248835786807
#             ],
#             [
#                 23476,
#                 0.07537542370792892
#             ],
#             [
#                 23405,
#                 0.07340644639445086
#             ]
#         ],
#         "love": [
#             [
#                 3203,
#                 0.07667066216200115
#             ]
#         ],
#         "sadness": [
#             [
#                 14915,
#                 0.13088293565167347
#             ],
#             [
#                 11683,
#                 0.10901298153471035
#             ],
#             [
#                 2442,
#                 0.10134184728648533
#             ],
#             [
#                 4350,
#                 0.08484378995198522
#             ],
#             [
#                 11568,
#                 0.06966354897426054
#             ]
#         ],
#         "surprise": [
#             [
#                 15076,
#                 0.12746189189513843
#             ],
#             [
#                 10353,
#                 0.11497617240740243
#             ],
#             [
#                 11365,
#                 0.09281374963404761
#             ],
#             [
#                 11631,
#                 0.08530139172590022
#             ],
#             [
#                 7800,
#                 0.07979319290773887
#             ],
#             [
#                 7902,
#                 0.06890262999999801
#             ]
#         ]
#     },
#     "layer_3": {
#         "anger": [
#             [
#                 13819,
#                 0.2699199198172551
#             ],
#             [
#                 16043,
#                 0.19656022490278602
#             ],
#             [
#                 3213,
#                 0.19035480386343653
#             ],
#             [
#                 412,
#                 0.18115905665938525
#             ],
#             [
#                 9272,
#                 0.11406987880124302
#             ],
#             [
#                 24133,
#                 0.11013771998763776
#             ]
#         ],
#         "fear": [
#             [
#                 9805,
#                 0.37307524449018326
#             ],
#             [
#                 8914,
#                 0.3640790135185004
#             ],
#             [
#                 6134,
#                 0.22710370579886724
#             ],
#             [
#                 22236,
#                 0.21368830859305607
#             ],
#             [
#                 6653,
#                 0.19515156494384123
#             ],
#             [
#                 20588,
#                 0.18749299322333565
#             ],
#             [
#                 1861,
#                 0.1784237428105986
#             ],
#             [
#                 8135,
#                 0.16471386326691803
#             ],
#             [
#                 2253,
#                 0.15247894044481547
#             ],
#             [
#                 20648,
#                 0.12210171207809402
#             ],
#             [
#                 20126,
#                 0.11596743807207702
#             ],
#             [
#                 18762,
#                 0.10996823753349491
#             ]
#         ],
#         "joy": [
#             [
#                 10739,
#                 0.3033343227657852
#             ],
#             [
#                 10990,
#                 0.290404197510232
#             ],
#             [
#                 6001,
#                 0.22178996982992916
#             ],
#             [
#                 9828,
#                 0.16630223394861934
#             ],
#             [
#                 14625,
#                 0.15553963898143797
#             ],
#             [
#                 5329,
#                 0.11385538224077471
#             ],
#             [
#                 19341,
#                 0.08220755922876147
#             ]
#         ],
#         "love": [
#             [
#                 11815,
#                 0.2151697103329929
#             ],
#             [
#                 23271,
#                 0.1421862637636011
#             ],
#             [
#                 15927,
#                 0.12418563911117868
#             ],
#             [
#                 14981,
#                 0.10385726070504728
#             ],
#             [
#                 5501,
#                 0.10100027975417092
#             ]
#         ],
#         "sadness": [
#             [
#                 14290,
#                 0.2137946147603388
#             ],
#             [
#                 22098,
#                 0.1952673551815616
#             ],
#             [
#                 24469,
#                 0.12268222312403322
#             ],
#             [
#                 24140,
#                 0.11089085529604116
#             ]
#         ],
#         "surprise": [
#             [
#                 14434,
#                 0.20189987134466356
#             ],
#             [
#                 3625,
#                 0.19220189492654574
#             ],
#             [
#                 10958,
#                 0.1461839921582414
#             ],
#             [
#                 3282,
#                 0.11914302379402406
#             ],
#             [
#                 972,
#                 0.11664777264243713
#             ],
#             [
#                 17365,
#                 0.09945335660731768
#             ],
#             [
#                 17827,
#                 0.08837494822804567
#             ],
#             [
#                 10647,
#                 0.07905270379522587
#             ],
#             [
#                 23140,
#                 0.06448036535893385
#             ]
#         ]
#     },
#     "layer_4": {
#         "anger": [
#             [
#                 11510,
#                 0.27737562713133734
#             ],
#             [
#                 18320,
#                 0.2189556618512231
#             ],
#             [
#                 9072,
#                 0.17251722873946043
#             ],
#             [
#                 15004,
#                 0.1535711462630919
#             ],
#             [
#                 3810,
#                 0.14003046212543133
#             ],
#             [
#                 22695,
#                 0.12867893843986386
#             ],
#             [
#                 16080,
#                 0.10338197816847375
#             ],
#             [
#                 11183,
#                 0.07544098450314801
#             ]
#         ],
#         "fear": [
#             [
#                 12290,
#                 0.3318287236254845
#             ],
#             [
#                 2955,
#                 0.21025919726937814
#             ],
#             [
#                 16651,
#                 0.19627285659318058
#             ],
#             [
#                 14836,
#                 0.19097086359005608
#             ],
#             [
#                 24553,
#                 0.18211432444279105
#             ],
#             [
#                 13386,
#                 0.1348076565103428
#             ],
#             [
#                 4338,
#                 0.13183044842658487
#             ],
#             [
#                 18321,
#                 0.11739830431909286
#             ],
#             [
#                 20655,
#                 0.1137355419718942
#             ],
#             [
#                 15882,
#                 0.11012787873157162
#             ]
#         ],
#         "joy": [
#             [
#                 9569,
#                 0.19305623894226878
#             ],
#             [
#                 15968,
#                 0.17825563283848447
#             ],
#             [
#                 8244,
#                 0.13373764065642485
#             ],
#             [
#                 12298,
#                 0.11350115069191585
#             ],
#             [
#                 22722,
#                 0.0432819606757845
#             ]
#         ],
#         "love": [
#             [
#                 10750,
#                 0.38149043474043914
#             ],
#             [
#                 9757,
#                 0.11675532508426302
#             ],
#             [
#                 7249,
#                 0.08282084519374922
#             ],
#             [
#                 4004,
#                 0.07846850338470268
#             ]
#         ],
#         "sadness": [
#             [
#                 10051,
#                 0.16184772836465164
#             ],
#             [
#                 5179,
#                 0.1516322026561144
#             ],
#             [
#                 9341,
#                 0.15079343321705496
#             ],
#             [
#                 7494,
#                 0.1360780662869252
#             ],
#             [
#                 22033,
#                 0.13225791959677188
#             ],
#             [
#                 23292,
#                 0.09588280335170336
#             ]
#         ],
#         "surprise": [
#             [
#                 19967,
#                 0.22212170014708327
#             ],
#             [
#                 19514,
#                 0.17719715775777112
#             ],
#             [
#                 16649,
#                 0.16817119087167884
#             ],
#             [
#                 24019,
#                 0.14636238788551154
#             ],
#             [
#                 9661,
#                 0.10748740445921887
#             ],
#             [
#                 12758,
#                 0.10678019294420539
#             ],
#             [
#                 15250,
#                 0.09674258038002881
#             ]
#         ]
#     },
#     "layer_5": {
#         "anger": [
#             [
#                 9706,
#                 0.30872216983025075
#             ],
#             [
#                 1773,
#                 0.25009367756577666
#             ],
#             [
#                 9559,
#                 0.1972460934823813
#             ],
#             [
#                 330,
#                 0.11633919510799778
#             ],
#             [
#                 5136,
#                 0.0989554919214543
#             ]
#         ],
#         "fear": [
#             [
#                 24318,
#                 0.19812114630159472
#             ],
#             [
#                 21689,
#                 0.1696821281947014
#             ],
#             [
#                 2212,
#                 0.15987935280310722
#             ],
#             [
#                 15844,
#                 0.15461875274687087
#             ],
#             [
#                 7952,
#                 0.1455917573824695
#             ],
#             [
#                 6801,
#                 0.07613900638119463
#             ],
#             [
#                 5990,
#                 0.07558356983123973
#             ],
#             [
#                 15747,
#                 0.07452067741522801
#             ]
#         ],
#         "joy": [
#             [
#                 14404,
#                 0.18633505918508522
#             ],
#             [
#                 17170,
#                 0.1754007513072962
#             ],
#             [
#                 1255,
#                 0.13581214034397743
#             ],
#             [
#                 14997,
#                 0.1327591879310639
#             ],
#             [
#                 6803,
#                 0.0763374170625742
#             ],
#             [
#                 13678,
#                 0.0525691035762242
#             ]
#         ],
#         "love": [
#             [
#                 18288,
#                 0.3234246777799626
#             ],
#             [
#                 13689,
#                 0.20441523940309536
#             ],
#             [
#                 3674,
#                 0.1747335410040413
#             ],
#             [
#                 4600,
#                 0.16897121919793856
#             ],
#             [
#                 3448,
#                 0.11051162943972177
#             ],
#             [
#                 23060,
#                 0.09093884075528191
#             ],
#             [
#                 12473,
#                 0.06409809093663213
#             ]
#         ],
#         "sadness": [
#             [
#                 22889,
#                 0.29763475567656644
#             ],
#             [
#                 1265,
#                 0.10136741527535473
#             ]
#         ],
#         "surprise": [
#             [
#                 14750,
#                 0.21974117514255104
#             ],
#             [
#                 16559,
#                 0.19984102707823578
#             ],
#             [
#                 3055,
#                 0.15142393532438173
#             ],
#             [
#                 2877,
#                 0.14950584620882204
#             ],
#             [
#                 7516,
#                 0.14110163813221097
#             ],
#             [
#                 9884,
#                 0.1402239291593294
#             ],
#             [
#                 6011,
#                 0.12399108423258706
#             ],
#             [
#                 21258,
#                 0.11544096803697967
#             ],
#             [
#                 3546,
#                 0.10862969880876583
#             ],
#             [
#                 23920,
#                 0.10169973522053877
#             ],
#             [
#                 17557,
#                 0.09976778649834034
#             ]
#         ]
#     },
#     "layer_6": {
#         "anger": [
#             [
#                 20521,
#                 0.28426048704802764
#             ],
#             [
#                 16530,
#                 0.17231968888774232
#             ],
#             [
#                 10131,
#                 0.16133901486968588
#             ],
#             [
#                 15780,
#                 0.14067356120817054
#             ],
#             [
#                 6415,
#                 0.13028725273899974
#             ],
#             [
#                 21846,
#                 0.12671795148385273
#             ]
#         ],
#         "fear": [
#             [
#                 3246,
#                 0.32926947278051205
#             ],
#             [
#                 20211,
#                 0.2512240289486539
#             ],
#             [
#                 19068,
#                 0.22841859896801917
#             ],
#             [
#                 6685,
#                 0.19622326730243717
#             ],
#             [
#                 2459,
#                 0.16700871286697283
#             ],
#             [
#                 2260,
#                 0.1413581022999798
#             ],
#             [
#                 5289,
#                 0.13559210383793402
#             ],
#             [
#                 18781,
#                 0.10887647379197264
#             ],
#             [
#                 12900,
#                 0.09087168095858553
#             ],
#             [
#                 20520,
#                 0.05956348273788324
#             ]
#         ],
#         "joy": [
#             [
#                 14968,
#                 0.4690107474334633
#             ],
#             [
#                 9995,
#                 0.41385311137790726
#             ],
#             [
#                 18199,
#                 0.23326015203554237
#             ],
#             [
#                 203,
#                 0.16420497389534608
#             ],
#             [
#                 3020,
#                 0.11806126284928456
#             ],
#             [
#                 2617,
#                 0.10490456665961148
#             ]
#         ],
#         "love": [
#             [
#                 11397,
#                 0.22841700643359672
#             ],
#             [
#                 19727,
#                 0.19431345137244435
#             ],
#             [
#                 16022,
#                 0.1929307095386162
#             ],
#             [
#                 14808,
#                 0.12070575426624416
#             ]
#         ],
#         "sadness": [
#             [
#                 20719,
#                 0.1827357826004929
#             ],
#             [
#                 251,
#                 0.1667884939417949
#             ]
#         ],
#         "surprise": [
#             [
#                 17678,
#                 0.21614031295649808
#             ],
#             [
#                 13502,
#                 0.20922938557635634
#             ],
#             [
#                 18954,
#                 0.17015569593926375
#             ],
#             [
#                 3036,
#                 0.1649389887646368
#             ],
#             [
#                 9978,
#                 0.16229374266252933
#             ],
#             [
#                 6315,
#                 0.14450375803182522
#             ],
#             [
#                 14477,
#                 0.13834870717572384
#             ],
#             [
#                 2328,
#                 0.1360437297200074
#             ],
#             [
#                 9678,
#                 0.13270161249664114
#             ],
#             [
#                 19798,
#                 0.10932340726353161
#             ],
#             [
#                 21364,
#                 0.10607247850985187
#             ]
#         ]
#     },
#     "layer_7": {
#         "anger": [
#             [
#                 1776,
#                 0.17804747766756485
#             ],
#             [
#                 10033,
#                 0.06780356380614216
#             ]
#         ],
#         "fear": [
#             [
#                 19010,
#                 0.2585205085495013
#             ],
#             [
#                 13519,
#                 0.24183575144316544
#             ],
#             [
#                 17128,
#                 0.15784299179192687
#             ],
#             [
#                 18892,
#                 0.15537577323750443
#             ],
#             [
#                 4505,
#                 0.1503526748630277
#             ],
#             [
#                 5211,
#                 0.14044034093836982
#             ],
#             [
#                 14791,
#                 0.1255267199853651
#             ],
#             [
#                 15862,
#                 0.10001354733692269
#             ],
#             [
#                 17463,
#                 0.09809035567977728
#             ],
#             [
#                 13863,
#                 0.08924924591761636
#             ]
#         ],
#         "joy": [
#             [
#                 19547,
#                 0.35747241000093927
#             ],
#             [
#                 17025,
#                 0.14009379918417494
#             ],
#             [
#                 24314,
#                 0.06363465125700116
#             ]
#         ],
#         "love": [
#             [
#                 2715,
#                 0.3127584331963752
#             ],
#             [
#                 2887,
#                 0.20600862078239304
#             ],
#             [
#                 19662,
#                 0.1835775892376651
#             ]
#         ],
#         "sadness": [
#             [
#                 2045,
#                 0.1409003258814016
#             ]
#         ],
#         "surprise": [
#             [
#                 17104,
#                 0.1901787382713103
#             ],
#             [
#                 17837,
#                 0.1895018667873762
#             ],
#             [
#                 10849,
#                 0.18370270248719928
#             ],
#             [
#                 15668,
#                 0.17688673844441655
#             ],
#             [
#                 20417,
#                 0.17180750192021166
#             ],
#             [
#                 8442,
#                 0.15597028072543984
#             ],
#             [
#                 11750,
#                 0.15439119878821872
#             ],
#             [
#                 8981,
#                 0.1285740173181606
#             ],
#             [
#                 12344,
#                 0.12735672379569282
#             ],
#             [
#                 8002,
#                 0.10999627438501877
#             ]
#         ]
#     },
#     "layer_8": {
#         "anger": [
#             [
#                 22715,
#                 0.1368442622445486
#             ],
#             [
#                 21519,
#                 0.11901920846699857
#             ],
#             [
#                 17121,
#                 0.11017614052347069
#             ],
#             [
#                 2133,
#                 0.0862203658669718
#             ]
#         ],
#         "fear": [
#             [
#                 19585,
#                 0.19822171970153785
#             ],
#             [
#                 17376,
#                 0.14968242201277351
#             ],
#             [
#                 4810,
#                 0.14167240495881306
#             ],
#             [
#                 8887,
#                 0.11249238293858611
#             ],
#             [
#                 19414,
#                 0.1045311308773317
#             ],
#             [
#                 4846,
#                 0.09494175476141464
#             ],
#             [
#                 13796,
#                 0.04482442464450781
#             ]
#         ],
#         "joy": [
#             [
#                 13624,
#                 0.14830001594368836
#             ],
#             [
#                 13433,
#                 0.13856570052810444
#             ],
#             [
#                 8708,
#                 0.1206259370930131
#             ]
#         ],
#         "love": [
#             [
#                 9837,
#                 0.14139453683451264
#             ],
#             [
#                 8631,
#                 0.10544465583492463
#             ],
#             [
#                 2017,
#                 0.0996319509378801
#             ]
#         ],
#         "sadness": [
#             [
#                 7473,
#                 0.10856316030212315
#             ],
#             [
#                 3927,
#                 0.08104116355909313
#             ]
#         ],
#         "surprise": [
#             [
#                 8855,
#                 0.15374417943965074
#             ],
#             [
#                 1366,
#                 0.13066969811132334
#             ],
#             [
#                 4939,
#                 0.12000355144580742
#             ],
#             [
#                 15950,
#                 0.11896818243524233
#             ],
#             [
#                 20821,
#                 0.1178396347906298
#             ],
#             [
#                 12456,
#                 0.10261458340283115
#             ],
#             [
#                 15512,
#                 0.09793672821155154
#             ],
#             [
#                 14571,
#                 0.092388661481209
#             ],
#             [
#                 14856,
#                 0.07721259945815388
#             ],
#             [
#                 20423,
#                 0.06023797337210977
#             ]
#         ]
#     },
#     "layer_9": {
#         "anger": [
#             [
#                 7002,
#                 0.15985840642348093
#             ],
#             [
#                 21253,
#                 0.12928596837232648
#             ],
#             [
#                 16663,
#                 0.1170638342267597
#             ],
#             [
#                 15510,
#                 0.08606158343518645
#             ]
#         ],
#         "fear": [
#             [
#                 14412,
#                 0.1353956456733649
#             ],
#             [
#                 20233,
#                 0.12446875970129781
#             ],
#             [
#                 1413,
#                 0.10423360039462017
#             ],
#             [
#                 5563,
#                 0.1016008907930907
#             ],
#             [
#                 15382,
#                 0.0893696203406636
#             ],
#             [
#                 19535,
#                 0.07207657681172679
#             ]
#         ],
#         "joy": [
#             [
#                 20850,
#                 0.17434274344256986
#             ],
#             [
#                 4864,
#                 0.148695212050079
#             ],
#             [
#                 7702,
#                 0.09938177177544495
#             ],
#             [
#                 4288,
#                 0.09918201302403717
#             ],
#             [
#                 1418,
#                 0.0334732841391533
#             ]
#         ],
#         "love": [
#             [
#                 21303,
#                 0.1155785884156918
#             ],
#             [
#                 21876,
#                 0.09235732461661074
#             ],
#             [
#                 20105,
#                 0.06628447646483075
#             ],
#             [
#                 17442,
#                 0.059408231626364785
#             ],
#             [
#                 9946,
#                 0.014630275186298988
#             ]
#         ],
#         "sadness": [
#             [
#                 5000,
#                 0.11067924148401045
#             ],
#             [
#                 17773,
#                 0.09846156633134527
#             ],
#             [
#                 10885,
#                 0.037305747074865524
#             ]
#         ],
#         "surprise": [
#             [
#                 21445,
#                 0.1626966362635964
#             ],
#             [
#                 21532,
#                 0.1390040421500891
#             ],
#             [
#                 1167,
#                 0.13320458762695553
#             ],
#             [
#                 17898,
#                 0.1232413654113332
#             ],
#             [
#                 10719,
#                 0.12170390195959997
#             ],
#             [
#                 14851,
#                 0.10707740013272268
#             ],
#             [
#                 1655,
#                 0.10652383171665133
#             ],
#             [
#                 7831,
#                 0.10213131959709884
#             ],
#             [
#                 24082,
#                 0.08588012020653156
#             ],
#             [
#                 14205,
#                 0.0724265120279411
#             ],
#             [
#                 16180,
#                 0.042706389885031136
#             ]
#         ]
#     }
# }

# %%
print(json.dumps(sorted_dict_steer_20_effects, sort_keys=True, indent=4))
# Out:
# {
#     "layer_0": {
#         "anger": [
#             [
#                 22318,
#                 0.6426368607874716
#             ],
#             [
#                 17628,
#                 0.6426368607874716
#             ],
#             [
#                 12030,
#                 0.6426368607874716
#             ],
#             [
#                 800,
#                 0.6426368607874716
#             ],
#             [
#                 22574,
#                 0.5185746304065922
#             ],
#             [
#                 13668,
#                 0.511182783635539
#             ]
#         ],
#         "fear": [
#             [
#                 8167,
#                 0.6203960348901981
#             ],
#             [
#                 634,
#                 0.6203960348901981
#             ],
#             [
#                 22447,
#                 0.6203960348901981
#             ],
#             [
#                 15196,
#                 0.6203960348901981
#             ],
#             [
#                 8194,
#                 0.6203960348901981
#             ],
#             [
#                 2288,
#                 0.6203960348901981
#             ],
#             [
#                 23219,
#                 0.6203960348901981
#             ],
#             [
#                 4783,
#                 0.6203960348901981
#             ],
#             [
#                 6938,
#                 0.6203960348901981
#             ],
#             [
#                 2998,
#                 0.45143754457661933
#             ],
#             [
#                 13200,
#                 0.31509620952094003
#             ]
#         ],
#         "joy": [
#             [
#                 16670,
#                 0.6900749503973443
#             ],
#             [
#                 15464,
#                 0.6900749503973443
#             ],
#             [
#                 10924,
#                 0.6625710332010968
#             ],
#             [
#                 1432,
#                 0.5959554323444414
#             ],
#             [
#                 8699,
#                 0.5585734434708455
#             ],
#             [
#                 13808,
#                 0.5314262530688707
#             ]
#         ],
#         "love": [
#             [
#                 24486,
#                 0.6131471922357722
#             ],
#             [
#                 19618,
#                 0.6131471922357722
#             ],
#             [
#                 3970,
#                 0.6131471922357722
#             ],
#             [
#                 7792,
#                 0.6131471922357722
#             ],
#             [
#                 13985,
#                 0.6131471922357722
#             ],
#             [
#                 4892,
#                 0.6131471922357722
#             ],
#             [
#                 7099,
#                 0.6131471922357722
#             ],
#             [
#                 21219,
#                 0.4043770850216072
#             ]
#         ],
#         "sadness": [
#             [
#                 23208,
#                 0.6900749503973443
#             ],
#             [
#                 14158,
#                 0.6900749503973443
#             ],
#             [
#                 10882,
#                 0.6900749503973443
#             ],
#             [
#                 10510,
#                 0.6900749503973443
#             ],
#             [
#                 546,
#                 0.6900749503973443
#             ],
#             [
#                 12266,
#                 0.3342725627650204
#             ]
#         ],
#         "surprise": [
#             [
#                 16023,
#                 0.8325546111576977
#             ],
#             [
#                 15694,
#                 0.8325546111576977
#             ],
#             [
#                 5029,
#                 0.7577871646041856
#             ],
#             [
#                 2031,
#                 0.6025099633716728
#             ],
#             [
#                 8279,
#                 0.5919696474543303
#             ],
#             [
#                 14386,
#                 0.37495664510515586
#             ]
#         ]
#     },
#     "layer_1": {
#         "anger": [
#             [
#                 20851,
#                 0.5214795089915476
#             ],
#             [
#                 10403,
#                 0.4676081660596984
#             ],
#             [
#                 13745,
#                 0.39781426442501144
#             ],
#             [
#                 11541,
#                 0.33140095954810417
#             ],
#             [
#                 4194,
#                 0.14910846922091406
#             ]
#         ],
#         "fear": [
#             [
#                 21612,
#                 0.5760966182475238
#             ],
#             [
#                 23954,
#                 0.571408040781233
#             ],
#             [
#                 20821,
#                 0.48221996956878665
#             ],
#             [
#                 6767,
#                 0.428088872994614
#             ],
#             [
#                 6146,
#                 0.36742756210967953
#             ],
#             [
#                 19325,
#                 0.3563546410820462
#             ],
#             [
#                 21153,
#                 0.22387984964346658
#             ],
#             [
#                 21826,
#                 0.19777785301015682
#             ],
#             [
#                 5186,
#                 0.18125375741600333
#             ]
#         ],
#         "joy": [
#             [
#                 7683,
#                 0.6206462239567553
#             ],
#             [
#                 6284,
#                 0.5301733310474793
#             ],
#             [
#                 11250,
#                 0.47956035798471486
#             ],
#             [
#                 17653,
#                 0.39495912102757147
#             ],
#             [
#                 3591,
#                 0.3645350187825248
#             ],
#             [
#                 24040,
#                 0.28238841744460363
#             ],
#             [
#                 23750,
#                 0.21743362694478516
#             ],
#             [
#                 18120,
#                 0.1791957953130178
#             ]
#         ],
#         "love": [
#             [
#                 14230,
#                 0.504940280913662
#             ],
#             [
#                 3091,
#                 0.3562953872645034
#             ],
#             [
#                 6847,
#                 0.334752679737321
#             ],
#             [
#                 4332,
#                 0.1702812592246092
#             ],
#             [
#                 150,
#                 0.1634181359866628
#             ]
#         ],
#         "sadness": [
#             [
#                 8419,
#                 0.6736934644883411
#             ],
#             [
#                 24104,
#                 0.5865597993302438
#             ],
#             [
#                 15771,
#                 0.4396637273220242
#             ],
#             [
#                 8174,
#                 0.19801128899830597
#             ]
#         ],
#         "surprise": [
#             [
#                 666,
#                 0.37204633503287937
#             ],
#             [
#                 18239,
#                 0.316270386019781
#             ],
#             [
#                 2037,
#                 0.2904005654613239
#             ],
#             [
#                 487,
#                 0.2678868140364526
#             ],
#             [
#                 16125,
#                 0.20496178059616083
#             ],
#             [
#                 23779,
#                 0.19698728287803097
#             ],
#             [
#                 8551,
#                 0.17426933656653762
#             ],
#             [
#                 12718,
#                 0.16601482333810866
#             ]
#         ]
#     },
#     "layer_10": {
#         "anger": [
#             [
#                 19957,
#                 0.08623285921361097
#             ],
#             [
#                 5203,
#                 0.0840580064126932
#             ],
#             [
#                 14697,
#                 0.04051492584496619
#             ]
#         ],
#         "fear": [
#             [
#                 18367,
#                 0.1318149815149412
#             ],
#             [
#                 6260,
#                 0.11113639097665096
#             ],
#             [
#                 20305,
#                 0.10213766050880989
#             ],
#             [
#                 6822,
#                 0.09873747193694314
#             ],
#             [
#                 2783,
#                 0.08523798972682094
#             ],
#             [
#                 24358,
#                 0.06409808344514091
#             ]
#         ],
#         "joy": [
#             [
#                 809,
#                 0.16163967666215007
#             ],
#             [
#                 5713,
#                 0.10009130379707126
#             ],
#             [
#                 4091,
#                 0.07463285665859269
#             ]
#         ],
#         "love": [
#             [
#                 14654,
#                 0.11838266857366356
#             ],
#             [
#                 130,
#                 0.11814322690192132
#             ],
#             [
#                 20694,
#                 0.09934300492580792
#             ],
#             [
#                 10165,
#                 0.09809741776992752
#             ],
#             [
#                 2095,
#                 0.09169892125411148
#             ],
#             [
#                 19070,
#                 0.0500409427516193
#             ]
#         ],
#         "sadness": [
#             [
#                 11363,
#                 0.15297674270877373
#             ]
#         ],
#         "surprise": [
#             [
#                 20367,
#                 0.13531849404228805
#             ],
#             [
#                 18509,
#                 0.12322311870974804
#             ],
#             [
#                 9733,
#                 0.10619796551625581
#             ],
#             [
#                 23922,
#                 0.08809041568442581
#             ],
#             [
#                 6227,
#                 0.08044877223211089
#             ],
#             [
#                 184,
#                 0.0795201668873627
#             ],
#             [
#                 2150,
#                 0.07524032947330406
#             ],
#             [
#                 14901,
#                 0.07412123160452701
#             ],
#             [
#                 7658,
#                 0.06641697762885396
#             ],
#             [
#                 23723,
#                 0.06538013080208098
#             ]
#         ]
#     },
#     "layer_11": {
#         "anger": [
#             [
#                 21754,
#                 0.11578382149103829
#             ],
#             [
#                 14410,
#                 0.10168033047963088
#             ],
#             [
#                 8427,
#                 0.05823129528507294
#             ],
#             [
#                 12214,
#                 0.04711889247649208
#             ],
#             [
#                 20367,
#                 0.03341939619277366
#             ]
#         ],
#         "fear": [
#             [
#                 9550,
#                 0.10915945457454701
#             ],
#             [
#                 13374,
#                 0.06907980725290445
#             ],
#             [
#                 12092,
#                 0.062930503108082
#             ],
#             [
#                 165,
#                 0.055546751290756695
#             ],
#             [
#                 13554,
#                 0.050573745401259564
#             ],
#             [
#                 14324,
#                 0.04638367764477975
#             ],
#             [
#                 24256,
#                 0.043794314088001315
#             ],
#             [
#                 20934,
#                 0.04216383754422474
#             ],
#             [
#                 9703,
#                 0.017362469960508557
#             ]
#         ],
#         "joy": [
#             [
#                 4943,
#                 0.08157081029772104
#             ],
#             [
#                 8946,
#                 0.04532830289072134
#             ]
#         ],
#         "love": [
#             [
#                 6694,
#                 0.10109361221721505
#             ],
#             [
#                 15057,
#                 0.08981374974551003
#             ],
#             [
#                 12316,
#                 0.07891690012107819
#             ],
#             [
#                 4407,
#                 0.07813330368595195
#             ],
#             [
#                 6390,
#                 0.051488804190592444
#             ]
#         ],
#         "sadness": [
#             [
#                 3334,
#                 0.07692967869445858
#             ],
#             [
#                 24428,
#                 0.047281798120880174
#             ],
#             [
#                 16896,
#                 0.03693486022526029
#             ]
#         ],
#         "surprise": [
#             [
#                 4452,
#                 0.13450115384645203
#             ],
#             [
#                 17777,
#                 0.11574238695007016
#             ],
#             [
#                 17670,
#                 0.10221279203168947
#             ],
#             [
#                 12189,
#                 0.09963687287867697
#             ],
#             [
#                 5047,
#                 0.09151840261579289
#             ],
#             [
#                 22471,
#                 0.08539735835263314
#             ],
#             [
#                 949,
#                 0.08281936929001357
#             ],
#             [
#                 15556,
#                 0.0735352943785579
#             ],
#             [
#                 22203,
#                 0.06332492679685887
#             ],
#             [
#                 17411,
#                 0.049771382201835745
#             ],
#             [
#                 5820,
#                 0.04229976370721881
#             ],
#             [
#                 21799,
#                 0.03491064789711906
#             ],
#             [
#                 3086,
#                 0.02950596771688512
#             ]
#         ]
#     },
#     "layer_2": {
#         "anger": [
#             [
#                 4707,
#                 0.5108683334322573
#             ],
#             [
#                 1550,
#                 0.50843086619925
#             ],
#             [
#                 14918,
#                 0.5010800618472416
#             ],
#             [
#                 21165,
#                 0.48563178905351534
#             ],
#             [
#                 252,
#                 0.39861539932756285
#             ],
#             [
#                 21027,
#                 0.28686177630046367
#             ],
#             [
#                 18357,
#                 0.1915820100709908
#             ],
#             [
#                 11085,
#                 0.16058625050543932
#             ],
#             [
#                 5526,
#                 0.11978103185995854
#             ]
#         ],
#         "fear": [
#             [
#                 24422,
#                 0.5212642857965966
#             ],
#             [
#                 21011,
#                 0.5019967588825527
#             ],
#             [
#                 9937,
#                 0.47567579351520745
#             ],
#             [
#                 18350,
#                 0.4254780714152799
#             ],
#             [
#                 20309,
#                 0.4205399527153864
#             ],
#             [
#                 10882,
#                 0.4129365206984076
#             ],
#             [
#                 22815,
#                 0.2917599694059094
#             ],
#             [
#                 5843,
#                 0.2416236711945626
#             ],
#             [
#                 12026,
#                 0.105852537490799
#             ]
#         ],
#         "joy": [
#             [
#                 13928,
#                 0.6478859922432403
#             ],
#             [
#                 7796,
#                 0.5820586393855772
#             ],
#             [
#                 22134,
#                 0.5393734195133569
#             ],
#             [
#                 3879,
#                 0.5302285766712713
#             ],
#             [
#                 23476,
#                 0.38893026848544443
#             ],
#             [
#                 3456,
#                 0.38228374431848106
#             ],
#             [
#                 23405,
#                 0.3302536214573834
#             ]
#         ],
#         "love": [
#             [
#                 3203,
#                 0.37924170700248633
#             ]
#         ],
#         "sadness": [
#             [
#                 2442,
#                 0.6452466603770844
#             ],
#             [
#                 14915,
#                 0.4813775355555935
#             ],
#             [
#                 11568,
#                 0.47322093645768415
#             ],
#             [
#                 11683,
#                 0.42081808597833864
#             ],
#             [
#                 4350,
#                 0.1584272296326534
#             ]
#         ],
#         "surprise": [
#             [
#                 10353,
#                 0.6131958493389996
#             ],
#             [
#                 15076,
#                 0.368039610612097
#             ],
#             [
#                 11631,
#                 0.3198549849755218
#             ],
#             [
#                 7902,
#                 0.261921834402286
#             ],
#             [
#                 7800,
#                 0.22873541575475864
#             ],
#             [
#                 11365,
#                 0.15984416639382695
#             ]
#         ]
#     },
#     "layer_3": {
#         "anger": [
#             [
#                 16043,
#                 0.4962056041813992
#             ],
#             [
#                 13819,
#                 0.45146558626802463
#             ],
#             [
#                 412,
#                 0.37183553303691563
#             ],
#             [
#                 3213,
#                 0.34561673674811416
#             ],
#             [
#                 9272,
#                 0.3233070953082321
#             ],
#             [
#                 24133,
#                 0.14751524053874
#             ]
#         ],
#         "fear": [
#             [
#                 9805,
#                 0.5289272095648475
#             ],
#             [
#                 1861,
#                 0.5039905131847776
#             ],
#             [
#                 8914,
#                 0.47987423725282824
#             ],
#             [
#                 6134,
#                 0.45112909849860106
#             ],
#             [
#                 22236,
#                 0.44961604692317886
#             ],
#             [
#                 6653,
#                 0.4366303014822455
#             ],
#             [
#                 18762,
#                 0.4102512036199883
#             ],
#             [
#                 20126,
#                 0.2802759984803786
#             ],
#             [
#                 2253,
#                 0.26051092689387567
#             ],
#             [
#                 8135,
#                 0.23598600055857363
#             ],
#             [
#                 20588,
#                 0.1626440887538156
#             ],
#             [
#                 20648,
#                 0.11201946624118156
#             ]
#         ],
#         "joy": [
#             [
#                 10990,
#                 0.5970141484237302
#             ],
#             [
#                 5329,
#                 0.5268244846783059
#             ],
#             [
#                 9828,
#                 0.469199236533968
#             ],
#             [
#                 10739,
#                 0.4167313852512651
#             ],
#             [
#                 6001,
#                 0.34492645291440993
#             ],
#             [
#                 19341,
#                 0.19066796395594293
#             ],
#             [
#                 14625,
#                 0.1159198298080156
#             ]
#         ],
#         "love": [
#             [
#                 15927,
#                 0.5233168196423317
#             ],
#             [
#                 14981,
#                 0.4401825545861473
#             ],
#             [
#                 23271,
#                 0.3476664524658161
#             ],
#             [
#                 11815,
#                 0.34291632006121886
#             ],
#             [
#                 5501,
#                 0.12228440205994488
#             ]
#         ],
#         "sadness": [
#             [
#                 14290,
#                 0.6592500608490731
#             ],
#             [
#                 24469,
#                 0.5718893583016912
#             ],
#             [
#                 22098,
#                 0.5166223965251571
#             ],
#             [
#                 24140,
#                 0.2868847779734347
#             ]
#         ],
#         "surprise": [
#             [
#                 14434,
#                 0.3918928747865469
#             ],
#             [
#                 17365,
#                 0.2996227770710999
#             ],
#             [
#                 3282,
#                 0.2784073977936605
#             ],
#             [
#                 3625,
#                 0.22414314560759557
#             ],
#             [
#                 23140,
#                 0.20884452249434482
#             ],
#             [
#                 10647,
#                 0.1791914935402091
#             ],
#             [
#                 972,
#                 0.17683250670476752
#             ],
#             [
#                 10958,
#                 0.15591592185574008
#             ],
#             [
#                 17827,
#                 0.1555771879003597
#             ]
#         ]
#     },
#     "layer_4": {
#         "anger": [
#             [
#                 11510,
#                 0.4393494829060536
#             ],
#             [
#                 18320,
#                 0.4124444112970954
#             ],
#             [
#                 9072,
#                 0.30778904657684564
#             ],
#             [
#                 3810,
#                 0.29534287193277825
#             ],
#             [
#                 15004,
#                 0.2599730820078979
#             ],
#             [
#                 11183,
#                 0.16421437259892332
#             ],
#             [
#                 16080,
#                 0.12616890239031509
#             ],
#             [
#                 22695,
#                 0.0875420489945724
#             ]
#         ],
#         "fear": [
#             [
#                 15882,
#                 0.5099847856450525
#             ],
#             [
#                 2955,
#                 0.5002759221660733
#             ],
#             [
#                 24553,
#                 0.4818682972675023
#             ],
#             [
#                 16651,
#                 0.4583757304421018
#             ],
#             [
#                 12290,
#                 0.3635917581918765
#             ],
#             [
#                 20655,
#                 0.31498132356321584
#             ],
#             [
#                 14836,
#                 0.26838448037129853
#             ],
#             [
#                 18321,
#                 0.2072194921759181
#             ],
#             [
#                 13386,
#                 0.20662592386996165
#             ],
#             [
#                 4338,
#                 0.14043983301191357
#             ]
#         ],
#         "joy": [
#             [
#                 9569,
#                 0.5275363784499418
#             ],
#             [
#                 8244,
#                 0.40842137948901497
#             ],
#             [
#                 12298,
#                 0.3113406866193559
#             ],
#             [
#                 22722,
#                 0.19878485663678228
#             ],
#             [
#                 15968,
#                 0.159798791529303
#             ]
#         ],
#         "love": [
#             [
#                 9757,
#                 0.48445232961569
#             ],
#             [
#                 10750,
#                 0.41874656792931325
#             ],
#             [
#                 7249,
#                 0.21111102413172186
#             ],
#             [
#                 4004,
#                 0.13696078983619253
#             ]
#         ],
#         "sadness": [
#             [
#                 10051,
#                 0.6533227708148979
#             ],
#             [
#                 23292,
#                 0.533009836602117
#             ],
#             [
#                 9341,
#                 0.43933190549993906
#             ],
#             [
#                 5179,
#                 0.31853708257843333
#             ],
#             [
#                 7494,
#                 0.16039840737324626
#             ],
#             [
#                 22033,
#                 0.14767154824800421
#             ]
#         ],
#         "surprise": [
#             [
#                 19967,
#                 0.3475159358157475
#             ],
#             [
#                 24019,
#                 0.282026960844354
#             ],
#             [
#                 12758,
#                 0.2569482060464797
#             ],
#             [
#                 9661,
#                 0.22621823062822202
#             ],
#             [
#                 16649,
#                 0.17579026654088142
#             ],
#             [
#                 19514,
#                 0.14761510802272368
#             ],
#             [
#                 15250,
#                 0.08509002323424154
#             ]
#         ]
#     },
#     "layer_5": {
#         "anger": [
#             [
#                 9706,
#                 0.4930797894343725
#             ],
#             [
#                 9559,
#                 0.3877473836126453
#             ],
#             [
#                 1773,
#                 0.38762251788852314
#             ],
#             [
#                 5136,
#                 0.1698357550231458
#             ],
#             [
#                 330,
#                 0.10676877643125651
#             ]
#         ],
#         "fear": [
#             [
#                 2212,
#                 0.46079473033849466
#             ],
#             [
#                 24318,
#                 0.43114610419886046
#             ],
#             [
#                 21689,
#                 0.4059665882972029
#             ],
#             [
#                 15844,
#                 0.19098461708742767
#             ],
#             [
#                 5990,
#                 0.1807575401923832
#             ],
#             [
#                 7952,
#                 0.17468072231521836
#             ],
#             [
#                 6801,
#                 0.09430149059476998
#             ],
#             [
#                 15747,
#                 0.08834701664559391
#             ]
#         ],
#         "joy": [
#             [
#                 14404,
#                 0.44409667548275233
#             ],
#             [
#                 6803,
#                 0.3957597431206345
#             ],
#             [
#                 13678,
#                 0.385554720970879
#             ],
#             [
#                 14997,
#                 0.33717630583806896
#             ],
#             [
#                 1255,
#                 0.29141689360414413
#             ],
#             [
#                 17170,
#                 0.2515157940256156
#             ]
#         ],
#         "love": [
#             [
#                 18288,
#                 0.5124019446793939
#             ],
#             [
#                 4600,
#                 0.40961268620853364
#             ],
#             [
#                 13689,
#                 0.3636011074012676
#             ],
#             [
#                 23060,
#                 0.22001158344154403
#             ],
#             [
#                 3674,
#                 0.19408262009600116
#             ],
#             [
#                 3448,
#                 0.16914460403871534
#             ],
#             [
#                 12473,
#                 0.16296652864128636
#             ]
#         ],
#         "sadness": [
#             [
#                 22889,
#                 0.6362044452741943
#             ],
#             [
#                 1265,
#                 0.38942862163750336
#             ]
#         ],
#         "surprise": [
#             [
#                 16559,
#                 0.35171095134921226
#             ],
#             [
#                 9884,
#                 0.2657927398166918
#             ],
#             [
#                 3546,
#                 0.2642457088077313
#             ],
#             [
#                 14750,
#                 0.2609074950453956
#             ],
#             [
#                 6011,
#                 0.2220253365384586
#             ],
#             [
#                 7516,
#                 0.21897053472083883
#             ],
#             [
#                 2877,
#                 0.20765453538574985
#             ],
#             [
#                 23920,
#                 0.2040587210411885
#             ],
#             [
#                 3055,
#                 0.17073032069959554
#             ],
#             [
#                 21258,
#                 0.16392415533702145
#             ],
#             [
#                 17557,
#                 0.15811427505133385
#             ]
#         ]
#     },
#     "layer_6": {
#         "anger": [
#             [
#                 20521,
#                 0.4572201235632718
#             ],
#             [
#                 6415,
#                 0.44142938783706637
#             ],
#             [
#                 10131,
#                 0.3248564797561769
#             ],
#             [
#                 16530,
#                 0.3231619455786411
#             ],
#             [
#                 15780,
#                 0.20936765117002468
#             ],
#             [
#                 21846,
#                 0.17405161161905897
#             ]
#         ],
#         "fear": [
#             [
#                 19068,
#                 0.4475718144065679
#             ],
#             [
#                 2260,
#                 0.3958519055908838
#             ],
#             [
#                 20211,
#                 0.38023939336474116
#             ],
#             [
#                 3246,
#                 0.3526797111946635
#             ],
#             [
#                 6685,
#                 0.3014049003735346
#             ],
#             [
#                 2459,
#                 0.21288577679930487
#             ],
#             [
#                 5289,
#                 0.15265222452603944
#             ],
#             [
#                 18781,
#                 0.13800551434883154
#             ],
#             [
#                 20520,
#                 0.12815160760680006
#             ],
#             [
#                 12900,
#                 0.0927755092771558
#             ]
#         ],
#         "joy": [
#             [
#                 14968,
#                 0.5344566426760966
#             ],
#             [
#                 9995,
#                 0.4667836187706595
#             ],
#             [
#                 203,
#                 0.44783143363900724
#             ],
#             [
#                 18199,
#                 0.3199709124931193
#             ],
#             [
#                 3020,
#                 0.2995921634609022
#             ],
#             [
#                 2617,
#                 0.20815450528502338
#             ]
#         ],
#         "love": [
#             [
#                 11397,
#                 0.3932678494976378
#             ],
#             [
#                 19727,
#                 0.35406235370376926
#             ],
#             [
#                 16022,
#                 0.3319243903330668
#             ],
#             [
#                 14808,
#                 0.18698828840010268
#             ]
#         ],
#         "sadness": [
#             [
#                 20719,
#                 0.4188080017246683
#             ],
#             [
#                 251,
#                 0.30267680982590506
#             ]
#         ],
#         "surprise": [
#             [
#                 17678,
#                 0.3263790439720347
#             ],
#             [
#                 2328,
#                 0.2455944915274588
#             ],
#             [
#                 9978,
#                 0.22404406951968134
#             ],
#             [
#                 18954,
#                 0.22256499625552034
#             ],
#             [
#                 13502,
#                 0.18841500705596356
#             ],
#             [
#                 21364,
#                 0.184128058939305
#             ],
#             [
#                 6315,
#                 0.16180571044716244
#             ],
#             [
#                 14477,
#                 0.15905051601425213
#             ],
#             [
#                 19798,
#                 0.14463409980342282
#             ],
#             [
#                 3036,
#                 0.1422751901506246
#             ],
#             [
#                 9678,
#                 0.11479110608239484
#             ]
#         ]
#     },
#     "layer_7": {
#         "anger": [
#             [
#                 1776,
#                 0.19509365917521224
#             ],
#             [
#                 10033,
#                 0.11603555053771646
#             ]
#         ],
#         "fear": [
#             [
#                 5211,
#                 0.40756768583873526
#             ],
#             [
#                 15862,
#                 0.37711548613625046
#             ],
#             [
#                 19010,
#                 0.31544170135952604
#             ],
#             [
#                 14791,
#                 0.26254967100265253
#             ],
#             [
#                 13519,
#                 0.2230033993059342
#             ],
#             [
#                 4505,
#                 0.2089425260682492
#             ],
#             [
#                 17128,
#                 0.16709940914971447
#             ],
#             [
#                 18892,
#                 0.1669388676482805
#             ],
#             [
#                 13863,
#                 0.13967974926152998
#             ],
#             [
#                 17463,
#                 0.0970867592609489
#             ]
#         ],
#         "joy": [
#             [
#                 19547,
#                 0.2645227298927844
#             ],
#             [
#                 24314,
#                 0.14250714198522998
#             ],
#             [
#                 17025,
#                 0.13805766618669893
#             ]
#         ],
#         "love": [
#             [
#                 2715,
#                 0.3168869421140775
#             ],
#             [
#                 2887,
#                 0.23803413251290045
#             ],
#             [
#                 19662,
#                 0.19957039646214217
#             ]
#         ],
#         "sadness": [
#             [
#                 2045,
#                 0.4415969060058746
#             ]
#         ],
#         "surprise": [
#             [
#                 20417,
#                 0.22211968436912893
#             ],
#             [
#                 10849,
#                 0.21396382371879144
#             ],
#             [
#                 8442,
#                 0.21221226201606497
#             ],
#             [
#                 15668,
#                 0.20538713017482624
#             ],
#             [
#                 17104,
#                 0.18222414598429398
#             ],
#             [
#                 11750,
#                 0.17210160600216695
#             ],
#             [
#                 8981,
#                 0.14771142369520274
#             ],
#             [
#                 8002,
#                 0.14060300848480894
#             ],
#             [
#                 17837,
#                 0.14036057234317698
#             ],
#             [
#                 12344,
#                 0.11528457491653957
#             ]
#         ]
#     },
#     "layer_8": {
#         "anger": [
#             [
#                 17121,
#                 0.19902977574647152
#             ],
#             [
#                 2133,
#                 0.1607958905400757
#             ],
#             [
#                 22715,
#                 0.10944272015794929
#             ],
#             [
#                 21519,
#                 0.09658232139550386
#             ]
#         ],
#         "fear": [
#             [
#                 17376,
#                 0.26390855646230726
#             ],
#             [
#                 19585,
#                 0.25169391760769994
#             ],
#             [
#                 4810,
#                 0.20262602251278322
#             ],
#             [
#                 8887,
#                 0.16339749364803594
#             ],
#             [
#                 19414,
#                 0.12532519658353597
#             ],
#             [
#                 13796,
#                 0.12093017130446482
#             ],
#             [
#                 4846,
#                 0.10056587671427908
#             ]
#         ],
#         "joy": [
#             [
#                 13433,
#                 0.17801814644353076
#             ],
#             [
#                 13624,
#                 0.154505641688851
#             ],
#             [
#                 8708,
#                 0.15395368477658902
#             ]
#         ],
#         "love": [
#             [
#                 9837,
#                 0.1631667737911828
#             ],
#             [
#                 8631,
#                 0.16301622632359247
#             ],
#             [
#                 2017,
#                 0.15192311019817742
#             ]
#         ],
#         "sadness": [
#             [
#                 7473,
#                 0.25057070197773934
#             ],
#             [
#                 3927,
#                 0.20485117401003242
#             ]
#         ],
#         "surprise": [
#             [
#                 20821,
#                 0.1765724577032459
#             ],
#             [
#                 15512,
#                 0.17649723691992655
#             ],
#             [
#                 4939,
#                 0.1696756270479311
#             ],
#             [
#                 14856,
#                 0.16205112566614885
#             ],
#             [
#                 1366,
#                 0.1578580400415697
#             ],
#             [
#                 12456,
#                 0.14725834868127907
#             ],
#             [
#                 8855,
#                 0.14281701614148742
#             ],
#             [
#                 14571,
#                 0.14198788280829178
#             ],
#             [
#                 20423,
#                 0.11063703384550894
#             ],
#             [
#                 15950,
#                 0.09446301131630665
#             ]
#         ]
#     },
#     "layer_9": {
#         "anger": [
#             [
#                 16663,
#                 0.21473812540887297
#             ],
#             [
#                 7002,
#                 0.19165987648872254
#             ],
#             [
#                 21253,
#                 0.14227579321941125
#             ],
#             [
#                 15510,
#                 0.12585348808072674
#             ]
#         ],
#         "fear": [
#             [
#                 14412,
#                 0.2523558114941905
#             ],
#             [
#                 5563,
#                 0.16224825403285922
#             ],
#             [
#                 1413,
#                 0.11857824542281893
#             ],
#             [
#                 15382,
#                 0.09281098311335982
#             ],
#             [
#                 19535,
#                 0.09177106545976688
#             ],
#             [
#                 20233,
#                 0.04986965340782195
#             ]
#         ],
#         "joy": [
#             [
#                 20850,
#                 0.1956920794849623
#             ],
#             [
#                 7702,
#                 0.1599505987320568
#             ],
#             [
#                 4864,
#                 0.14074204721175307
#             ],
#             [
#                 4288,
#                 0.1319626996286992
#             ],
#             [
#                 1418,
#                 0.06399159932365774
#             ]
#         ],
#         "love": [
#             [
#                 21876,
#                 0.1469545155132451
#             ],
#             [
#                 17442,
#                 0.11701267854432718
#             ],
#             [
#                 9946,
#                 0.11666193263094957
#             ],
#             [
#                 20105,
#                 0.08738932025264082
#             ],
#             [
#                 21303,
#                 0.05451161388276922
#             ]
#         ],
#         "sadness": [
#             [
#                 17773,
#                 0.19092236120522685
#             ],
#             [
#                 10885,
#                 0.1292078931165955
#             ],
#             [
#                 5000,
#                 0.11223734687350946
#             ]
#         ],
#         "surprise": [
#             [
#                 21445,
#                 0.1850345634398196
#             ],
#             [
#                 17898,
#                 0.13615547034093636
#             ],
#             [
#                 14851,
#                 0.1300274898812157
#             ],
#             [
#                 1167,
#                 0.12529097914859502
#             ],
#             [
#                 21532,
#                 0.11987030325248489
#             ],
#             [
#                 7831,
#                 0.09777214876996076
#             ],
#             [
#                 14205,
#                 0.0961427479942547
#             ],
#             [
#                 10719,
#                 0.08937957886027464
#             ],
#             [
#                 24082,
#                 0.08867761913365724
#             ],
#             [
#                 1655,
#                 0.08737819222006589
#             ],
#             [
#                 16180,
#                 0.05907471591346272
#             ]
#         ]
#     }
# }

# %% [markdown]
# ## Explore cosine sims of semantically related features for each layer

# %%
cos_sims_steer_20 = copy.deepcopy(sorted_dict_steer_20_effects)
cos_sim_func = torch.nn.CosineSimilarity(dim=0, eps=1e-08)

for layer_idx in range(len(sorted_dict_steer_20_effects.keys())):

    layer = layer_idx
    # Load SAE for this layer
    sae, cfg_dict, _ = SAE.from_pretrained(
        release = "gpt2-small-res-jb",
        sae_id = f"blocks.{layer_idx}.hook_resid_pre",
        device = device
        )

    # get hook point
    hook_point = sae.cfg.hook_name

    for emotion in sorted_dict_steer_20_effects[f'layer_{layer_idx}']:

        strongest_feature = sorted_dict_steer_20_effects[f'layer_{layer_idx}'][emotion][0][0]
        feat_a = sae.W_dec[strongest_feature]

        cos_sims = [1]
        for i in range(1, len(sorted_dict_steer_20_effects[f'layer_{layer_idx}'][emotion])):
            feat_b = sae.W_dec[sorted_dict_steer_20_effects[f'layer_{layer_idx}'][emotion][i][0]]
            cos_sims.append(cos_sim_func(feat_a, feat_b).cpu().detach().numpy().item())
        
        cos_sims_steer_20[f'layer_{layer_idx}'][emotion] = list(zip([tup[0] for tup in sorted_dict_steer_20_effects[f'layer_{layer_idx}'][emotion]], cos_sims, [tup[1] for tup in sorted_dict_steer_20_effects[f'layer_{layer_idx}'][emotion]]))

# %%
print(json.dumps(cos_sims_steer_20, sort_keys=True, indent=4))
# Out:
# {
#     "layer_0": {
#         "anger": [
#             [
#                 22318,
#                 1,
#                 0.6426368607874716
#             ],
#             [
#                 17628,
#                 0.30661237239837646,
#                 0.6426368607874716
#             ],
#             [
#                 12030,
#                 0.3349297046661377,
#                 0.6426368607874716
#             ],
#             [
#                 800,
#                 0.4166766405105591,
#                 0.6426368607874716
#             ],
#             [
#                 22574,
#                 0.11732331663370132,
#                 0.5185746304065922
#             ],
#             [
#                 13668,
#                 0.15332671999931335,
#                 0.511182783635539
#             ]
#         ],
#         "fear": [
#             [
#                 8167,
#                 1,
#                 0.6203960348901981
#             ],
#             [
#                 634,
#                 0.14560428261756897,
#                 0.6203960348901981
#             ],
#             [
#                 22447,
#                 0.21891945600509644,
#                 0.6203960348901981
#             ],
#             [
#                 15196,
#                 0.25107914209365845,
#                 0.6203960348901981
#             ],
#             [
#                 8194,
#                 0.3683561384677887,
#                 0.6203960348901981
#             ],
#             [
#                 2288,
#                 0.15925851464271545,
#                 0.6203960348901981
#             ],
#             [
#                 23219,
#                 0.13422131538391113,
#                 0.6203960348901981
#             ],
#             [
#                 4783,
#                 0.22424060106277466,
#                 0.6203960348901981
#             ],
#             [
#                 6938,
#                 0.14430366456508636,
#                 0.6203960348901981
#             ],
#             [
#                 2998,
#                 0.14110997319221497,
#                 0.45143754457661933
#             ],
#             [
#                 13200,
#                 0.11182790994644165,
#                 0.31509620952094003
#             ]
#         ],
#         "joy": [
#             [
#                 16670,
#                 1,
#                 0.6900749503973443
#             ],
#             [
#                 15464,
#                 0.5288773775100708,
#                 0.6900749503973443
#             ],
#             [
#                 10924,
#                 0.2858995199203491,
#                 0.6625710332010968
#             ],
#             [
#                 1432,
#                 0.04350403696298599,
#                 0.5959554323444414
#             ],
#             [
#                 8699,
#                 0.21899479627609253,
#                 0.5585734434708455
#             ],
#             [
#                 13808,
#                 0.13073386251926422,
#                 0.5314262530688707
#             ]
#         ],
#         "love": [
#             [
#                 24486,
#                 1,
#                 0.6131471922357722
#             ],
#             [
#                 19618,
#                 0.08911937475204468,
#                 0.6131471922357722
#             ],
#             [
#                 3970,
#                 0.11436371505260468,
#                 0.6131471922357722
#             ],
#             [
#                 7792,
#                 0.13422256708145142,
#                 0.6131471922357722
#             ],
#             [
#                 13985,
#                 0.09803196042776108,
#                 0.6131471922357722
#             ],
#             [
#                 4892,
#                 0.179393470287323,
#                 0.6131471922357722
#             ],
#             [
#                 7099,
#                 0.12044426053762436,
#                 0.6131471922357722
#             ],
#             [
#                 21219,
#                 0.12373705208301544,
#                 0.4043770850216072
#             ]
#         ],
#         "sadness": [
#             [
#                 23208,
#                 1,
#                 0.6900749503973443
#             ],
#             [
#                 14158,
#                 0.19055849313735962,
#                 0.6900749503973443
#             ],
#             [
#                 10882,
#                 0.07049966603517532,
#                 0.6900749503973443
#             ],
#             [
#                 10510,
#                 0.2943267822265625,
#                 0.6900749503973443
#             ],
#             [
#                 546,
#                 0.19590753316879272,
#                 0.6900749503973443
#             ],
#             [
#                 12266,
#                 0.004629200324416161,
#                 0.3342725627650204
#             ]
#         ],
#         "surprise": [
#             [
#                 16023,
#                 1,
#                 0.8325546111576977
#             ],
#             [
#                 15694,
#                 0.6747560501098633,
#                 0.8325546111576977
#             ],
#             [
#                 5029,
#                 0.29556748270988464,
#                 0.7577871646041856
#             ],
#             [
#                 2031,
#                 0.1422814130783081,
#                 0.6025099633716728
#             ],
#             [
#                 8279,
#                 0.11324802041053772,
#                 0.5919696474543303
#             ],
#             [
#                 14386,
#                 0.12419763207435608,
#                 0.37495664510515586
#             ]
#         ]
#     },
#     "layer_1": {
#         "anger": [
#             [
#                 20851,
#                 1,
#                 0.5214795089915476
#             ],
#             [
#                 10403,
#                 0.7261019945144653,
#                 0.4676081660596984
#             ],
#             [
#                 13745,
#                 0.6517045497894287,
#                 0.39781426442501144
#             ],
#             [
#                 11541,
#                 0.24461854994297028,
#                 0.33140095954810417
#             ],
#             [
#                 4194,
#                 0.29464828968048096,
#                 0.14910846922091406
#             ]
#         ],
#         "fear": [
#             [
#                 21612,
#                 1,
#                 0.5760966182475238
#             ],
#             [
#                 23954,
#                 0.6115756034851074,
#                 0.571408040781233
#             ],
#             [
#                 20821,
#                 0.42583394050598145,
#                 0.48221996956878665
#             ],
#             [
#                 6767,
#                 0.6368129849433899,
#                 0.428088872994614
#             ],
#             [
#                 6146,
#                 0.5154646635055542,
#                 0.36742756210967953
#             ],
#             [
#                 19325,
#                 0.1267150193452835,
#                 0.3563546410820462
#             ],
#             [
#                 21153,
#                 0.2838628888130188,
#                 0.22387984964346658
#             ],
#             [
#                 21826,
#                 0.11837665736675262,
#                 0.19777785301015682
#             ],
#             [
#                 5186,
#                 -0.011945820413529873,
#                 0.18125375741600333
#             ]
#         ],
#         "joy": [
#             [
#                 7683,
#                 1,
#                 0.6206462239567553
#             ],
#             [
#                 6284,
#                 0.588939905166626,
#                 0.5301733310474793
#             ],
#             [
#                 11250,
#                 0.49702322483062744,
#                 0.47956035798471486
#             ],
#             [
#                 17653,
#                 0.36017996072769165,
#                 0.39495912102757147
#             ],
#             [
#                 3591,
#                 0.4028002619743347,
#                 0.3645350187825248
#             ],
#             [
#                 24040,
#                 0.44001567363739014,
#                 0.28238841744460363
#             ],
#             [
#                 23750,
#                 0.21765340864658356,
#                 0.21743362694478516
#             ],
#             [
#                 18120,
#                 0.30091264843940735,
#                 0.1791957953130178
#             ]
#         ],
#         "love": [
#             [
#                 14230,
#                 1,
#                 0.504940280913662
#             ],
#             [
#                 3091,
#                 0.6069774627685547,
#                 0.3562953872645034
#             ],
#             [
#                 6847,
#                 0.5985791683197021,
#                 0.334752679737321
#             ],
#             [
#                 4332,
#                 0.3240659832954407,
#                 0.1702812592246092
#             ],
#             [
#                 150,
#                 0.04269645735621452,
#                 0.1634181359866628
#             ]
#         ],
#         "sadness": [
#             [
#                 8419,
#                 1,
#                 0.6736934644883411
#             ],
#             [
#                 24104,
#                 0.6223868131637573,
#                 0.5865597993302438
#             ],
#             [
#                 15771,
#                 0.6888639330863953,
#                 0.4396637273220242
#             ],
#             [
#                 8174,
#                 0.2573395371437073,
#                 0.19801128899830597
#             ]
#         ],
#         "surprise": [
#             [
#                 666,
#                 1,
#                 0.37204633503287937
#             ],
#             [
#                 18239,
#                 0.5214537382125854,
#                 0.316270386019781
#             ],
#             [
#                 2037,
#                 0.32372385263442993,
#                 0.2904005654613239
#             ],
#             [
#                 487,
#                 0.2800039052963257,
#                 0.2678868140364526
#             ],
#             [
#                 16125,
#                 0.21148993074893951,
#                 0.20496178059616083
#             ],
#             [
#                 23779,
#                 0.6460616588592529,
#                 0.19698728287803097
#             ],
#             [
#                 8551,
#                 0.05948147922754288,
#                 0.17426933656653762
#             ],
#             [
#                 12718,
#                 0.19390203058719635,
#                 0.16601482333810866
#             ]
#         ]
#     },
#     "layer_10": {
#         "anger": [
#             [
#                 19957,
#                 1,
#                 0.08623285921361097
#             ],
#             [
#                 5203,
#                 0.09274908900260925,
#                 0.0840580064126932
#             ],
#             [
#                 14697,
#                 0.03374909237027168,
#                 0.04051492584496619
#             ]
#         ],
#         "fear": [
#             [
#                 18367,
#                 1,
#                 0.1318149815149412
#             ],
#             [
#                 6260,
#                 0.03593336418271065,
#                 0.11113639097665096
#             ],
#             [
#                 20305,
#                 0.1662580817937851,
#                 0.10213766050880989
#             ],
#             [
#                 6822,
#                 0.1391221582889557,
#                 0.09873747193694314
#             ],
#             [
#                 2783,
#                 0.05773799121379852,
#                 0.08523798972682094
#             ],
#             [
#                 24358,
#                 0.10113662481307983,
#                 0.06409808344514091
#             ]
#         ],
#         "joy": [
#             [
#                 809,
#                 1,
#                 0.16163967666215007
#             ],
#             [
#                 5713,
#                 0.02494841441512108,
#                 0.10009130379707126
#             ],
#             [
#                 4091,
#                 0.009520009160041809,
#                 0.07463285665859269
#             ]
#         ],
#         "love": [
#             [
#                 14654,
#                 1,
#                 0.11838266857366356
#             ],
#             [
#                 130,
#                 0.03852052986621857,
#                 0.11814322690192132
#             ],
#             [
#                 20694,
#                 0.05968725308775902,
#                 0.09934300492580792
#             ],
#             [
#                 10165,
#                 -0.010927915573120117,
#                 0.09809741776992752
#             ],
#             [
#                 2095,
#                 0.06998393684625626,
#                 0.09169892125411148
#             ],
#             [
#                 19070,
#                 0.161062091588974,
#                 0.0500409427516193
#             ]
#         ],
#         "sadness": [
#             [
#                 11363,
#                 1,
#                 0.15297674270877373
#             ]
#         ],
#         "surprise": [
#             [
#                 20367,
#                 1,
#                 0.13531849404228805
#             ],
#             [
#                 18509,
#                 0.013551585376262665,
#                 0.12322311870974804
#             ],
#             [
#                 9733,
#                 0.06029217317700386,
#                 0.10619796551625581
#             ],
#             [
#                 23922,
#                 -0.004201166331768036,
#                 0.08809041568442581
#             ],
#             [
#                 6227,
#                 0.09239734709262848,
#                 0.08044877223211089
#             ],
#             [
#                 184,
#                 0.03014972247183323,
#                 0.0795201668873627
#             ],
#             [
#                 2150,
#                 0.05881562829017639,
#                 0.07524032947330406
#             ],
#             [
#                 14901,
#                 0.06143435835838318,
#                 0.07412123160452701
#             ],
#             [
#                 7658,
#                 0.056523289531469345,
#                 0.06641697762885396
#             ],
#             [
#                 23723,
#                 0.07524491846561432,
#                 0.06538013080208098
#             ]
#         ]
#     },
#     "layer_11": {
#         "anger": [
#             [
#                 21754,
#                 1,
#                 0.11578382149103829
#             ],
#             [
#                 14410,
#                 -0.050099726766347885,
#                 0.10168033047963088
#             ],
#             [
#                 8427,
#                 0.013513220474123955,
#                 0.05823129528507294
#             ],
#             [
#                 12214,
#                 0.07590915262699127,
#                 0.04711889247649208
#             ],
#             [
#                 20367,
#                 0.07800757884979248,
#                 0.03341939619277366
#             ]
#         ],
#         "fear": [
#             [
#                 9550,
#                 1,
#                 0.10915945457454701
#             ],
#             [
#                 13374,
#                 0.21280032396316528,
#                 0.06907980725290445
#             ],
#             [
#                 12092,
#                 0.009367487393319607,
#                 0.062930503108082
#             ],
#             [
#                 165,
#                 0.09986895322799683,
#                 0.055546751290756695
#             ],
#             [
#                 13554,
#                 0.008945208042860031,
#                 0.050573745401259564
#             ],
#             [
#                 14324,
#                 0.15609514713287354,
#                 0.04638367764477975
#             ],
#             [
#                 24256,
#                 0.2173338532447815,
#                 0.043794314088001315
#             ],
#             [
#                 20934,
#                 0.10124589502811432,
#                 0.04216383754422474
#             ],
#             [
#                 9703,
#                 0.07222122699022293,
#                 0.017362469960508557
#             ]
#         ],
#         "joy": [
#             [
#                 4943,
#                 1,
#                 0.08157081029772104
#             ],
#             [
#                 8946,
#                 0.07367405295372009,
#                 0.04532830289072134
#             ]
#         ],
#         "love": [
#             [
#                 6694,
#                 1,
#                 0.10109361221721505
#             ],
#             [
#                 15057,
#                 0.2368050217628479,
#                 0.08981374974551003
#             ],
#             [
#                 12316,
#                 0.06979425251483917,
#                 0.07891690012107819
#             ],
#             [
#                 4407,
#                 0.14104467630386353,
#                 0.07813330368595195
#             ],
#             [
#                 6390,
#                 0.04550687596201897,
#                 0.051488804190592444
#             ]
#         ],
#         "sadness": [
#             [
#                 3334,
#                 1,
#                 0.07692967869445858
#             ],
#             [
#                 24428,
#                 0.18560835719108582,
#                 0.047281798120880174
#             ],
#             [
#                 16896,
#                 0.1113036721944809,
#                 0.03693486022526029
#             ]
#         ],
#         "surprise": [
#             [
#                 4452,
#                 1,
#                 0.13450115384645203
#             ],
#             [
#                 17777,
#                 -0.040279291570186615,
#                 0.11574238695007016
#             ],
#             [
#                 17670,
#                 -0.045881420373916626,
#                 0.10221279203168947
#             ],
#             [
#                 12189,
#                 0.024026785045862198,
#                 0.09963687287867697
#             ],
#             [
#                 5047,
#                 -0.045690201222896576,
#                 0.09151840261579289
#             ],
#             [
#                 22471,
#                 -0.044508196413517,
#                 0.08539735835263314
#             ],
#             [
#                 949,
#                 -0.04850040748715401,
#                 0.08281936929001357
#             ],
#             [
#                 15556,
#                 -0.006019752472639084,
#                 0.0735352943785579
#             ],
#             [
#                 22203,
#                 -0.023359641432762146,
#                 0.06332492679685887
#             ],
#             [
#                 17411,
#                 -0.0019999821670353413,
#                 0.049771382201835745
#             ],
#             [
#                 5820,
#                 -0.015868734568357468,
#                 0.04229976370721881
#             ],
#             [
#                 21799,
#                 0.06563844531774521,
#                 0.03491064789711906
#             ],
#             [
#                 3086,
#                 0.012976694852113724,
#                 0.02950596771688512
#             ]
#         ]
#     },
#     "layer_2": {
#         "anger": [
#             [
#                 4707,
#                 1,
#                 0.5108683334322573
#             ],
#             [
#                 1550,
#                 0.7109501361846924,
#                 0.50843086619925
#             ],
#             [
#                 14918,
#                 0.21855561435222626,
#                 0.5010800618472416
#             ],
#             [
#                 21165,
#                 0.5447418093681335,
#                 0.48563178905351534
#             ],
#             [
#                 252,
#                 0.3914327323436737,
#                 0.39861539932756285
#             ],
#             [
#                 21027,
#                 0.40524929761886597,
#                 0.28686177630046367
#             ],
#             [
#                 18357,
#                 0.11374174803495407,
#                 0.1915820100709908
#             ],
#             [
#                 11085,
#                 0.10830332338809967,
#                 0.16058625050543932
#             ],
#             [
#                 5526,
#                 0.10598623007535934,
#                 0.11978103185995854
#             ]
#         ],
#         "fear": [
#             [
#                 24422,
#                 1,
#                 0.5212642857965966
#             ],
#             [
#                 21011,
#                 0.6458343863487244,
#                 0.5019967588825527
#             ],
#             [
#                 9937,
#                 0.5807356834411621,
#                 0.47567579351520745
#             ],
#             [
#                 18350,
#                 0.6388469934463501,
#                 0.4254780714152799
#             ],
#             [
#                 20309,
#                 0.7982625365257263,
#                 0.4205399527153864
#             ],
#             [
#                 10882,
#                 0.7096896767616272,
#                 0.4129365206984076
#             ],
#             [
#                 22815,
#                 0.3492046594619751,
#                 0.2917599694059094
#             ],
#             [
#                 5843,
#                 0.2694486975669861,
#                 0.2416236711945626
#             ],
#             [
#                 12026,
#                 0.23477941751480103,
#                 0.105852537490799
#             ]
#         ],
#         "joy": [
#             [
#                 13928,
#                 1,
#                 0.6478859922432403
#             ],
#             [
#                 7796,
#                 0.6899735927581787,
#                 0.5820586393855772
#             ],
#             [
#                 22134,
#                 0.5273895263671875,
#                 0.5393734195133569
#             ],
#             [
#                 3879,
#                 0.6115921139717102,
#                 0.5302285766712713
#             ],
#             [
#                 23476,
#                 0.13263440132141113,
#                 0.38893026848544443
#             ],
#             [
#                 3456,
#                 0.43322843313217163,
#                 0.38228374431848106
#             ],
#             [
#                 23405,
#                 0.34257131814956665,
#                 0.3302536214573834
#             ]
#         ],
#         "love": [
#             [
#                 3203,
#                 1,
#                 0.37924170700248633
#             ]
#         ],
#         "sadness": [
#             [
#                 2442,
#                 1,
#                 0.6452466603770844
#             ],
#             [
#                 14915,
#                 0.45385169982910156,
#                 0.4813775355555935
#             ],
#             [
#                 11568,
#                 0.6869579553604126,
#                 0.47322093645768415
#             ],
#             [
#                 11683,
#                 0.3587898015975952,
#                 0.42081808597833864
#             ],
#             [
#                 4350,
#                 -0.07717709243297577,
#                 0.1584272296326534
#             ]
#         ],
#         "surprise": [
#             [
#                 10353,
#                 1,
#                 0.6131958493389996
#             ],
#             [
#                 15076,
#                 0.756019115447998,
#                 0.368039610612097
#             ],
#             [
#                 11631,
#                 0.16083312034606934,
#                 0.3198549849755218
#             ],
#             [
#                 7902,
#                 0.48217707872390747,
#                 0.261921834402286
#             ],
#             [
#                 7800,
#                 0.41898250579833984,
#                 0.22873541575475864
#             ],
#             [
#                 11365,
#                 0.10534092038869858,
#                 0.15984416639382695
#             ]
#         ]
#     },
#     "layer_3": {
#         "anger": [
#             [
#                 16043,
#                 1,
#                 0.4962056041813992
#             ],
#             [
#                 13819,
#                 0.7261377573013306,
#                 0.45146558626802463
#             ],
#             [
#                 412,
#                 0.48689356446266174,
#                 0.37183553303691563
#             ],
#             [
#                 3213,
#                 0.554175853729248,
#                 0.34561673674811416
#             ],
#             [
#                 9272,
#                 0.5195806622505188,
#                 0.3233070953082321
#             ],
#             [
#                 24133,
#                 0.23631955683231354,
#                 0.14751524053874
#             ]
#         ],
#         "fear": [
#             [
#                 9805,
#                 1,
#                 0.5289272095648475
#             ],
#             [
#                 1861,
#                 0.8066787719726562,
#                 0.5039905131847776
#             ],
#             [
#                 8914,
#                 0.7633740901947021,
#                 0.47987423725282824
#             ],
#             [
#                 6134,
#                 0.5556949377059937,
#                 0.45112909849860106
#             ],
#             [
#                 22236,
#                 0.47290217876434326,
#                 0.44961604692317886
#             ],
#             [
#                 6653,
#                 0.6871586441993713,
#                 0.4366303014822455
#             ],
#             [
#                 18762,
#                 0.3961453437805176,
#                 0.4102512036199883
#             ],
#             [
#                 20126,
#                 0.5079413652420044,
#                 0.2802759984803786
#             ],
#             [
#                 2253,
#                 0.22984063625335693,
#                 0.26051092689387567
#             ],
#             [
#                 8135,
#                 0.26449209451675415,
#                 0.23598600055857363
#             ],
#             [
#                 20588,
#                 0.2740037739276886,
#                 0.1626440887538156
#             ],
#             [
#                 20648,
#                 0.16240493953227997,
#                 0.11201946624118156
#             ]
#         ],
#         "joy": [
#             [
#                 10990,
#                 1,
#                 0.5970141484237302
#             ],
#             [
#                 5329,
#                 0.5893313884735107,
#                 0.5268244846783059
#             ],
#             [
#                 9828,
#                 0.5109533667564392,
#                 0.469199236533968
#             ],
#             [
#                 10739,
#                 0.4821523427963257,
#                 0.4167313852512651
#             ],
#             [
#                 6001,
#                 0.658768892288208,
#                 0.34492645291440993
#             ],
#             [
#                 19341,
#                 0.20766694843769073,
#                 0.19066796395594293
#             ],
#             [
#                 14625,
#                 0.07319404184818268,
#                 0.1159198298080156
#             ]
#         ],
#         "love": [
#             [
#                 15927,
#                 1,
#                 0.5233168196423317
#             ],
#             [
#                 14981,
#                 0.34564918279647827,
#                 0.4401825545861473
#             ],
#             [
#                 23271,
#                 0.4715486764907837,
#                 0.3476664524658161
#             ],
#             [
#                 11815,
#                 0.35892727971076965,
#                 0.34291632006121886
#             ],
#             [
#                 5501,
#                 0.20216265320777893,
#                 0.12228440205994488
#             ]
#         ],
#         "sadness": [
#             [
#                 14290,
#                 1,
#                 0.6592500608490731
#             ],
#             [
#                 24469,
#                 0.3531394600868225,
#                 0.5718893583016912
#             ],
#             [
#                 22098,
#                 0.4417746067047119,
#                 0.5166223965251571
#             ],
#             [
#                 24140,
#                 0.47896263003349304,
#                 0.2868847779734347
#             ]
#         ],
#         "surprise": [
#             [
#                 14434,
#                 1,
#                 0.3918928747865469
#             ],
#             [
#                 17365,
#                 0.5762181282043457,
#                 0.2996227770710999
#             ],
#             [
#                 3282,
#                 0.3711344301700592,
#                 0.2784073977936605
#             ],
#             [
#                 3625,
#                 0.1909150779247284,
#                 0.22414314560759557
#             ],
#             [
#                 23140,
#                 0.3931146264076233,
#                 0.20884452249434482
#             ],
#             [
#                 10647,
#                 0.10177415609359741,
#                 0.1791914935402091
#             ],
#             [
#                 972,
#                 0.13158094882965088,
#                 0.17683250670476752
#             ],
#             [
#                 10958,
#                 0.3222191333770752,
#                 0.15591592185574008
#             ],
#             [
#                 17827,
#                 0.17331640422344208,
#                 0.1555771879003597
#             ]
#         ]
#     },
#     "layer_4": {
#         "anger": [
#             [
#                 11510,
#                 1,
#                 0.4393494829060536
#             ],
#             [
#                 18320,
#                 0.7670301795005798,
#                 0.4124444112970954
#             ],
#             [
#                 9072,
#                 0.33299586176872253,
#                 0.30778904657684564
#             ],
#             [
#                 3810,
#                 0.5686273574829102,
#                 0.29534287193277825
#             ],
#             [
#                 15004,
#                 0.4062795341014862,
#                 0.2599730820078979
#             ],
#             [
#                 11183,
#                 0.17466673254966736,
#                 0.16421437259892332
#             ],
#             [
#                 16080,
#                 0.24378728866577148,
#                 0.12616890239031509
#             ],
#             [
#                 22695,
#                 0.08056814968585968,
#                 0.0875420489945724
#             ]
#         ],
#         "fear": [
#             [
#                 15882,
#                 1,
#                 0.5099847856450525
#             ],
#             [
#                 2955,
#                 0.618578314781189,
#                 0.5002759221660733
#             ],
#             [
#                 24553,
#                 0.6651734113693237,
#                 0.4818682972675023
#             ],
#             [
#                 16651,
#                 0.7004886865615845,
#                 0.4583757304421018
#             ],
#             [
#                 12290,
#                 0.7714091539382935,
#                 0.3635917581918765
#             ],
#             [
#                 20655,
#                 0.2714759111404419,
#                 0.31498132356321584
#             ],
#             [
#                 14836,
#                 0.24987319111824036,
#                 0.26838448037129853
#             ],
#             [
#                 18321,
#                 0.30864405632019043,
#                 0.2072194921759181
#             ],
#             [
#                 13386,
#                 0.07028710097074509,
#                 0.20662592386996165
#             ],
#             [
#                 4338,
#                 0.26121580600738525,
#                 0.14043983301191357
#             ]
#         ],
#         "joy": [
#             [
#                 9569,
#                 1,
#                 0.5275363784499418
#             ],
#             [
#                 8244,
#                 0.4367852807044983,
#                 0.40842137948901497
#             ],
#             [
#                 12298,
#                 0.3252795338630676,
#                 0.3113406866193559
#             ],
#             [
#                 22722,
#                 0.05937700718641281,
#                 0.19878485663678228
#             ],
#             [
#                 15968,
#                 0.1134202629327774,
#                 0.159798791529303
#             ]
#         ],
#         "love": [
#             [
#                 9757,
#                 1,
#                 0.48445232961569
#             ],
#             [
#                 10750,
#                 0.39659082889556885,
#                 0.41874656792931325
#             ],
#             [
#                 7249,
#                 0.340706467628479,
#                 0.21111102413172186
#             ],
#             [
#                 4004,
#                 0.17838333547115326,
#                 0.13696078983619253
#             ]
#         ],
#         "sadness": [
#             [
#                 10051,
#                 1,
#                 0.6533227708148979
#             ],
#             [
#                 23292,
#                 0.7151974439620972,
#                 0.533009836602117
#             ],
#             [
#                 9341,
#                 0.4711158871650696,
#                 0.43933190549993906
#             ],
#             [
#                 5179,
#                 0.31707340478897095,
#                 0.31853708257843333
#             ],
#             [
#                 7494,
#                 0.01063959114253521,
#                 0.16039840737324626
#             ],
#             [
#                 22033,
#                 0.04311252385377884,
#                 0.14767154824800421
#             ]
#         ],
#         "surprise": [
#             [
#                 19967,
#                 1,
#                 0.3475159358157475
#             ],
#             [
#                 24019,
#                 0.5733447074890137,
#                 0.282026960844354
#             ],
#             [
#                 12758,
#                 0.10972452908754349,
#                 0.2569482060464797
#             ],
#             [
#                 9661,
#                 0.11084258556365967,
#                 0.22621823062822202
#             ],
#             [
#                 16649,
#                 0.12170542031526566,
#                 0.17579026654088142
#             ],
#             [
#                 19514,
#                 0.02547081559896469,
#                 0.14761510802272368
#             ],
#             [
#                 15250,
#                 0.113282211124897,
#                 0.08509002323424154
#             ]
#         ]
#     },
#     "layer_5": {
#         "anger": [
#             [
#                 9706,
#                 1,
#                 0.4930797894343725
#             ],
#             [
#                 9559,
#                 0.538055956363678,
#                 0.3877473836126453
#             ],
#             [
#                 1773,
#                 0.5019505023956299,
#                 0.38762251788852314
#             ],
#             [
#                 5136,
#                 0.15474370121955872,
#                 0.1698357550231458
#             ],
#             [
#                 330,
#                 0.0677867978811264,
#                 0.10676877643125651
#             ]
#         ],
#         "fear": [
#             [
#                 2212,
#                 1,
#                 0.46079473033849466
#             ],
#             [
#                 24318,
#                 0.5978635549545288,
#                 0.43114610419886046
#             ],
#             [
#                 21689,
#                 0.5703258514404297,
#                 0.4059665882972029
#             ],
#             [
#                 15844,
#                 0.08631076663732529,
#                 0.19098461708742767
#             ],
#             [
#                 5990,
#                 0.0022431211546063423,
#                 0.1807575401923832
#             ],
#             [
#                 7952,
#                 0.3041169345378876,
#                 0.17468072231521836
#             ],
#             [
#                 6801,
#                 -0.01277146302163601,
#                 0.09430149059476998
#             ],
#             [
#                 15747,
#                 0.279133141040802,
#                 0.08834701664559391
#             ]
#         ],
#         "joy": [
#             [
#                 14404,
#                 1,
#                 0.44409667548275233
#             ],
#             [
#                 6803,
#                 0.5000931024551392,
#                 0.3957597431206345
#             ],
#             [
#                 13678,
#                 0.3077109456062317,
#                 0.385554720970879
#             ],
#             [
#                 14997,
#                 0.1426757574081421,
#                 0.33717630583806896
#             ],
#             [
#                 1255,
#                 0.3038829565048218,
#                 0.29141689360414413
#             ],
#             [
#                 17170,
#                 0.5955168008804321,
#                 0.2515157940256156
#             ]
#         ],
#         "love": [
#             [
#                 18288,
#                 1,
#                 0.5124019446793939
#             ],
#             [
#                 4600,
#                 0.5975496768951416,
#                 0.40961268620853364
#             ],
#             [
#                 13689,
#                 0.47264403104782104,
#                 0.3636011074012676
#             ],
#             [
#                 23060,
#                 0.28382793068885803,
#                 0.22001158344154403
#             ],
#             [
#                 3674,
#                 -0.005768731236457825,
#                 0.19408262009600116
#             ],
#             [
#                 3448,
#                 0.006426038220524788,
#                 0.16914460403871534
#             ],
#             [
#                 12473,
#                 0.2857845425605774,
#                 0.16296652864128636
#             ]
#         ],
#         "sadness": [
#             [
#                 22889,
#                 1,
#                 0.6362044452741943
#             ],
#             [
#                 1265,
#                 0.4399958848953247,
#                 0.38942862163750336
#             ]
#         ],
#         "surprise": [
#             [
#                 16559,
#                 1,
#                 0.35171095134921226
#             ],
#             [
#                 9884,
#                 0.33914709091186523,
#                 0.2657927398166918
#             ],
#             [
#                 3546,
#                 0.1805330514907837,
#                 0.2642457088077313
#             ],
#             [
#                 14750,
#                 0.072517029941082,
#                 0.2609074950453956
#             ],
#             [
#                 6011,
#                 0.21299102902412415,
#                 0.2220253365384586
#             ],
#             [
#                 7516,
#                 0.2870073914527893,
#                 0.21897053472083883
#             ],
#             [
#                 2877,
#                 0.21246720850467682,
#                 0.20765453538574985
#             ],
#             [
#                 23920,
#                 0.33994176983833313,
#                 0.2040587210411885
#             ],
#             [
#                 3055,
#                 0.09709233045578003,
#                 0.17073032069959554
#             ],
#             [
#                 21258,
#                 0.17374971508979797,
#                 0.16392415533702145
#             ],
#             [
#                 17557,
#                 0.3721271753311157,
#                 0.15811427505133385
#             ]
#         ]
#     },
#     "layer_6": {
#         "anger": [
#             [
#                 20521,
#                 1,
#                 0.4572201235632718
#             ],
#             [
#                 6415,
#                 0.15799331665039062,
#                 0.44142938783706637
#             ],
#             [
#                 10131,
#                 0.09693184494972229,
#                 0.3248564797561769
#             ],
#             [
#                 16530,
#                 0.13421019911766052,
#                 0.3231619455786411
#             ],
#             [
#                 15780,
#                 0.14461687207221985,
#                 0.20936765117002468
#             ],
#             [
#                 21846,
#                 0.08765782415866852,
#                 0.17405161161905897
#             ]
#         ],
#         "fear": [
#             [
#                 19068,
#                 1,
#                 0.4475718144065679
#             ],
#             [
#                 2260,
#                 0.44185546040534973,
#                 0.3958519055908838
#             ],
#             [
#                 20211,
#                 0.7070258259773254,
#                 0.38023939336474116
#             ],
#             [
#                 3246,
#                 0.4758360981941223,
#                 0.3526797111946635
#             ],
#             [
#                 6685,
#                 0.3372601270675659,
#                 0.3014049003735346
#             ],
#             [
#                 2459,
#                 0.25263679027557373,
#                 0.21288577679930487
#             ],
#             [
#                 5289,
#                 0.08317866921424866,
#                 0.15265222452603944
#             ],
#             [
#                 18781,
#                 0.09583388268947601,
#                 0.13800551434883154
#             ],
#             [
#                 20520,
#                 0.13951966166496277,
#                 0.12815160760680006
#             ],
#             [
#                 12900,
#                 0.0986354649066925,
#                 0.0927755092771558
#             ]
#         ],
#         "joy": [
#             [
#                 14968,
#                 1,
#                 0.5344566426760966
#             ],
#             [
#                 9995,
#                 0.5050569772720337,
#                 0.4667836187706595
#             ],
#             [
#                 203,
#                 0.18582533299922943,
#                 0.44783143363900724
#             ],
#             [
#                 18199,
#                 0.37103456258773804,
#                 0.3199709124931193
#             ],
#             [
#                 3020,
#                 0.06504881381988525,
#                 0.2995921634609022
#             ],
#             [
#                 2617,
#                 0.3202481269836426,
#                 0.20815450528502338
#             ]
#         ],
#         "love": [
#             [
#                 11397,
#                 1,
#                 0.3932678494976378
#             ],
#             [
#                 19727,
#                 0.3883468806743622,
#                 0.35406235370376926
#             ],
#             [
#                 16022,
#                 0.19206950068473816,
#                 0.3319243903330668
#             ],
#             [
#                 14808,
#                 -0.03217412531375885,
#                 0.18698828840010268
#             ]
#         ],
#         "sadness": [
#             [
#                 20719,
#                 1,
#                 0.4188080017246683
#             ],
#             [
#                 251,
#                 0.22027625143527985,
#                 0.30267680982590506
#             ]
#         ],
#         "surprise": [
#             [
#                 17678,
#                 1,
#                 0.3263790439720347
#             ],
#             [
#                 2328,
#                 0.037712447345256805,
#                 0.2455944915274588
#             ],
#             [
#                 9978,
#                 0.2127104252576828,
#                 0.22404406951968134
#             ],
#             [
#                 18954,
#                 0.01862742379307747,
#                 0.22256499625552034
#             ],
#             [
#                 13502,
#                 0.43437281250953674,
#                 0.18841500705596356
#             ],
#             [
#                 21364,
#                 0.16919410228729248,
#                 0.184128058939305
#             ],
#             [
#                 6315,
#                 0.2858494520187378,
#                 0.16180571044716244
#             ],
#             [
#                 14477,
#                 0.09161025285720825,
#                 0.15905051601425213
#             ],
#             [
#                 19798,
#                 -0.0015201568603515625,
#                 0.14463409980342282
#             ],
#             [
#                 3036,
#                 0.0268726646900177,
#                 0.1422751901506246
#             ],
#             [
#                 9678,
#                 -0.00700276717543602,
#                 0.11479110608239484
#             ]
#         ]
#     },
#     "layer_7": {
#         "anger": [
#             [
#                 1776,
#                 1,
#                 0.19509365917521224
#             ],
#             [
#                 10033,
#                 0.1706317514181137,
#                 0.11603555053771646
#             ]
#         ],
#         "fear": [
#             [
#                 5211,
#                 1,
#                 0.40756768583873526
#             ],
#             [
#                 15862,
#                 0.48561957478523254,
#                 0.37711548613625046
#             ],
#             [
#                 19010,
#                 0.39256322383880615,
#                 0.31544170135952604
#             ],
#             [
#                 14791,
#                 0.2774255871772766,
#                 0.26254967100265253
#             ],
#             [
#                 13519,
#                 0.2346014827489853,
#                 0.2230033993059342
#             ],
#             [
#                 4505,
#                 0.0924084335565567,
#                 0.2089425260682492
#             ],
#             [
#                 17128,
#                 -0.00709292758256197,
#                 0.16709940914971447
#             ],
#             [
#                 18892,
#                 0.17805129289627075,
#                 0.1669388676482805
#             ],
#             [
#                 13863,
#                 0.0015267841517925262,
#                 0.13967974926152998
#             ],
#             [
#                 17463,
#                 -0.024567686021327972,
#                 0.0970867592609489
#             ]
#         ],
#         "joy": [
#             [
#                 19547,
#                 1,
#                 0.2645227298927844
#             ],
#             [
#                 24314,
#                 0.032760489732027054,
#                 0.14250714198522998
#             ],
#             [
#                 17025,
#                 0.07954329252243042,
#                 0.13805766618669893
#             ]
#         ],
#         "love": [
#             [
#                 2715,
#                 1,
#                 0.3168869421140775
#             ],
#             [
#                 2887,
#                 0.4328603744506836,
#                 0.23803413251290045
#             ],
#             [
#                 19662,
#                 0.018454205244779587,
#                 0.19957039646214217
#             ]
#         ],
#         "sadness": [
#             [
#                 2045,
#                 1,
#                 0.4415969060058746
#             ]
#         ],
#         "surprise": [
#             [
#                 20417,
#                 1,
#                 0.22211968436912893
#             ],
#             [
#                 10849,
#                 -0.011162716895341873,
#                 0.21396382371879144
#             ],
#             [
#                 8442,
#                 0.06689639389514923,
#                 0.21221226201606497
#             ],
#             [
#                 15668,
#                 0.3795921504497528,
#                 0.20538713017482624
#             ],
#             [
#                 17104,
#                 0.01942264288663864,
#                 0.18222414598429398
#             ],
#             [
#                 11750,
#                 0.06946098059415817,
#                 0.17210160600216695
#             ],
#             [
#                 8981,
#                 0.014602972194552422,
#                 0.14771142369520274
#             ],
#             [
#                 8002,
#                 0.04838086664676666,
#                 0.14060300848480894
#             ],
#             [
#                 17837,
#                 0.004755072295665741,
#                 0.14036057234317698
#             ],
#             [
#                 12344,
#                 0.02838791348040104,
#                 0.11528457491653957
#             ]
#         ]
#     },
#     "layer_8": {
#         "anger": [
#             [
#                 17121,
#                 1,
#                 0.19902977574647152
#             ],
#             [
#                 2133,
#                 0.5426587462425232,
#                 0.1607958905400757
#             ],
#             [
#                 22715,
#                 0.438755601644516,
#                 0.10944272015794929
#             ],
#             [
#                 21519,
#                 0.41546928882598877,
#                 0.09658232139550386
#             ]
#         ],
#         "fear": [
#             [
#                 17376,
#                 1,
#                 0.26390855646230726
#             ],
#             [
#                 19585,
#                 0.5735774636268616,
#                 0.25169391760769994
#             ],
#             [
#                 4810,
#                 0.27226516604423523,
#                 0.20262602251278322
#             ],
#             [
#                 8887,
#                 0.08804775774478912,
#                 0.16339749364803594
#             ],
#             [
#                 19414,
#                 0.05977080017328262,
#                 0.12532519658353597
#             ],
#             [
#                 13796,
#                 0.2105170339345932,
#                 0.12093017130446482
#             ],
#             [
#                 4846,
#                 0.016738727688789368,
#                 0.10056587671427908
#             ]
#         ],
#         "joy": [
#             [
#                 13433,
#                 1,
#                 0.17801814644353076
#             ],
#             [
#                 13624,
#                 0.20513269305229187,
#                 0.154505641688851
#             ],
#             [
#                 8708,
#                 -0.003364543430507183,
#                 0.15395368477658902
#             ]
#         ],
#         "love": [
#             [
#                 9837,
#                 1,
#                 0.1631667737911828
#             ],
#             [
#                 8631,
#                 -0.0017908625304698944,
#                 0.16301622632359247
#             ],
#             [
#                 2017,
#                 -0.020764045417308807,
#                 0.15192311019817742
#             ]
#         ],
#         "sadness": [
#             [
#                 7473,
#                 1,
#                 0.25057070197773934
#             ],
#             [
#                 3927,
#                 0.25391995906829834,
#                 0.20485117401003242
#             ]
#         ],
#         "surprise": [
#             [
#                 20821,
#                 1,
#                 0.1765724577032459
#             ],
#             [
#                 15512,
#                 0.28180158138275146,
#                 0.17649723691992655
#             ],
#             [
#                 4939,
#                 0.2758517861366272,
#                 0.1696756270479311
#             ],
#             [
#                 14856,
#                 0.051559433341026306,
#                 0.16205112566614885
#             ],
#             [
#                 1366,
#                 0.07213882356882095,
#                 0.1578580400415697
#             ],
#             [
#                 12456,
#                 0.013793841935694218,
#                 0.14725834868127907
#             ],
#             [
#                 8855,
#                 0.2565309703350067,
#                 0.14281701614148742
#             ],
#             [
#                 14571,
#                 0.11001048982143402,
#                 0.14198788280829178
#             ],
#             [
#                 20423,
#                 -0.020416703075170517,
#                 0.11063703384550894
#             ],
#             [
#                 15950,
#                 0.10090149939060211,
#                 0.09446301131630665
#             ]
#         ]
#     },
#     "layer_9": {
#         "anger": [
#             [
#                 16663,
#                 1,
#                 0.21473812540887297
#             ],
#             [
#                 7002,
#                 0.2885972261428833,
#                 0.19165987648872254
#             ],
#             [
#                 21253,
#                 0.10931296646595001,
#                 0.14227579321941125
#             ],
#             [
#                 15510,
#                 -0.04688166826963425,
#                 0.12585348808072674
#             ]
#         ],
#         "fear": [
#             [
#                 14412,
#                 1,
#                 0.2523558114941905
#             ],
#             [
#                 5563,
#                 0.24532251060009003,
#                 0.16224825403285922
#             ],
#             [
#                 1413,
#                 0.053354572504758835,
#                 0.11857824542281893
#             ],
#             [
#                 15382,
#                 0.0976681113243103,
#                 0.09281098311335982
#             ],
#             [
#                 19535,
#                 0.1335928589105606,
#                 0.09177106545976688
#             ],
#             [
#                 20233,
#                 0.2844880521297455,
#                 0.04986965340782195
#             ]
#         ],
#         "joy": [
#             [
#                 20850,
#                 1,
#                 0.1956920794849623
#             ],
#             [
#                 7702,
#                 0.16698084771633148,
#                 0.1599505987320568
#             ],
#             [
#                 4864,
#                 0.08466528356075287,
#                 0.14074204721175307
#             ],
#             [
#                 4288,
#                 0.01165294274687767,
#                 0.1319626996286992
#             ],
#             [
#                 1418,
#                 0.01783488318324089,
#                 0.06399159932365774
#             ]
#         ],
#         "love": [
#             [
#                 21876,
#                 1,
#                 0.1469545155132451
#             ],
#             [
#                 17442,
#                 0.07604388892650604,
#                 0.11701267854432718
#             ],
#             [
#                 9946,
#                 0.08113935589790344,
#                 0.11666193263094957
#             ],
#             [
#                 20105,
#                 0.12429343163967133,
#                 0.08738932025264082
#             ],
#             [
#                 21303,
#                 -0.09180434048175812,
#                 0.05451161388276922
#             ]
#         ],
#         "sadness": [
#             [
#                 17773,
#                 1,
#                 0.19092236120522685
#             ],
#             [
#                 10885,
#                 0.3229801058769226,
#                 0.1292078931165955
#             ],
#             [
#                 5000,
#                 0.12129554152488708,
#                 0.11223734687350946
#             ]
#         ],
#         "surprise": [
#             [
#                 21445,
#                 1,
#                 0.1850345634398196
#             ],
#             [
#                 17898,
#                 0.05941426753997803,
#                 0.13615547034093636
#             ],
#             [
#                 14851,
#                 -1.0085292160511017e-05,
#                 0.1300274898812157
#             ],
#             [
#                 1167,
#                 0.03792114183306694,
#                 0.12529097914859502
#             ],
#             [
#                 21532,
#                 0.035126809030771255,
#                 0.11987030325248489
#             ],
#             [
#                 7831,
#                 0.09166508913040161,
#                 0.09777214876996076
#             ],
#             [
#                 14205,
#                 -0.006352921947836876,
#                 0.0961427479942547
#             ],
#             [
#                 10719,
#                 0.08245493471622467,
#                 0.08937957886027464
#             ],
#             [
#                 24082,
#                 0.09726198017597198,
#                 0.08867761913365724
#             ],
#             [
#                 1655,
#                 0.062036607414484024,
#                 0.08737819222006589
#             ],
#             [
#                 16180,
#                 0.01960209757089615,
#                 0.05907471591346272
#             ]
#         ]
#     }
# }

# %% [markdown]
# ^^^ \
# Why are semantically related features almost orthogonal to each other? Or am I mistaken in the sense that most features should be almost orthogonal to each other?
#
# Also, what happens when the features are normalized, more important features (whatever tf important means) should have higher norms right? So what happens when we normalize the weights of the features, i.e. what happens if we just isolate for the direction of the feature.

# %%
sae, cfg_dict, _ = SAE.from_pretrained(
        release = "gpt2-small-res-jb",
        sae_id = f"blocks.{3}.hook_resid_pre",
        device = device
        )

# %%
feature_vector = sae.W_dec[1]
# print(feature_vector)
print('norm(feature_vector)', torch.norm(feature_vector, p='fro', dim=None, keepdim=False, out=None, dtype=None))
print('feature_vector.shape', feature_vector.shape)
# print(torch.nn.functional.normalize(feature_vector, dim=0))
# Out:
# norm(feature_vector) tensor(1.0000, device='cuda:0')
# feature_vector.shape torch.Size([768])
